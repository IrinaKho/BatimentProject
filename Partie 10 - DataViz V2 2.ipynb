# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
df_selec_2=pd.read_csv("df_selec_2.csv")

# %%
df_selec_2.head()
# Out:
#    idmutation           etaban_lot  qty_of_mut  Revente     datemut  anneemut  \
# 0     7819809  75101_4901_00019_93           0        0  2021-06-04      2021
# 1     7819821  75117_5503_00103_24           0        0  2021-03-18      2021
# 2     7819822  75115_2521_00008_19           0        0  2021-11-12      2021
# 3     7819824  75118_2113_00110_19           1        1  2021-01-08      2021
# 4     8563148  75118_2113_00110_19           1        1  2016-09-09      2016
#
#    moismut  Immeuble_neuf  valeurfonc  nblot  ...  georad2020_alea  \
# 0        6              0    370000.0      1  ...           Faible
# 1        3              0    451000.0      1  ...           Faible
# 2       11              0    433000.0      3  ...           Faible
# 3        1              0    561076.0      1  ...           Faible
# 4        9              0    375980.0      1  ...           Faible
#
#    igntop202103_bat_hauteur  mcumer202007_is_mer  adedpe202006_logtype_s_hab  \
# 0                      20.2                  1.0                        75.0
# 1                      18.8                  1.0                        36.0
# 2                      18.0                  1.0                        49.0
# 3                      18.9                  1.0                       100.0
# 4                      18.9                  1.0                       100.0
#
#    adedpe202006_logtype_ch_type_inst  adedpe202006_logtype_ecs_type_inst  \
# 0                         individuel                          individuel
# 1                         individuel                          individuel
# 2                         individuel                          individuel
# 3                         individuel                          individuel
# 4                         individuel                          individuel
#
#    adedpe202006_logtype_mur_ep_mat_ext  adedpe202006_logtype_mur_mat_ext  \
# 0                                  NaN                     Mur en brique
# 1                                  NaN                     Mur en pierre
# 2                                  NaN                     Mur en pierre
# 3                                  NaN                     Mur en pierre
# 4                                  NaN                     Mur en pierre
#
#    adedpe202006_logtype_mur_pos_isol_ext  Commerces_bruyants
# 0                                    ITI                   1
# 1                                    ITI                   0
# 2                                    ITI                   0
# 3                                    ITI                   1
# 4                                    ITI                   1
#
# [5 rows x 51 columns]

# %%
# Idmutation en index
df_selec_2.set_index("idmutation", inplace=True)

# %%
df_selec_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105340 entries, 7819809 to 8843172
# Data columns (total 50 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   etaban_lot                                   105340 non-null  object
#  1   qty_of_mut                                   105340 non-null  int64
#  2   Revente                                      105340 non-null  int64
#  3   datemut                                      105340 non-null  object
#  4   anneemut                                     105340 non-null  int64
#  5   moismut                                      105340 non-null  int64
#  6   Immeuble_neuf                                105340 non-null  int64
#  7   valeurfonc                                   105304 non-null  float64
#  8   nblot                                        105340 non-null  int64
#  9   nbcomm                                       105340 non-null  int64
#  10  l_codinsee                                   105340 non-null  int64
#  11  nblocapt                                     105340 non-null  int64
#  12  nblocdep                                     105340 non-null  int64
#  13  nbapt2pp                                     105340 non-null  int64
#  14  nbapt3pp                                     105340 non-null  int64
#  15  sbati                                        105340 non-null  int64
#  16  sbatapt                                      105340 non-null  int64
#  17  sbatact                                      105340 non-null  int64
#  18  sapt2pp                                      105340 non-null  int64
#  19  sapt3pp                                      105340 non-null  int64
#  20  scarrez                                      105340 non-null  float64
#  21  anarnc202012_nb_log                          105340 non-null  float64
#  22  anarnc202012_nb_lot_garpark                  105340 non-null  float64
#  23  anarnc202012_nb_lot_tertiaire                105340 non-null  float64
#  24  anarnc202012_nb_lot_tot                      105340 non-null  float64
#  25  adedpe202006_logtype_baie_type_vitrage       100411 non-null  object
#  26  adedpe202006_logtype_ch_gen_lib_princ        100768 non-null  object
#  27  adedpe202006_mean_class_conso_ener           101524 non-null  object
#  28  adedpe202006_mean_class_estim_ges            101524 non-null  object
#  29  adedpe202006_logtype_traversant              88106 non-null   object
#  30  adedpe202006_logtype_ecs_type_ener           99710 non-null   object
#  31  adedpe202006_logtype_perc_surf_vitree_ext    16973 non-null   float64
#  32  adedpe202006_logtype_ph_pos_isol             76625 non-null   object
#  33  adedpe202006_logtype_presence_balcon         18477 non-null   float64
#  34  adedpe202006_logtype_presence_climatisation  101504 non-null  float64
#  35  adedpe202006_logtype_type_batiment           101504 non-null  object
#  36  ancqpv201410_is_qpv                          105129 non-null  float64
#  37  cerffo2020_annee_construction                95852 non-null   object
#  38  cerffo2020_usage_niveau_1_txt                105340 non-null  object
#  39  cerffo2020_nb_log                            105340 non-null  int64
#  40  georad2020_alea                              105129 non-null  object
#  41  igntop202103_bat_hauteur                     105116 non-null  float64
#  42  mcumer202007_is_mer                          105129 non-null  float64
#  43  adedpe202006_logtype_s_hab                   101346 non-null  float64
#  44  adedpe202006_logtype_ch_type_inst            88452 non-null   object
#  45  adedpe202006_logtype_ecs_type_inst           89494 non-null   object
#  46  adedpe202006_logtype_mur_ep_mat_ext          18044 non-null   object
#  47  adedpe202006_logtype_mur_mat_ext             105340 non-null  object
#  48  adedpe202006_logtype_mur_pos_isol_ext        105340 non-null  object
#  49  Commerces_bruyants                           105340 non-null  int64
# dtypes: float64(13), int64(19), object(18)
# memory usage: 41.0+ MB

# %%
df_selec_2.isna().sum()
# Out:
# etaban_lot                                         0
# qty_of_mut                                         0
# Revente                                            0
# datemut                                            0
# anneemut                                           0
# moismut                                            0
# Immeuble_neuf                                      0
# valeurfonc                                        36
# nblot                                              0
# nbcomm                                             0
# l_codinsee                                         0
# nblocapt                                           0
# nblocdep                                           0
# nbapt2pp                                           0
# nbapt3pp                                           0
# sbati                                              0
# sbatapt                                            0
# sbatact                                            0
# sapt2pp                                            0
# sapt3pp                                            0
# scarrez                                            0
# anarnc202012_nb_log                                0
# anarnc202012_nb_lot_garpark                        0
# anarnc202012_nb_lot_tertiaire                      0
# anarnc202012_nb_lot_tot                            0
# adedpe202006_logtype_baie_type_vitrage          4929
# adedpe202006_logtype_ch_gen_lib_princ           4572
# adedpe202006_mean_class_conso_ener              3816
# adedpe202006_mean_class_estim_ges               3816
# adedpe202006_logtype_traversant                17234
# adedpe202006_logtype_ecs_type_ener              5630
# adedpe202006_logtype_perc_surf_vitree_ext      88367
# adedpe202006_logtype_ph_pos_isol               28715
# adedpe202006_logtype_presence_balcon           86863
# adedpe202006_logtype_presence_climatisation     3836
# adedpe202006_logtype_type_batiment              3836
# ancqpv201410_is_qpv                              211
# cerffo2020_annee_construction                   9488
# cerffo2020_usage_niveau_1_txt                      0
# cerffo2020_nb_log                                  0
# georad2020_alea                                  211
# igntop202103_bat_hauteur                         224
# mcumer202007_is_mer                              211
# adedpe202006_logtype_s_hab                      3994
# adedpe202006_logtype_ch_type_inst              16888
# adedpe202006_logtype_ecs_type_inst             15846
# adedpe202006_logtype_mur_ep_mat_ext            87296
# adedpe202006_logtype_mur_mat_ext                   0
# adedpe202006_logtype_mur_pos_isol_ext              0
# Commerces_bruyants                                 0
# dtype: int64

# %%
df_selec_2.head()
# Out:
#                      etaban_lot  qty_of_mut  Revente     datemut  anneemut  \
# idmutation
# 7819809     75101_4901_00019_93           0        0  2021-06-04      2021
# 7819821     75117_5503_00103_24           0        0  2021-03-18      2021
# 7819822     75115_2521_00008_19           0        0  2021-11-12      2021
# 7819824     75118_2113_00110_19           1        1  2021-01-08      2021
# 8563148     75118_2113_00110_19           1        1  2016-09-09      2016
#
#             moismut  Immeuble_neuf  valeurfonc  nblot  nbcomm  ...  \
# idmutation                                                     ...
# 7819809           6              0    370000.0      1       1  ...
# 7819821           3              0    451000.0      1       1  ...
# 7819822          11              0    433000.0      3       1  ...
# 7819824           1              0    561076.0      1       1  ...
# 8563148           9              0    375980.0      1       1  ...
#
#             georad2020_alea  igntop202103_bat_hauteur  mcumer202007_is_mer  \
# idmutation
# 7819809              Faible                      20.2                  1.0
# 7819821              Faible                      18.8                  1.0
# 7819822              Faible                      18.0                  1.0
# 7819824              Faible                      18.9                  1.0
# 8563148              Faible                      18.9                  1.0
#
#             adedpe202006_logtype_s_hab  adedpe202006_logtype_ch_type_inst  \
# idmutation
# 7819809                           75.0                         individuel
# 7819821                           36.0                         individuel
# 7819822                           49.0                         individuel
# 7819824                          100.0                         individuel
# 8563148                          100.0                         individuel
#
#             adedpe202006_logtype_ecs_type_inst  \
# idmutation
# 7819809                             individuel
# 7819821                             individuel
# 7819822                             individuel
# 7819824                             individuel
# 8563148                             individuel
#
#             adedpe202006_logtype_mur_ep_mat_ext  \
# idmutation
# 7819809                                     NaN
# 7819821                                     NaN
# 7819822                                     NaN
# 7819824                                     NaN
# 8563148                                     NaN
#
#             adedpe202006_logtype_mur_mat_ext  \
# idmutation
# 7819809                        Mur en brique
# 7819821                        Mur en pierre
# 7819822                        Mur en pierre
# 7819824                        Mur en pierre
# 8563148                        Mur en pierre
#
#             adedpe202006_logtype_mur_pos_isol_ext  Commerces_bruyants
# idmutation
# 7819809                                       ITI                   1
# 7819821                                       ITI                   0
# 7819822                                       ITI                   0
# 7819824                                       ITI                   1
# 8563148                                       ITI                   1
#
# [5 rows x 50 columns]

# %%
# Analyse de la variable "Revente"
g=sns.countplot(x="Revente", data=df_selec_2, palette="Set2")
g.set_xticklabels(["Non", "Oui"])
plt.title('Revente pendant la période 2014 - 2021');

# %%
# Analyse de la variable df_selec_2["Immeuble_neuf"]

# %%
plt.figure(figsize=(10,10))
x=df_selec_2["Immeuble_neuf"].value_counts()
labels=["Non", "Oui"]
plt.pie(x, labels=labels, 
        colors=["#cc7ba6", "#84ae57"], 
        explode=[0.1,0.1], 
        autopct=lambda x : str(round(x,2))+ "%", 
        pctdistance=0.6, 
        shadow=True)
plt.title("Proportion de mutations en Vefa", fontsize=20)
plt.legend(loc="best");

# %%
# Analyse de la variable "valeurfonc" => prix ou évaluation déclarée dans le cadre d'une mutation onéreuse

# %%
pd.set_option('float_format', '{:f}'.format)
df_selec_2["valeurfonc"].describe().to_frame()
# Out:
#           valeurfonc
# count  105304.000000
# mean   461395.083071
# std    261237.367617
# min         0.000000
# 25%    298000.000000
# 50%    406000.000000
# 75%    560000.000000
# max   7650000.000000

# %%
g=sns.catplot(x="valeurfonc", kind="box", data=df_selec_2)
plt.title("Distribution de la valeur foncière", fontsize=20)
plt.xlabel('Valeurs foncières');

# %%
# Mémo => Allure = courbe Beta

# %%
df_selec_2[df_selec_2["valeurfonc"]<1000].shape
# Out:
# (41, 50)

# %%
df_selec_2[df_selec_2["valeurfonc"]>3500000].shape
# Out:
# (19, 50)

# %%
# Suppression des valeurs extrêmes
df_selec_2=df_selec_2[(df_selec_2["valeurfonc"]>1000)&(df_selec_2["valeurfonc"]<3500000)]

# %%
pd.set_option('float_format', '{:f}'.format)
df_selec_2["valeurfonc"].describe()
# Out:
# count    105240.000000
# mean     460776.174381
# std      253419.185406
# min        1001.000000
# 25%      298000.000000
# 50%      406093.500000
# 75%      560000.000000
# max     3455000.000000
# Name: valeurfonc, dtype: float64

# %%
g=sns.catplot(x="valeurfonc", kind="box", data=df_selec_2)
plt.title("Distribution de la valeur foncière", fontsize=20)
plt.xlabel('Valeurs foncières');

# %%
# Création de catégories de valeurs foncières
df_selec_2["cat_valeur"]=pd.cut(df_selec_2["valeurfonc"], 
bins=[0, 320000, 436600, 600000,3455000], 
labels=["<320k€ €", "Entre 320 & 436k€ €", "Entre 436 & 600k€", ">600k€"])

# %%
df_selec_2["cat_valeur"].value_counts().to_frame()
# Out:
#                      cat_valeur
# <320k€ €                  32621
# Entre 320 & 436k€ €       26309
# Entre 436 & 600k€         24933
# >600k€                    21377

# %%
plt.figure(figsize=(10,10))
x=df_selec_2["cat_valeur"].value_counts()
lab=df_selec_2["cat_valeur"].value_counts().index
color=["#e0c0f7", "#84ae57","#90aacc","#fd9283"]
plt.pie(x, labels=lab, 
        colors=color, 
        explode=[0.05,0.05,0.05,0.05],
        autopct=lambda x : str(round(x,2))+ "%", 
        pctdistance=0.7, 
        shadow=True)
plt.title("Valeurs foncières des appartements", fontsize=15)
plt.legend(loc="best");

# %%
pd.crosstab(df_selec_2["Revente"], df_selec_2["cat_valeur"], normalize=1)
# Out:
# cat_valeur  <320k€ €  Entre 320 & 436k€ €  Entre 436 & 600k€   >600k€
# Revente
# 0           0.828945             0.816755           0.799944 0.799130
# 1           0.171055             0.183245           0.200056 0.200870

# %%
plt.figure(figsize=(10,5))

sns.countplot(x=df_selec_2["cat_valeur"], palette="Set2")
plt.title("Nombre de mutations par catégorie de Valeurs foncières,\n sur la période 2014-2021", fontsize=20)
plt.xlabel('Valeurs foncières en €')
plt.legend(loc="best");
# Out:
# No handles with labels found to put in legend.

# %%
g=df_selec_2.groupby("cat_valeur").agg({"Revente":"mean"})

# %%
list_valeur=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(8,8))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#8f9873")
plt.xticks(x_ticks, list_valeur, rotation=60)
plt.xlabel("Catégorie de valeurs foncières")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot selon sa valeur foncière \n sur la période 2014-2021", fontsize=15);

# %%
# Ces 2 graphs ne nous donnent pas d'information évidente. Un même bien peut figurer plusieurs fois sur ce graphique 
# puisqu’il a pu être revendu plusieurs fois avec une valeur foncière qui a évolué. Donc interprétation très compliquée.
# On va plutôt créer une variable sur l'évolution des valeurs foncières d'un même lot entre 2 mutations

df_selec_2[["etaban_lot","valeurfonc","anneemut", "qty_of_mut"]]
# Out:
#                        etaban_lot    valeurfonc  anneemut  qty_of_mut
# idmutation
# 7819809       75101_4901_00019_93 370000.000000      2021           0
# 7819821       75117_5503_00103_24 451000.000000      2021           0
# 7819822       75115_2521_00008_19 433000.000000      2021           0
# 7819824       75118_2113_00110_19 561076.000000      2021           1
# 8563148       75118_2113_00110_19 375980.000000      2016           1
# ...                           ...           ...       ...         ...
# 8843161     75115_3500_00008_1047 462700.000000      2014           0
# 8843163       75109_7484_00037_10 225000.000000      2014           0
# 8843166       75118_5012_00009_20 198860.000000      2014           0
# 8843171       75108_1914_00007_18 360000.000000      2014           0
# 8843172       75116_6639_00177_33 315000.000000      2014           0
#
# [105240 rows x 4 columns]

# %%
df_selec_2["qty_of_mut"].value_counts()
# Out:
# 0    85557
# 1    18407
# 2     1232
# 3       44
# Name: qty_of_mut, dtype: int64

# %%
# On commence par isoler les lots qui ont été revendus au moins 1 fois pendant la période

t=df_selec_2[df_selec_2["qty_of_mut"]>0][["etaban_lot","anneemut","valeurfonc"]].sort_values(by=["etaban_lot","anneemut"])

# %%
t.head()
# Out:
#                      etaban_lot  anneemut    valeurfonc
# idmutation
# 8269301      75101_0407_00049_4      2018 660000.000000
# 8105917      75101_0407_00049_4      2019 853370.000000
# 8439768      75101_0407_00049_5      2017 660000.000000
# 8119208      75101_0407_00049_5      2019 880000.000000
# 8712767     75101_0407_00056_21      2015 200000.000000

# %%
# On créé une colonne qui va nous permettre de distinguer la 1ère ligne de mutation (first)
# pour calculer l'évolution des prix sur les autres lignes (not first)

etaban_lot=t["etaban_lot"].iloc[0]
t["range_revente_first"]="not first"

for index, value in enumerate(t["etaban_lot"]) :
    if etaban_lot!=value :
        t["range_revente_first"].iloc[index]="first"
    etaban_lot=value
    print(value)
# Out:
# 75101_0407_00049_4
# 75101_0407_00049_4
# 75101_0407_00049_5
# 75101_0407_00049_5
# 75101_0407_00056_21
# 75101_0407_00056_21
# 75101_0407_00056_8
# 75101_0407_00056_8
# 75101_0632_00006_13
# 75101_0632_00006_13
# 75101_0632_00006_13
# 75101_0632_00006_20
# 75101_0632_00006_20
# 75101_1105_00020_48
# 75101_1105_00020_48
# 75101_1178_00013_9
# 75101_1178_00013_9
# 75101_1178_00015_12
# 75101_1178_00015_12
# 75101_2318_00008_6
# 75101_2318_00008_6
# 75101_2318_00031_297
# 75101_2318_00031_297
# 75101_2400_00001_8
# 75101_2400_00001_8
# 75101_2453_00020_83
# 75101_2453_00020_83
# 75101_2502_00009_5
# 75101_2502_00009_5
# 75101_2594_00016_12
# 75101_2594_00016_12
# 75101_2999_00017_21
# 75101_2999_00017_21
# 75101_3392_00003_5
# 75101_3392_00003_5
# 75101_3392_00027_24
# 75101_3392_00027_24
# 75101_3621_00011_9
# 75101_3621_00011_9
# 75101_4461_00019_25
# 75101_4461_00019_25
# 75101_4619_00013_57
# 75101_4619_00013_57
# 75101_4901_00019_199
# 75101_4901_00019_199
# 75101_5368_00010_8
# 75101_5368_00010_8
# 75101_5417_00008_24
# 75101_5417_00008_24
# 75101_5824_00026_6
# 75101_5824_00026_6
# 75101_5825_00015_113
# 75101_5825_00015_113
# 75101_6033_00017_3
# 75101_6033_00017_3
# 75101_6033_00019_14
# 75101_6033_00019_14
# 75101_6033_00034_39
# 75101_6033_00034_39
# 75101_6033_00036_7
# 75101_6033_00036_7
# 75101_6034_00006_19
# 75101_6034_00006_19
# 75101_6249_00020_56
# 75101_6249_00020_56
# 75101_6407_00005_113
# 75101_6407_00005_113
# 75101_6407_00009_18
# 75101_6407_00009_18
# 75101_6407_00009_7
# 75101_6407_00009_7
# 75101_6513_00017_107
# 75101_6513_00017_107
# 75101_6513_00026_42
# 75101_6513_00026_42
# 75101_6513_00026_42
# 75101_6520_00027_66
# 75101_6520_00027_66
# 75101_6520_00027_67
# 75101_6520_00027_67
# 75101_6520_00032_46
# 75101_6520_00032_46
# 75101_6537_00032_7
# 75101_6537_00032_7
# 75101_7279_00005_52
# 75101_7279_00005_52
# 75101_7348_00007_10
# 75101_7348_00007_10
# 75101_7902_00005_49
# 75101_7902_00005_49
# 75101_8212_00043_120
# 75101_8212_00043_120
# 75101_8212_00056_63
# 75101_8212_00056_63
# 75101_8249_00140_27
# 75101_8249_00140_27
# 75101_8397_00003_18
# 75101_8397_00003_18
# 75101_8397_00017_14
# 75101_8397_00017_14
# 75101_8525_00015_5
# 75101_8525_00015_5
# 75101_8525_00079_11
# 75101_8525_00079_11
# 75101_8534_00030_7
# 75101_8534_00030_7
# 75101_8534_00034_16
# 75101_8534_00034_16
# 75101_8611_00010_27
# 75101_8611_00010_27
# 75101_8623_00013_5
# 75101_8623_00013_5
# 75101_8623_00013_7
# 75101_8623_00013_7
# 75101_8635_00035_16
# 75101_8635_00035_16
# 75101_8635_00089_22
# 75101_8635_00089_22
# 75101_8635_00123_219
# 75101_8635_00123_219
# 75101_8635_00127_108
# 75101_8635_00127_108
# 75101_8635_00173_29
# 75101_8635_00173_29
# 75101_8635_00179_19
# 75101_8635_00179_19
# 75101_8635_00179_19
# 75101_8635_00191_81
# 75101_8635_00191_81
# 75101_8635_00209_8
# 75101_8635_00209_8
# 75101_8635_00304_4
# 75101_8635_00304_4
# 75101_8635_00304_4
# 75101_8635_00304_9
# 75101_8635_00304_9
# 75101_8641_00008_154
# 75101_8641_00008_154
# 75101_8855_00005_18
# 75101_8855_00005_18
# 75101_8894_00007_17
# 75101_8894_00007_17
# 75101_8894_00037_31
# 75101_8894_00037_31
# 75101_8894_00039_57
# 75101_8894_00039_57
# 75101_8894_00043_6
# 75101_8894_00043_6
# 75102_0040_00094_25
# 75102_0040_00094_25
# 75102_0040_00094_31
# 75102_0040_00094_31
# 75102_0040_00117_28
# 75102_0040_00117_28
# 75102_0040_00130_19
# 75102_0040_00130_19
# 75102_0440_00007_8
# 75102_0440_00007_8
# 75102_0440_00044_4
# 75102_0440_00044_4
# 75102_0622_00006_12
# 75102_0622_00006_12
# 75102_0789_00014_32
# 75102_0789_00014_32
# 75102_0789_00028_32
# 75102_0789_00028_32
# 75102_0789_00050_10
# 75102_0789_00050_10
# 75102_1021_00021_21
# 75102_1021_00021_21
# 75102_1317_00002_4
# 75102_1317_00002_4
# 75102_1432_00019_21
# 75102_1432_00019_21
# 75102_1432_00042_13
# 75102_1432_00042_13
# 75102_1432_00043_29
# 75102_1432_00043_29
# 75102_2013_00019_33
# 75102_2013_00019_33
# 75102_2110_00006_16
# 75102_2110_00006_16
# 75102_2110_00006_16
# 75102_2110_00008_12
# 75102_2110_00008_12
# 75102_2110_00035_43
# 75102_2110_00035_43
# 75102_2110_00051_30
# 75102_2110_00051_30
# 75102_2110_00089_24
# 75102_2110_00089_24
# 75102_2110_00100_37
# 75102_2110_00100_37
# 75102_2451_00008_111
# 75102_2451_00008_111
# 75102_2451_00013_22
# 75102_2451_00013_22
# 75102_2451_00017_3
# 75102_2451_00017_3
# 75102_3055_00020_157
# 75102_3055_00020_157
# 75102_3055_00022_301
# 75102_3055_00022_301
# 75102_3635_00032_35
# 75102_3635_00032_35
# 75102_3635_00034_6
# 75102_3635_00034_6
# 75102_3779_00012_45
# 75102_3779_00012_45
# 75102_4318_00048_27
# 75102_4318_00048_27
# 75102_4318_00048_34
# 75102_4318_00048_34
# 75102_4973_00001_4
# 75102_4973_00001_4
# 75102_4973_00001_6
# 75102_4973_00001_6
# 75102_4973_00018_39
# 75102_4973_00018_39
# 75102_5302_00018_17
# 75102_5302_00018_17
# 75102_5302_00020_11
# 75102_5302_00020_11
# 75102_5302_00020_64
# 75102_5302_00020_64
# 75102_5582_00028_18
# 75102_5582_00028_18
# 75102_5820_00005_37
# 75102_5820_00005_37
# 75102_5850_00035_37
# 75102_5850_00035_37
# 75102_5850_00035_55
# 75102_5850_00035_55
# 75102_5913_00009_15
# 75102_5913_00009_15
# 75102_5974_00007_3
# 75102_5974_00007_3
# 75102_5974_00014_6
# 75102_5974_00014_6
# 75102_6124_00019_40
# 75102_6124_00019_40
# 75102_6510_00017_64
# 75102_6510_00017_64
# 75102_6513_00049_8
# C:\Users\Anne\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 75102_6513_00049_8
# 75102_6513_00055_15
# 75102_6513_00055_15
# 75102_6513_00055_21
# 75102_6513_00055_21
# 75102_6513_00055_28
# 75102_6513_00055_28
# 75102_6513_00062_8
# 75102_6513_00062_8
# 75102_6513_00064_5
# 75102_6513_00064_5
# 75102_6513_00112_14
# 75102_6513_00112_14
# 75102_6513_00152_105
# 75102_6513_00152_105
# 75102_6513_00159_134
# 75102_6513_00159_134
# 75102_6513_00164_14
# 75102_6513_00164_14
# 75102_6520_00071_14
# 75102_6520_00071_14
# 75102_6520_00076_12
# 75102_6520_00076_12
# 75102_6635_00002_7
# 75102_6635_00002_7
# 75102_6635_00007_22
# 75102_6635_00007_22
# 75102_6783_00003_18
# 75102_6783_00003_18
# 75102_6783_00010_19
# 75102_6783_00010_19
# 75102_6836_00018_6
# 75102_6836_00018_6
# 75102_6836_00020_18
# 75102_6836_00020_18
# 75102_6998_00006_42
# 75102_6998_00006_42
# 75102_7028_00022_331
# 75102_7028_00022_331
# 75102_7346_00003_32
# 75102_7346_00003_32
# 75102_7346_00005_19
# 75102_7346_00005_19
# 75102_7346_00010_10
# 75102_7346_00010_10
# 75102_7346_00019_17
# 75102_7346_00019_17
# 75102_7346_00037_38
# 75102_7346_00037_38
# 75102_7561_00030_5
# 75102_7561_00030_5
# 75102_7561_00031_12
# 75102_7561_00031_12
# 75102_7738_00010_13
# 75102_7738_00010_13
# 75102_7738_00010_13
# 75102_8073_00085_15
# 75102_8073_00085_15
# 75102_8212_00110_69
# 75102_8212_00110_69
# 75102_8493_00003_14
# 75102_8493_00003_14
# 75102_8525_00118_7
# 75102_8525_00118_7
# 75102_8525_00126_16
# 75102_8525_00126_16
# 75102_8525_00128_8
# 75102_8525_00128_8
# 75102_8525_00136_104
# 75102_8525_00136_104
# 75102_8525_00141_112
# 75102_8525_00141_112
# 75102_8525_00142_11
# 75102_8525_00142_11
# 75102_8525_00142_23
# 75102_8525_00142_23
# 75102_8525_00163_84
# 75102_8525_00163_84
# 75102_8525_00183_31
# 75102_8525_00183_31
# 75102_8525_00187_16
# 75102_8525_00187_16
# 75102_8525_00187_25
# 75102_8525_00187_25
# 75102_8525_00216_5
# 75102_8525_00216_5
# 75102_8525_00228_114
# 75102_8525_00228_114
# 75102_8525_00251_10
# 75102_8525_00251_10
# 75102_8525_00251_6
# 75102_8525_00251_6
# 75102_8525_00251_8
# 75102_8525_00251_8
# 75102_8525_00271_55
# 75102_8525_00271_55
# 75102_8534_00046_18
# 75102_8534_00046_18
# 75102_8534_00071_12
# 75102_8534_00071_12
# 75102_8538_00016_11
# 75102_8538_00016_11
# 75102_8538_00016_9
# 75102_8538_00016_9
# 75102_8538_00019_14
# 75102_8538_00019_14
# 75102_8538_00023_91
# 75102_8538_00023_91
# 75102_8561_00014_125
# 75102_8561_00014_125
# 75102_8561_00014_166
# 75102_8561_00014_166
# 75102_8561_00014_168
# 75102_8561_00014_168
# 75102_8561_00014_5
# 75102_8561_00014_5
# 75102_8561_00014_96
# 75102_8561_00014_96
# 75102_8609_00018_3
# 75102_8609_00018_3
# 75102_8686_00008_195
# 75102_8686_00008_195
# 75102_8686_00008_195
# 75102_8686_00008_197
# 75102_8686_00008_197
# 75102_8752_00005_4
# 75102_8752_00005_4
# 75102_8752_00024_28
# 75102_8752_00024_28
# 75102_8752_00024_36
# 75102_8752_00024_36
# 75102_8752_00024_39
# 75102_8752_00024_39
# 75102_8752_00057_5
# 75102_8752_00057_5
# 75102_8894_00133_9
# 75102_8894_00133_9
# 75102_9318_00002_14
# 75102_9318_00002_14
# 75102_9318_00012_3
# 75102_9318_00012_3
# 75102_9318_00031_3
# 75102_9318_00031_3
# 75102_9318_00035_9
# 75102_9318_00035_9
# 75102_9318_00036_13
# 75102_9318_00036_13
# 75102_9318_00044_2
# 75102_9318_00044_2
# 75102_9318_00054_4
# 75102_9318_00054_4
# 75102_9318_00062_13
# 75102_9318_00062_13
# 75102_9318_00062_58
# 75102_9318_00062_58
# 75102_9408_00007_32
# 75102_9408_00007_32
# 75102_9408_00009_8
# 75102_9408_00009_8
# 75102_9504_00022_19
# 75102_9504_00022_19
# 75102_9741_00008_9
# 75102_9741_00008_9
# 75102_9834_00002_32
# 75102_9834_00002_32
# 75102_9834_00009_5
# 75102_9834_00009_5
# 75102_9834_00009_6
# 75102_9834_00009_6
# 75102_9893_00028_6
# 75102_9893_00028_6
# 75102_9893_00042_20
# 75102_9893_00042_20
# 75102_9893_00046_10
# 75102_9893_00046_10
# 75102_9900_00002_10
# 75102_9900_00002_10
# 75103_0420_00047_7
# 75103_0420_00047_7
# 75103_0420_00055_137
# 75103_0420_00055_137
# 75103_0420_00059_47
# 75103_0420_00059_47
# 75103_0420_00075_204
# 75103_0420_00075_204
# 75103_0420_00078_11
# 75103_0420_00078_11
# 75103_0420_00079_31
# 75103_0420_00079_31
# 75103_0420_00090_88
# 75103_0420_00090_88
# 75103_0420_00096_10
# 75103_0420_00096_10
# 75103_0761_00018_9
# 75103_0761_00018_9
# 75103_0783_00083_6
# 75103_0783_00083_6
# 75103_0783_00085_51
# 75103_0783_00085_51
# 75103_0783_00113_18
# 75103_0783_00113_18
# 75103_0783_00113_58
# 75103_0783_00113_58
# 75103_0871_00019_37
# 75103_0871_00019_37
# 75103_0871_00020_13
# 75103_0871_00020_13
# 75103_0871_00021_31
# 75103_0871_00021_31
# 75103_0871_00024_32
# 75103_0871_00024_32
# 75103_1021_00003_27
# 75103_1021_00003_27
# 75103_1261_00009_27
# 75103_1261_00009_27
# 75103_1275_00017_12
# 75103_1275_00017_12
# 75103_1275_00025_18
# 75103_1275_00025_18
# 75103_1275_00069_10
# 75103_1275_00069_10
# 75103_1413_00008_3
# 75103_1413_00008_3
# 75103_1413_00016_27
# 75103_1413_00016_27
# 75103_1771_00011_18
# 75103_1771_00011_18
# 75103_1771_00024_16
# 75103_1771_00024_16
# 75103_1771_00026_18
# 75103_1771_00026_18
# 75103_1771_00028_26
# 75103_1771_00028_26
# 75103_1771_00054_14
# 75103_1771_00054_14
# 75103_1771_00054_14
# 75103_1771_00056_520
# 75103_1771_00056_520
# 75103_1880_00020_10
# 75103_1880_00020_10
# 75103_1880_00020_10
# 75103_1880_00023_3
# 75103_1880_00023_3
# 75103_1880_00033_109
# 75103_1880_00033_109
# 75103_1880_00043_29
# 75103_1880_00043_29
# 75103_1880_00049_9
# 75103_1880_00049_9
# 75103_1880_00067_4
# 75103_1880_00067_4
# 75103_1880_00077_128
# 75103_1880_00077_128
# 75103_1880_00077_134
# 75103_1880_00077_134
# 75103_2249_00012_68
# 75103_2249_00012_68
# 75103_2249_00019_10
# 75103_2249_00019_10
# 75103_2330_00014_30
# 75103_2330_00014_30
# 75103_2412_00022_11
# 75103_2412_00022_11
# 75103_2616_00010_4
# 75103_2616_00010_4
# 75103_2616_00029_5
# 75103_2616_00029_5
# 75103_2616_00031_67
# 75103_2616_00031_67
# 75103_2996_00004_15
# 75103_2996_00004_15
# 75103_2997_00002_13
# 75103_2997_00002_13
# 75103_2997_00016_29
# 75103_2997_00016_29
# 75103_3196_00015_11
# 75103_3196_00015_11
# 75103_3196_00015_12
# 75103_3196_00015_12
# 75103_3643_00004_65
# 75103_3643_00004_65
# 75103_3643_00006_11
# 75103_3643_00006_11
# 75103_3643_00012_8
# 75103_3643_00012_8
# 75103_3698_00004_5
# 75103_3698_00004_5
# 75103_3698_00006_57
# 75103_3698_00006_57
# 75103_3820_00046_34
# 75103_3820_00046_34
# 75103_3820_00048_4
# 75103_3820_00048_4
# 75103_3875_00004_4
# 75103_3875_00004_4
# 75103_3875_00014_21
# 75103_3875_00014_21
# 75103_4301_00003_5
# 75103_4301_00003_5
# 75103_4302_00005_18
# 75103_4302_00005_18
# 75103_4302_00018_9
# 75103_4302_00018_9
# 75103_4302_00018_9
# 75103_4302_00052_14
# 75103_4302_00052_14
# 75103_4302_00059_115
# 75103_4302_00059_115
# 75103_5927_00012_27
# 75103_5927_00012_27
# 75103_5927_00049_7
# 75103_5927_00049_7
# 75103_5927_00049_7
# 75103_5927_00059_11
# 75103_5927_00059_11
# 75103_5927_00059_6
# 75103_5927_00059_6
# 75103_6286_00022_16
# 75103_6286_00022_16
# 75103_6286_00032_52
# 75103_6286_00032_52
# 75103_6286_00041_14
# 75103_6286_00041_14
# 75103_6286_00041_4
# 75103_6286_00041_4
# 75103_6286_00048_28
# 75103_6286_00048_28
# 75103_6286_00050_39
# 75103_6286_00050_39
# 75103_6286_00050_39
# 75103_6336_00015_21
# 75103_6336_00015_21
# 75103_6336_00018_18
# 75103_6336_00018_18
# 75103_6336_00021_25
# 75103_6336_00021_25
# 75103_6336_00023_36
# 75103_6336_00023_36
# 75103_6497_00008_6
# 75103_6497_00008_6
# 75103_6517_00034_7
# 75103_6517_00034_7
# 75103_6517_00034_7
# 75103_6517_00037_24
# 75103_6517_00037_24
# 75103_6834_00005_16
# 75103_6834_00005_16
# 75103_6834_00007_17
# 75103_6834_00007_17
# 75103_6834_00007_19
# 75103_6834_00007_19
# 75103_6834_00009_44
# 75103_6834_00009_44
# 75103_6834_00010_33
# 75103_6834_00010_33
# 75103_6834_00013_42
# 75103_6834_00013_42
# 75103_6834_00018_16
# 75103_6834_00018_16
# 75103_6834_00019_133
# 75103_6834_00019_133
# 75103_6834_00026_58
# 75103_6834_00026_58
# 75103_6834_00028_26
# 75103_6834_00028_26
# 75103_6834_00028_6
# 75103_6834_00028_6
# 75103_6834_00030_6
# 75103_6834_00030_6
# 75103_6834_00034_113
# 75103_6834_00034_113
# 75103_6834_00035_25
# 75103_6834_00035_25
# 75103_6834_00036_14
# 75103_6834_00036_14
# 75103_6834_00044_36
# 75103_6834_00044_36
# 75103_6834_00050_8
# 75103_6834_00050_8
# 75103_6834_00056_6
# 75103_6834_00056_6
# 75103_6834_00058_10
# 75103_6834_00058_10
# 75103_6834_00066_37
# 75103_6834_00066_37
# 75103_6834_00067_6
# 75103_6834_00067_6
# 75103_6834_00068_31
# 75103_6834_00068_31
# 75103_6834_00076_264
# 75103_6834_00076_264
# 75103_6834_00079_20
# 75103_6834_00079_20
# 75103_6834_00084_8
# 75103_6834_00084_8
# 75103_6983_00009_8
# 75103_6983_00009_8
# 75103_7061_00016_684
# 75103_7061_00016_684
# 75103_7094_00044_21
# 75103_7094_00044_21
# 75103_7151_00003_22
# 75103_7151_00003_22
# 75103_7248_00007_6
# 75103_7248_00007_6
# 75103_7248_00011_15
# 75103_7248_00011_15
# 75103_7248_00011_17
# 75103_7248_00011_17
# 75103_7248_00011_24
# 75103_7248_00011_24
# 75103_7248_00011_64
# 75103_7248_00011_64
# 75103_7395_00009_16
# 75103_7395_00009_16
# 75103_7395_00011_19
# 75103_7395_00011_19
# 75103_7572_00006_4
# 75103_7572_00006_4
# 75103_7572_00019_11
# 75103_7572_00019_11
# 75103_7572_00023_15
# 75103_7572_00023_15
# 75103_7572_00023_15
# 75103_7572_00024_116
# 75103_7572_00024_116
# 75103_7572_00025_18
# 75103_7572_00025_18
# 75103_7605_00025_5
# 75103_7605_00025_5
# 75103_7729_00005_9
# 75103_7729_00005_9
# 75103_7970_00086_16
# 75103_7970_00086_16
# 75103_7970_00088_4
# 75103_7970_00088_4
# 75103_7970_00088_5
# 75103_7970_00088_5
# 75103_7970_00100_15
# 75103_7970_00100_15
# 75103_8009_00020_21
# 75103_8009_00020_21
# 75103_8009_00020_32
# 75103_8009_00020_32
# 75103_8009_00026_29
# 75103_8009_00026_29
# 75103_8009_00026_29
# 75103_8009_00058_12
# 75103_8009_00058_12
# 75103_8073_00018_2
# 75103_8073_00018_2
# 75103_8073_00018_5
# 75103_8073_00018_5
# 75103_8073_00030_59
# 75103_8073_00030_59
# 75103_8073_00030_7
# 75103_8073_00030_7
# 75103_8520_00010_44
# 75103_8520_00010_44
# 75103_8520_00020_212
# 75103_8520_00020_212
# 75103_8531_00016_10
# 75103_8531_00016_10
# 75103_8538_00007_16
# 75103_8538_00007_16
# 75103_8552_00004_68
# 75103_8552_00004_68
# 75103_8692_00007_4
# 75103_8692_00007_4
# 75103_8692_00037_34
# 75103_8692_00037_34
# 75103_8692_00055_9
# 75103_8692_00055_9
# 75103_8694_00163_103
# 75103_8694_00163_103
# 75103_8694_00163_56
# 75103_8694_00163_56
# 75103_8694_00171_12
# 75103_8694_00171_12
# 75103_8694_00177_7
# 75103_8694_00177_7
# 75103_8694_00210_9
# 75103_8694_00210_9
# 75103_8694_00227_31
# 75103_8694_00227_31
# 75103_8694_00236_6
# 75103_8694_00236_6
# 75103_8694_00245_8
# 75103_8694_00245_8
# 75103_8694_00245_9
# 75103_8694_00245_9
# 75103_8694_00314_210
# 75103_8694_00314_210
# 75103_8694_00318_3
# 75103_8694_00318_3
# 75103_8694_00341_52
# 75103_8694_00341_52
# 75103_8716_00022_14
# 75103_8716_00022_14
# 75103_8716_00026_118
# 75103_8716_00026_118
# 75103_8716_00042_11
# 75103_8716_00042_11
# 75103_8716_00059_9
# 75103_8716_00059_9
# 75103_8716_00065_15
# 75103_8716_00065_15
# 75103_9190_00017_31
# 75103_9190_00017_31
# 75103_9190_00017_33
# 75103_9190_00017_33
# 75103_9190_00037_63
# 75103_9190_00037_63
# 75103_9191_00081_59
# 75103_9191_00081_59
# 75103_9191_00081_65
# 75103_9191_00081_65
# 75103_9191_00102_22
# 75103_9191_00102_22
# 75103_9191_00138_48
# 75103_9191_00138_48
# 75103_9191_00159_102
# 75103_9191_00159_102
# 75103_9191_00161_9
# 75103_9191_00161_9
# 75103_9191_00167_38
# 75103_9191_00167_38
# 75103_9191_00170_215
# 75103_9191_00170_215
# 75103_9191_00189_26
# 75103_9191_00189_26
# 75103_9298_00013_43
# 75103_9298_00013_43
# 75103_9382_00045_36
# 75103_9382_00045_36
# 75103_9382_00056_50
# 75103_9382_00056_50
# 75103_9382_00058_9
# 75103_9382_00058_9
# 75103_9504_00040_5
# 75103_9504_00040_5
# 75103_9504_00044_12
# 75103_9504_00044_12
# 75103_9504_00077_19
# 75103_9504_00077_19
# 75103_9504_00079_3
# 75103_9504_00079_3
# 75103_9504_00087_13
# 75103_9504_00087_13
# 75103_9506_00038_14
# 75103_9506_00038_14
# 75103_9506_00044_6
# 75103_9506_00044_6
# 75103_9506_00045_35
# 75103_9506_00045_35
# 75103_9506_00057_24
# 75103_9506_00057_24
# 75103_9506_00060_2
# 75103_9506_00060_2
# 75103_9506_00062_15
# 75103_9506_00062_15
# 75103_9506_00075_38
# 75103_9506_00075_38
# 75103_9506_00085_19
# 75103_9506_00085_19
# 75103_9506_00092_6
# 75103_9506_00092_6
# 75103_9506_00093_18
# 75103_9506_00093_18
# 75103_9506_00097_36
# 75103_9506_00097_36
# 75103_9506_00117_8
# 75103_9506_00117_8
# 75103_9711_00007_11
# 75103_9711_00007_11
# 75103_9711_00030_8
# 75103_9711_00030_8
# 75103_9715_00019_18
# 75103_9715_00019_18
# 75103_9715_00022_4
# 75103_9715_00022_4
# 75103_9715_00028_10
# 75103_9715_00028_10
# 75103_9783_00106_23
# 75103_9783_00106_23
# 75103_9783_00109_8
# 75103_9783_00109_8
# 75103_9783_00117_205
# 75103_9783_00117_205
# 75103_9783_00130_19
# 75103_9783_00130_19
# 75103_9905_00006_3
# 75103_9905_00006_3
# 75103_9905_00042_9
# 75103_9905_00042_9
# 75103_9905_00043_118
# 75103_9905_00043_118
# 75103_9905_00043_118
# 75103_9905_00050_1
# 75103_9905_00050_1
# 75103_9905_00052_14
# 75103_9905_00052_14
# 75104_0350_00005_26
# 75104_0350_00005_26
# 75104_0420_00015_29
# 75104_0420_00015_29
# 75104_0420_00018_107
# 75104_0420_00018_107
# 75104_0420_00018_18
# 75104_0420_00018_18
# 75104_0420_00033_38
# 75104_0420_00033_38
# 75104_0420_00036_8
# 75104_0420_00036_8
# 75104_0420_00036_8
# 75104_0420_00052_15
# 75104_0420_00052_15
# 75104_0420_00052_22
# 75104_0420_00052_22
# 75104_0471_00011_3
# 75104_0471_00011_3
# 75104_0523_00008_37
# 75104_0523_00008_37
# 75104_0523_00008_59
# 75104_0523_00008_59
# 75104_0783_00019_5
# 75104_0783_00019_5
# 75104_0783_00029_6
# 75104_0783_00029_6
# 75104_0797_00010_27
# 75104_0797_00010_27
# 75104_0797_00010_27
# 75104_0978_00007_6
# 75104_0978_00007_6
# 75104_1013_00019_5
# 75104_1013_00019_5
# 75104_1013_00028_8
# 75104_1013_00028_8
# 75104_1182_00019_2
# 75104_1182_00019_2
# 75104_1182_00021_65
# 75104_1182_00021_65
# 75104_1223_00002_48
# 75104_1223_00002_48
# 75104_1223_00007_6
# 75104_1223_00007_6
# 75104_1365_00013_10
# 75104_1365_00013_10
# 75104_1636_00014_14
# 75104_1636_00014_14
# 75104_1636_00022_63
# 75104_1636_00022_63
# 75104_1748_00017_73
# 75104_1748_00017_73
# 75104_1748_00026_10
# 75104_1748_00026_10
# 75104_1797_00016_3
# 75104_1797_00016_3
# 75104_1797_00016_62
# 75104_1797_00016_62
# 75104_2130_00016_704
# 75104_2130_00016_704
# 75104_2197_00004_4
# 75104_2197_00004_4
# 75104_2774_00019_36
# 75104_2774_00019_36
# 75104_2774_00035_41
# 75104_2774_00035_41
# 75104_3106_00025_34
# 75104_3106_00025_34
# 75104_3583_00002_7
# 75104_3583_00002_7
# 75104_3805_00019_17
# 75104_3805_00019_17
# 75104_3820_00029_26
# 75104_3820_00029_26
# 75104_3820_00029_8
# 75104_3820_00029_8
# 75104_4102_00007_125
# 75104_4102_00007_125
# 75104_4365_00004_10
# 75104_4365_00004_10
# 75104_4365_00008_24
# 75104_4365_00008_24
# 75104_4365_00010_8
# 75104_4365_00010_8
# 75104_4583_00027_210
# 75104_4583_00027_210
# 75104_4831_00006_18
# 75104_4831_00006_18
# 75104_5599_00011_6
# 75104_5599_00011_6
# 75104_5616_00010_15
# 75104_5616_00010_15
# 75104_5702_00015_120
# 75104_5702_00015_120
# 75104_5738_00006_12
# 75104_5738_00006_12
# 75104_5738_00006_18
# 75104_5738_00006_18
# 75104_5738_00012_17
# 75104_5738_00012_17
# 75104_5958_00004_10
# 75104_5958_00004_10
# 75104_5958_00020_105
# 75104_5958_00020_105
# 75104_6559_00014_15
# 75104_6559_00014_15
# 75104_6559_00014_4
# 75104_6559_00014_4
# 75104_6944_00011_5
# 75104_6944_00011_5
# 75104_7195_00006_7
# 75104_7195_00006_7
# 75104_7195_00006_7
# 75104_7213_00001_1
# 75104_7213_00001_1
# 75104_7213_00007_27
# 75104_7213_00007_27
# 75104_7213_00011_11
# 75104_7213_00011_11
# 75104_7213_00012_67
# 75104_7213_00012_67
# 75104_7338_00015_9
# 75104_7338_00015_9
# 75104_7338_00016_16
# 75104_7338_00016_16
# 75104_7772_00004_6
# 75104_7772_00004_6
# 75104_7970_00061_74
# 75104_7970_00061_74
# 75104_8009_00015_27
# 75104_8009_00015_27
# 75104_8249_00050_13
# 75104_8249_00050_13
# 75104_8316_00027_5
# 75104_8316_00027_5
# 75104_8316_00028_4
# 75104_8316_00028_4
# 75104_8316_00050_206
# 75104_8316_00050_206
# 75104_8370_00008_17
# 75104_8370_00008_17
# 75104_8370_00024_23
# 75104_8370_00024_23
# 75104_8370_00029_3
# 75104_8370_00029_3
# 75104_8490_00016_155
# 75104_8490_00016_155
# 75104_8490_00019_55
# 75104_8490_00019_55
# 75104_8490_00032_65
# 75104_8490_00032_65
# 75104_8490_00054_3
# 75104_8490_00054_3
# 75104_8490_00055_10
# 75104_8490_00055_10
# 75104_8490_00060_166
# 75104_8490_00060_166
# 75104_8490_00068_8
# 75104_8490_00068_8
# 75104_8548_00024_2
# 75104_8548_00024_2
# 75104_8548_00024_24
# 75104_8548_00024_24
# 75104_8548_00038_21
# 75104_8548_00038_21
# 75104_8548_00039_107
# 75104_8548_00039_107
# 75104_8548_00039_113
# 75104_8548_00039_113
# 75104_8548_00039_12
# 75104_8548_00039_12
# 75104_8678_00055_7
# 75104_8678_00055_7
# 75104_8678_00056_13
# 75104_8678_00056_13
# 75104_8678_00068_6
# 75104_8678_00068_6
# 75104_8678_00068_8
# 75104_8678_00068_8
# 75104_8694_00024_9
# 75104_8694_00024_9
# 75104_8694_00067_10
# 75104_8694_00067_10
# 75104_8694_00073_16
# 75104_8694_00073_16
# 75104_8694_00090_6
# 75104_8694_00090_6
# 75104_8723_00010_23
# 75104_8723_00010_23
# 75104_8723_00035_121
# 75104_8723_00035_121
# 75104_8723_00037_12
# 75104_8723_00037_12
# 75104_8894_00028_8
# 75104_8894_00028_8
# 75104_8953_00014_24
# 75104_8953_00014_24
# 75104_8953_00017_7
# 75104_8953_00017_7
# 75104_9191_00019_21
# 75104_9191_00019_21
# 75104_9191_00019_5
# 75104_9191_00019_5
# 75104_9191_00031_11
# 75104_9191_00031_11
# 75104_9191_00043_30
# 75104_9191_00043_30
# 75104_9382_00008_124
# 75104_9382_00008_124
# 75104_9382_00013_22
# 75104_9382_00013_22
# 75104_9506_00023_164
# 75104_9506_00023_164
# 75104_9704_00011_3
# 75104_9704_00011_3
# 75104_9704_00016_15
# 75104_9704_00016_15
# 75104_9704_00054_11
# 75104_9704_00054_11
# 75104_9704_00065_45
# 75104_9704_00065_45
# 75104_9783_00011_8
# 75104_9783_00011_8
# 75104_9783_00016_10
# 75104_9783_00016_10
# 75104_9783_00022_14
# 75104_9783_00022_14
# 75105_0052_00002_205
# 75105_0052_00002_205
# 75105_0896_00014_2
# 75105_0896_00014_2
# 75105_0896_00024_48
# 75105_0896_00024_48
# 75105_0964_00005_2
# 75105_0964_00005_2
# 75105_1001_00002_13
# 75105_1001_00002_13
# 75105_1001_00007_15
# 75105_1001_00007_15
# 75105_1156_00022_114
# 75105_1156_00022_114
# 75105_1156_00030_4
# 75105_1156_00030_4
# 75105_1313_00012_7
# 75105_1313_00012_7
# 75105_1313_00036_45
# 75105_1313_00036_45
# 75105_1313_00042_12
# 75105_1313_00042_12
# 75105_1543_00005_17
# 75105_1543_00005_17
# 75105_1545_00038_32
# 75105_1545_00038_32
# 75105_1545_00053_17
# 75105_1545_00053_17
# 75105_1545_00053_17
# 75105_1545_00068_30
# 75105_1545_00068_30
# 75105_1554_00012_11
# 75105_1554_00012_11
# 75105_1642_00024_126
# 75105_1642_00024_126
# 75105_1642_00026_2
# 75105_1642_00026_2
# 75105_1642_00049_12
# 75105_1642_00049_12
# 75105_1642_00049_4
# 75105_1642_00049_4
# 75105_2069_00035_7
# 75105_2069_00035_7
# 75105_2069_00037_4
# 75105_2069_00037_4
# 75105_2069_00063_102
# 75105_2069_00063_102
# 75105_2094_00005_225
# 75105_2094_00005_225
# 75105_2094_00030_102
# 75105_2094_00030_102
# 75105_2094_00035_3
# 75105_2094_00035_3
# 75105_2187_00009_8
# 75105_2187_00009_8
# 75105_2187_00025_9
# 75105_2187_00025_9
# 75105_2487_00013_4
# 75105_2487_00013_4
# 75105_2580_00005_30
# 75105_2580_00005_30
# 75105_2580_00007_42
# 75105_2580_00007_42
# 75105_2580_00022_4
# 75105_2580_00022_4
# 75105_2580_00023_50
# 75105_2580_00023_50
# 75105_2580_00028_33
# 75105_2580_00028_33
# 75105_2580_00036_9
# 75105_2580_00036_9
# 75105_2724_00040_11
# 75105_2724_00040_11
# 75105_2724_00042_117
# 75105_2724_00042_117
# 75105_2724_00042_134
# 75105_2724_00042_134
# 75105_2724_00045_21
# 75105_2724_00045_21
# 75105_3095_00016_3
# 75105_3095_00016_3
# 75105_3098_00020_37
# 75105_3098_00020_37
# 75105_3098_00030_17
# 75105_3098_00030_17
# 75105_3098_00038_21
# 75105_3098_00038_21
# 75105_3298_00013_1218
# 75105_3298_00013_1218
# 75105_3368_00005_53
# 75105_3368_00005_53
# 75105_3368_00007_32
# 75105_3368_00007_32
# 75105_3368_00009_33
# 75105_3368_00009_33
# 75105_3573_00036_18
# 75105_3573_00036_18
# 75105_3573_00041_10
# 75105_3573_00041_10
# 75105_3665_00007_9
# 75105_3665_00007_9
# 75105_3747_00046_7
# 75105_3747_00046_7
# 75105_3749_00004_25
# 75105_3749_00004_25
# 75105_3751_00012_206
# 75105_3751_00012_206
# 75105_3848_00025_4
# 75105_3848_00025_4
# 75105_3921_00057_6
# 75105_3921_00057_6
# 75105_4108_00006_55
# 75105_4108_00006_55
# 75105_4108_00030_6
# 75105_4108_00030_6
# 75105_4209_00007_18
# 75105_4209_00007_18
# 75105_4209_00007_25
# 75105_4209_00007_25
# 75105_4209_00010_18
# 75105_4209_00010_18
# 75105_4209_00010_18
# 75105_4259_00003_26
# 75105_4259_00003_26
# 75105_4259_00010_17
# 75105_4259_00010_17
# 75105_4259_00039_4
# 75105_4259_00039_4
# 75105_4434_00008_125
# 75105_4434_00008_125
# 75105_4434_00010_10
# 75105_4434_00010_10
# 75105_4434_00010_17
# 75105_4475_00051_12
# 75105_4475_00051_12
# 75105_4475_00051_17
# 75105_4475_00051_17
# 75105_4649_00034_60
# 75105_4649_00034_60
# 75105_4649_00034_62
# 75105_4649_00034_62
# 75105_4649_00034_91
# 75105_4649_00034_91
# 75105_4661_00009_12
# 75105_4661_00009_12
# 75105_4877_00011_20
# 75105_4877_00011_20
# 75105_5129_00003_13
# 75105_5129_00003_13
# 75105_5220_00006_22
# 75105_5220_00006_22
# 75105_5220_00027_3
# 75105_5220_00027_3
# 75105_5362_00001_102
# 75105_5362_00001_102
# 75105_5362_00005_9
# 75105_5362_00005_9
# 75105_5479_00006_16
# 75105_5479_00006_16
# 75105_5479_00006_5
# 75105_5479_00006_5
# 75105_5648_00052_23
# 75105_5648_00052_23
# 75105_5648_00052_23
# 75105_5696_00015_228
# 75105_5696_00015_228
# 75105_5696_00015_341
# 75105_5696_00015_341
# 75105_5696_00035_6
# 75105_5696_00035_6
# 75105_5696_00045_129
# 75105_5696_00045_129
# 75105_5868_00018_114
# 75105_5868_00018_114
# 75105_5949_00005_406
# 75105_5949_00005_406
# 75105_5972_00001_42
# 75105_5972_00001_42
# 75105_5972_00002_5
# 75105_5972_00002_5
# 75105_6383_00002_28
# 75105_6383_00002_28
# 75105_6432_00012_42
# 75105_6432_00012_42
# 75105_6432_00029_6
# 75105_6432_00029_6
# 75105_6432_00068_22
# 75105_6432_00068_22
# 75105_6432_00077_16
# 75105_6432_00077_16
# 75105_6432_00084_5
# 75105_6432_00084_5
# 75105_6432_00093_62
# 75105_6432_00093_62
# 75105_6432_00099_54
# 75105_6432_00099_54
# 75105_6432_00111_20
# 75105_6432_00111_20
# 75105_6581_00022_3
# 75105_6581_00022_3
# 75105_6581_00122_171
# 75105_6581_00122_171
# 75105_6702_00005_15
# 75105_6702_00005_15
# 75105_6702_00008_81
# 75105_6702_00008_81
# 75105_6761_00003_15
# 75105_6761_00003_15
# 75105_7076_00011_47
# 75105_7076_00011_47
# 75105_7076_00014_28
# 75105_7076_00014_28
# 75105_7103_00014_11
# 75105_7103_00014_11
# 75105_7301_00010_12
# 75105_7301_00010_12
# 75105_7424_00022_30
# 75105_7424_00022_30
# 75105_7467_00011_8
# 75105_7467_00011_8
# 75105_7467_00035_31
# 75105_7467_00035_31
# 75105_7467_00041_16
# 75105_7467_00041_16
# 75105_7566_00033_15
# 75105_7566_00033_15
# 75105_7576_00046_112
# 75105_7576_00046_112
# 75105_7740_00058_11
# 75105_7740_00058_11
# 75105_7740_00070_153
# 75105_7740_00070_153
# 75105_7740_00070_153
# 75105_7740_00082_53
# 75105_7740_00082_53
# 75105_7740_00088_29
# 75105_7740_00088_29
# 75105_7740_00088_29
# 75105_7752_00018_13
# 75105_7752_00018_13
# 75105_7911_00010_1
# 75105_7911_00010_1
# 75105_7911_00010_30
# 75105_7911_00010_30
# 75105_8329_00007_6
# 75105_8329_00007_6
# 75105_8329_00018_17
# 75105_8329_00018_17
# 75105_8421_00012_4
# 75105_8421_00012_4
# 75105_8421_00016_32
# 75105_8421_00016_32
# 75105_8619_00011_49
# 75105_8619_00011_49
# 75105_8619_00015_96
# 75105_8619_00015_96
# 75105_8619_00074_6
# 75105_8619_00074_6
# 75105_8619_00074_9
# 75105_8619_00074_9
# 75105_8648_00187_11
# 75105_8648_00187_11
# 75105_8648_00247_187
# 75105_8648_00247_187
# 75105_8648_00314_12
# 75105_8648_00314_12
# 75105_8648_00314_12
# 75105_8648_00322_30
# 75105_8648_00322_30
# 75105_8648_00326_9
# 75105_8648_00326_9
# 75105_8690_00016_23
# 75105_8690_00016_23
# 75105_8690_00022_19
# 75105_8690_00022_19
# 75105_8690_00038_25
# 75105_8690_00038_25
# 75105_8690_00056_109
# 75105_8690_00056_109
# 75105_8690_00078_109
# 75105_8690_00078_109
# 75105_8705_00083_9
# 75105_8705_00083_9
# 75105_8705_00097_19
# 75105_8705_00097_19
# 75105_8705_00113_136
# 75105_8705_00113_136
# 75105_8760_00009_12
# 75105_8760_00009_12
# 75105_8760_00010_21
# 75105_8760_00010_21
# 75105_8760_00016_71
# 75105_8760_00016_71
# 75105_8884_00004_241
# 75105_8884_00004_241
# 75105_8884_00004_404
# 75105_8884_00004_404
# 75105_9544_00006_1
# 75105_9544_00006_1
# 75105_9544_00007_211
# 75105_9544_00007_211
# 75105_9544_00011_14
# 75105_9544_00011_14
# 75105_9544_00011_28
# 75105_9544_00011_28
# 75105_9751_00004_4
# 75105_9751_00004_4
# 75105_9751_00011_21
# 75105_9751_00011_21
# 75105_9975_00014_413
# 75105_9975_00014_413
# 75106_0002_00008_2
# 75106_0002_00008_2
# 75106_0002_00010_38
# 75106_0002_00010_38
# 75106_0010_00013_10
# 75106_0010_00013_10
# 75106_0010_00025_3
# 75106_0010_00025_3
# 75106_0010_00026_8
# 75106_0010_00026_8
# 75106_0010_00029_16
# 75106_0010_00029_16
# 75106_0499_00033_50
# 75106_0499_00033_50
# 75106_0499_00052_4
# 75106_0499_00052_4
# 75106_0499_00066_290
# 75106_0499_00066_290
# 75106_0499_00098_2
# 75106_0499_00098_2
# 75106_0499_00104_222
# 75106_0499_00104_222
# 75106_0499_00106_3
# 75106_0499_00106_3
# 75106_0499_00106_3
# 75106_0499_00126_25
# 75106_0499_00126_25
# 75106_0499_00130_20
# 75106_0499_00130_20
# 75106_0801_00006_10
# 75106_0801_00006_10
# 75106_0898_00009_35
# 75106_0898_00009_35
# 75106_1087_00006_40
# 75106_1087_00006_40
# 75106_1087_00007_30
# 75106_1087_00007_30
# 75106_1087_00064_118
# 75106_1087_00064_118
# 75106_1263_00011_11
# 75106_1263_00011_11
# 75106_1263_00027_12
# 75106_1263_00027_12
# 75106_1360_00015_21
# 75106_1360_00015_21
# 75106_1360_00032_110
# 75106_1360_00032_110
# 75106_1360_00032_110
# 75106_1486_00007_45
# 75106_1486_00007_45
# 75106_1591_00013_38
# 75106_1591_00013_38
# 75106_1591_00013_38
# 75106_1591_00016_7
# 75106_1591_00016_7
# 75106_1978_00042_7
# 75106_1978_00042_7
# 75106_1978_00044_39
# 75106_1978_00044_39
# 75106_1978_00058_48
# 75106_1978_00058_48
# 75106_1978_00058_90
# 75106_1978_00058_90
# 75106_1978_00066_22
# 75106_1978_00066_22
# 75106_1978_00073_24
# 75106_1978_00073_24
# 75106_1978_00106_7
# 75106_1978_00106_7
# 75106_1978_00109_8
# 75106_1978_00109_8
# 75106_1978_00117_13
# 75106_1978_00117_13
# 75106_1978_00117_7
# 75106_1978_00117_7
# 75106_2004_00005_35
# 75106_2004_00005_35
# 75106_2171_00007_48
# 75106_2171_00007_48
# 75106_2426_00004_6
# 75106_2426_00004_6
# 75106_2595_00016_24
# 75106_2595_00016_24
# 75106_2595_00020_64
# 75106_2595_00020_64
# 75106_2595_00024_86
# 75106_2595_00024_86
# 75106_2925_00017_8
# 75106_2925_00017_8
# 75106_2925_00019_59
# 75106_2925_00019_59
# 75106_2925_00022_28
# 75106_2925_00022_28
# 75106_2925_00038_113
# 75106_2925_00038_113
# 75106_3001_00013_8
# 75106_3001_00013_8
# 75106_3001_00017_9
# 75106_3001_00017_9
# 75106_3001_00019_3
# 75106_3001_00019_3
# 75106_3673_00021_6
# 75106_3673_00021_6
# 75106_3673_00023_6
# 75106_3673_00023_6
# 75106_3673_00025_3
# 75106_3673_00025_3
# 75106_3763_00010_22
# 75106_3763_00010_22
# 75106_3763_00028_266
# 75106_3763_00028_266
# 75106_3946_00010_30
# 75106_3946_00010_30
# 75106_4274_00011_16
# 75106_4274_00011_16
# 75106_4274_00011_28
# 75106_4274_00011_28
# 75106_4274_00013_17
# 75106_4274_00013_17
# 75106_4284_00037_104
# 75106_4284_00037_104
# 75106_4284_00055_251
# 75106_4284_00055_251
# 75106_4285_00003_1
# 75106_4285_00003_1
# 75106_4285_00003_133
# 75106_4285_00003_133
# 75106_4285_00017_38
# 75106_4285_00017_38
# 75106_4306_00017_14
# 75106_4306_00017_14
# 75106_4367_00021_5
# 75106_4367_00021_5
# 75106_4367_00035_24
# 75106_4367_00035_24
# 75106_4400_00008_8
# 75106_4400_00008_8
# 75106_4400_00008_8
# 75106_4400_00015_13
# 75106_4400_00015_13
# 75106_4442_00008_140
# 75106_4442_00008_140
# 75106_4442_00008_140
# 75106_4490_00001_22
# 75106_4490_00001_22
# 75106_4686_00002_18
# 75106_4686_00002_18
# 75106_4771_00008_16
# 75106_4771_00008_16
# 75106_4771_00008_19
# 75106_4771_00008_19
# 75106_4771_00011_46
# 75106_4771_00011_46
# 75106_4771_00018_6
# 75106_4771_00018_6
# 75106_4887_00014_27
# 75106_4887_00014_27
# 75106_5004_00007_9
# 75106_5004_00007_9
# 75106_5636_00023_1
# 75106_5636_00023_1
# 75106_6221_00017_34
# 75106_6221_00017_34
# 75106_6221_00020_5
# 75106_6221_00020_5
# 75106_6228_00027_34
# 75106_6228_00027_34
# 75106_6228_00037_15
# 75106_6228_00037_15
# 75106_6228_00052_14
# 75106_6228_00052_14
# 75106_6228_00072_22
# 75106_6228_00072_22
# 75106_6228_00076_5
# 75106_6228_00076_5
# 75106_6228_00076_9
# 75106_6228_00076_9
# 75106_6232_00008_2
# 75106_6232_00008_2
# 75106_6444_00034_3
# 75106_6444_00034_3
# 75106_6444_00052_12
# 75106_6444_00052_12
# 75106_6522_00011_109
# 75106_6522_00011_109
# 75106_6522_00043_20
# 75106_6522_00043_20
# 75106_6522_00071_17
# 75106_6522_00071_17
# 75106_6522_00101_117
# 75106_6522_00101_117
# 75106_6522_00135_5
# 75106_6522_00135_5
# 75106_6522_00153_36
# 75106_6522_00153_36
# 75106_6522_00157_42
# 75106_6522_00157_42
# 75106_6716_00002_6
# 75106_6716_00002_6
# 75106_6838_00077_202
# 75106_6838_00077_202
# 75106_6838_00117_319
# 75106_6838_00117_319
# 75106_6873_00009_11
# 75106_6873_00009_11
# 75106_6873_00013_26
# 75106_6873_00013_26
# 75106_6873_00013_26
# 75106_6873_00014_10
# 75106_6873_00014_10
# 75106_7610_00003_158
# 75106_7610_00003_158
# 75106_7610_00005_44
# 75106_7610_00005_44
# 75106_7837_00018_5
# 75106_7837_00018_5
# 75106_7837_00018_5
# 75106_7940_00010_5
# 75106_7940_00010_5
# 75106_7940_00010_5
# 75106_7989_00005_11
# 75106_7989_00005_11
# 75106_8045_00087_4
# 75106_8045_00087_4
# 75106_8092_00010_16
# 75106_8092_00010_16
# 75106_8092_00012_73
# 75106_8092_00012_73
# 75106_8092_00024_42
# 75106_8092_00024_42
# 75106_8151_00146_67
# 75106_8151_00146_67
# 75106_8151_00150_23
# 75106_8151_00150_23
# 75106_8151_00151_34
# 75106_8151_00151_34
# 75106_8151_00161_67
# 75106_8151_00161_67
# 75106_8484_00025_8
# 75106_8484_00025_8
# 75106_8484_00030_31
# 75106_8484_00030_31
# 75106_8484_00052_7
# 75106_8484_00052_7
# 75106_8484_00058_12
# 75106_8484_00058_12
# 75106_8619_00106_73
# 75106_8619_00106_73
# 75106_8619_00106_79
# 75106_8619_00106_79
# 75106_8653_00002_27
# 75106_8653_00002_27
# 75106_8653_00008_15
# 75106_8653_00008_15
# 75106_8705_00020_5
# 75106_8705_00020_5
# 75106_8705_00020_8
# 75106_8705_00020_8
# 75106_8705_00036_14
# 75106_8705_00036_14
# 75106_8735_00018_10
# 75106_8735_00018_10
# 75106_8742_00005_49
# 75106_8742_00005_49
# 75106_8742_00005_49
# 75106_8742_00020_5
# 75106_8742_00020_5
# 75106_8772_00030_7
# 75106_8772_00030_7
# 75106_8772_00038_114
# 75106_8772_00038_114
# 75106_8907_00001_29
# 75106_8907_00001_29
# 75106_8907_00005_3
# 75106_8907_00005_3
# 75106_8913_00020_54
# 75106_8913_00020_54
# 75106_8913_00033_11
# 75106_8913_00033_11
# 75106_8944_00011_22
# 75106_8944_00011_22
# 75106_8944_00012_11
# 75106_8944_00012_11
# 75106_8944_00014_49
# 75106_8944_00014_49
# 75106_8955_00005_19
# 75106_8955_00005_19
# 75106_8955_00045_60
# 75106_8955_00045_60
# 75106_8955_00079_9
# 75106_8955_00079_9
# 75106_8955_00125_17
# 75106_8955_00125_17
# 75106_8955_00137_4
# 75106_8955_00137_4
# 75106_8955_00137_8
# 75106_8955_00137_8
# 75106_8955_00139_28
# 75106_8955_00139_28
# 75106_9624_00029_6
# 75106_9624_00029_6
# 75106_9624_00080_103
# 75106_9624_00080_103
# 75106_9624_00118_1042
# 75106_9624_00118_1042
# 75106_9624_00128_29
# 75106_9624_00128_29
# 75106_9634_00012_11
# 75106_9634_00012_11
# 75106_9634_00023_1
# 75106_9634_00023_1
# 75106_9793_00008_77
# 75106_9793_00008_77
# 75106_9880_00005_7
# 75106_9880_00005_7
# 75106_9880_00007_38
# 75106_9880_00007_38
# 75107_0208_00001_34
# 75107_0208_00001_34
# 75107_0216_00008_11
# 75107_0216_00008_11
# 75107_0535_00008_12
# 75107_0535_00008_12
# 75107_0535_00009_4
# 75107_0535_00009_4
# 75107_0535_00016_14
# 75107_0535_00016_14
# 75107_0535_00024_5
# 75107_0535_00024_5
# 75107_0618_00044_4
# 75107_0618_00044_4
# 75107_0618_00045_4
# 75107_0618_00045_4
# 75107_0618_00051_11
# 75107_0618_00051_11
# 75107_0618_00068_16
# 75107_0618_00068_16
# 75107_0620_00034_73
# 75107_0620_00034_73
# 75107_0620_00042_38
# 75107_0620_00042_38
# 75107_0620_00076_17
# 75107_0620_00076_17
# 75107_0620_00134_69
# 75107_0620_00134_69
# 75107_0664_00016_80
# 75107_0664_00016_80
# 75107_0664_00030_46
# 75107_0664_00030_46
# 75107_0664_00042_17
# 75107_0664_00042_17
# 75107_0785_00012_25
# 75107_0785_00012_25
# 75107_0785_00022_19
# 75107_0785_00022_19
# 75107_0825_00029_112
# 75107_0825_00029_112
# 75107_0991_00007_221
# 75107_0991_00007_221
# 75107_1119_00032_3
# 75107_1119_00032_3
# 75107_1119_00043_23
# 75107_1119_00043_23
# 75107_1119_00069_33
# 75107_1119_00069_33
# 75107_1120_00009_54
# 75107_1120_00009_54
# 75107_1120_00015_60
# 75107_1120_00015_60
# 75107_1120_00025_101
# 75107_1120_00025_101
# 75107_1120_00030_12
# 75107_1120_00030_12
# 75107_1202_00031_32
# 75107_1202_00031_32
# 75107_1202_00052_46
# 75107_1202_00052_46
# 75107_1277_00028_26
# 75107_1277_00028_26
# 75107_1277_00033_38
# 75107_1277_00033_38
# 75107_1277_00055_9
# 75107_1277_00055_9
# 75107_1589_00015_5
# 75107_1589_00015_5
# 75107_1717_00031_17
# 75107_1717_00031_17
# 75107_1717_00037_11
# 75107_1717_00037_11
# 75107_1832_00041_27
# 75107_1832_00041_27
# 75107_1996_00013_43
# 75107_1996_00013_43
# 75107_1996_00031_11
# 75107_1996_00031_11
# 75107_2017_00007_31
# 75107_2017_00007_31
# 75107_2106_00003_19
# 75107_2106_00003_19
# 75107_2106_00019_28
# 75107_2106_00019_28
# 75107_2106_00030_23
# 75107_2106_00030_23
# 75107_2106_00036_100
# 75107_2106_00036_100
# 75107_2106_00038_14
# 75107_2106_00038_14
# 75107_2106_00056_36
# 75107_2106_00056_36
# 75107_2177_00007_129
# 75107_2177_00007_129
# 75107_2201_00009_11
# 75107_2201_00009_11
# 75107_2223_00021_25
# 75107_2223_00021_25
# 75107_3023_00015_23
# 75107_3023_00015_23
# 75107_3023_00039_7
# 75107_3023_00039_7
# 75107_3023_00039_7
# 75107_3045_00020_206
# 75107_3045_00020_206
# 75107_3065_00009_9
# 75107_3065_00009_9
# 75107_3065_00014_1
# 75107_3065_00014_1
# 75107_3065_00016_6
# 75107_3065_00016_6
# 75107_3065_00023_16
# 75107_3065_00023_16
# 75107_3203_00002_1
# 75107_3203_00002_1
# 75107_3217_00021_139
# 75107_3217_00021_139
# 75107_3477_00024_14
# 75107_3477_00024_14
# 75107_3477_00046_94
# 75107_3477_00046_94
# 75107_3818_00013_82
# 75107_3818_00013_82
# 75107_3818_00013_83
# 75107_3818_00013_83
# 75107_3818_00013_92
# 75107_3818_00013_92
# 75107_3818_00013_92
# 75107_4015_00010_111
# 75107_4015_00010_111
# 75107_4015_00022_30
# 75107_4015_00022_30
# 75107_4015_00022_30
# 75107_4314_00038_23
# 75107_4314_00038_23
# 75107_4314_00051_61
# 75107_4314_00051_61
# 75107_4314_00064_19
# 75107_4314_00064_19
# 75107_4314_00066_4
# 75107_4314_00066_4
# 75107_4314_00066_6
# 75107_4314_00066_6
# 75107_4314_00070_12
# 75107_4314_00070_12
# 75107_4314_00070_3
# 75107_4314_00070_3
# 75107_4314_00161_13
# 75107_4314_00161_13
# 75107_4314_00161_8
# 75107_4314_00161_8
# 75107_4314_00174_6
# 75107_4314_00174_6
# 75107_4314_00180_35
# 75107_4314_00180_35
# 75107_4314_00180_35
# 75107_4314_00187_44
# 75107_4314_00187_44
# 75107_4314_00187_44
# 75107_4314_00187_92
# 75107_4314_00187_92
# 75107_4314_00208_49
# 75107_4314_00208_49
# 75107_4348_00002_45
# 75107_4348_00002_45
# 75107_4726_00015_117
# 75107_4726_00015_117
# 75107_4726_00036_19
# 75107_4726_00036_19
# 75107_4726_00036_20
# 75107_4726_00036_20
# 75107_4935_00009_30
# 75107_4935_00009_30
# 75107_4935_00009_6
# 75107_4935_00009_6
# 75107_4935_00011_13
# 75107_4935_00011_13
# 75107_5002_00009_26
# 75107_5002_00009_26
# 75107_5202_00017_113
# 75107_5202_00017_113
# 75107_5202_00017_120
# 75107_5202_00017_120
# 75107_5202_00023_40
# 75107_5202_00023_40
# 75107_5202_00059_3
# 75107_5202_00059_3
# 75107_5202_00059_93
# 75107_5202_00059_93
# 75107_5202_00067_20
# 75107_5202_00067_20
# 75107_5202_00081_14
# 75107_5202_00081_14
# 75107_5202_00081_16
# 75107_5202_00081_16
# 75107_5308_00009_9
# 75107_5308_00009_9
# 75107_5308_00013_49
# 75107_5308_00013_49
# 75107_5308_00027_216
# 75107_5308_00027_216
# 75107_5308_00039_33
# 75107_5308_00039_33
# 75107_5366_00001_127
# 75107_5366_00001_127
# 75107_5383_00027_7
# 75107_5383_00027_7
# 75107_5686_00006_13
# 75107_5686_00006_13
# 75107_5686_00010_6
# 75107_5686_00010_6
# 75107_5686_00017_26
# 75107_5686_00017_26
# 75107_5686_00045_14
# 75107_5686_00045_14
# 75107_6160_00004_1231
# 75107_6160_00004_1231
# 75107_6535_00014_3
# 75107_6535_00014_3
# 75107_6535_00015_13
# 75107_6535_00015_13
# 75107_6535_00018_48
# 75107_6535_00018_48
# 75107_6952_00085_178
# 75107_6952_00085_178
# 75107_6952_00085_187
# 75107_6952_00085_187
# 75107_6971_00009_30
# 75107_6971_00009_30
# 75107_6971_00014_16
# 75107_6971_00014_16
# 75107_6971_00014_38
# 75107_6971_00014_38
# 75107_7451_00006_3
# 75107_7451_00006_3
# 75107_7451_00026_129
# 75107_7451_00026_129
# 75107_8045_00008_102
# 75107_8045_00008_102
# 75107_8045_00027_30
# 75107_8045_00027_30
# 75107_8400_00015_30
# 75107_8400_00015_30
# 75107_8400_00018_23
# 75107_8400_00018_23
# 75107_8400_00020_32
# 75107_8400_00020_32
# 75107_8400_00028_11
# 75107_8400_00028_11
# 75107_8529_00064_52
# 75107_8529_00064_52
# 75107_8529_00064_92
# 75107_8529_00064_92
# 75107_8529_00078_48
# 75107_8529_00078_48
# 75107_8529_00080_303
# 75107_8529_00080_303
# 75107_8529_00081_107
# 75107_8529_00081_107
# 75107_8529_00081_123
# 75107_8529_00081_123
# 75107_8529_00085_179
# 75107_8529_00085_179
# 75107_8529_00085_252
# 75107_8529_00085_252
# 75107_8529_00085_257
# 75107_8529_00085_257
# 75107_8529_00094_37
# 75107_8529_00094_37
# 75107_8529_00097_208
# 75107_8529_00097_208
# 75107_8529_00101_61
# 75107_8529_00101_61
# 75107_8529_00102_19
# 75107_8529_00102_19
# 75107_8529_00124_22
# 75107_8529_00124_22
# 75107_8529_00124_22
# 75107_8529_00125_7
# 75107_8529_00125_7
# 75107_8529_00133_195
# 75107_8529_00133_195
# 75107_8529_00133_22
# 75107_8529_00133_22
# 75107_8529_00133_229
# 75107_8529_00133_229
# 75107_8529_00133_8
# 75107_8529_00133_8
# 75107_8529_00145_76
# 75107_8529_00145_76
# 75107_8529_00149_19
# 75107_8529_00149_19
# 75107_8619_00189_16
# 75107_8619_00189_16
# 75107_8619_00196_22
# 75107_8619_00196_22
# 75107_8619_00214_17
# 75107_8619_00214_17
# 75107_8619_00276_90
# 75107_8619_00276_90
# 75107_8619_00276_92
# 75107_8619_00276_92
# 75107_8631_00019_47
# 75107_8631_00019_47
# 75107_8767_00036_4
# 75107_8767_00036_4
# 75107_8866_00037_208
# 75107_8866_00037_208
# 75107_8866_00042_129
# 75107_8866_00042_129
# 75107_8903_00009_30
# 75107_8903_00009_30
# 75107_8903_00011_17
# 75107_8903_00011_17
# 75107_8955_00054_7
# 75107_8955_00054_7
# 75107_9114_00007_14
# 75107_9114_00007_14
# 75107_9114_00049_17
# 75107_9114_00049_17
# 75107_9127_00031_5
# 75107_9127_00031_5
# 75107_9393_00019_7
# 75107_9393_00019_7
# 75107_9393_00027_8
# 75107_9393_00027_8
# 75107_9527_00012_32
# 75107_9527_00012_32
# 75107_9527_00036_14
# 75107_9527_00036_14
# 75107_9527_00036_31
# 75107_9527_00036_31
# 75107_9527_00086_91
# 75107_9527_00086_91
# 75107_9527_00149_20
# 75107_9527_00149_20
# 75107_9527_00164_10
# 75107_9527_00164_10
# 75107_9527_00171_17
# 75107_9527_00171_17
# 75107_9527_00193_176
# 75107_9527_00193_176
# 75107_9542_00005_8
# 75107_9542_00005_8
# 75107_9588_00041_20
# 75107_9588_00041_20
# 75107_9588_00050_26
# 75107_9588_00050_26
# 75107_9597_00048_17
# 75107_9597_00048_17
# 75107_9691_00011_26
# 75107_9691_00011_26
# 75107_9691_00011_31
# 75107_9691_00011_31
# 75107_9691_00018_11
# 75107_9691_00018_11
# 75107_9691_00020_22
# 75107_9691_00020_22
# 75107_9691_00020_79
# 75107_9691_00020_79
# 75107_9691_00029_8
# 75107_9691_00029_8
# 75107_9691_00035_23
# 75107_9691_00035_23
# 75107_9691_00035_23
# 75107_9691_00046_63
# 75107_9691_00046_63
# 75107_9691_00054_126
# 75107_9691_00054_126
# 75107_9691_00056_60
# 75107_9691_00056_60
# 75107_9691_00060_87
# 75107_9691_00060_87
# 75107_9911_00017_16
# 75107_9911_00017_16
# 75108_0179_00006_1
# 75108_0179_00006_1
# 75108_0300_00069_8
# 75108_0300_00069_8
# 75108_0351_00003_19
# 75108_0351_00003_19
# 75108_0487_00008_20
# 75108_0487_00008_20
# 75108_0487_00008_22
# 75108_0487_00008_22
# 75108_0487_00046_28
# 75108_0487_00046_28
# 75108_0652_00008_34
# 75108_0652_00008_34
# 75108_0719_00021_17
# 75108_0719_00021_17
# 75108_0719_00023_24
# 75108_0719_00023_24
# 75108_0719_00023_34
# 75108_0719_00023_34
# 75108_0719_00023_43
# 75108_0719_00023_43
# 75108_0719_00023_59
# 75108_0719_00023_59
# 75108_0719_00029_26
# 75108_0719_00029_26
# 75108_0779_00012_51
# 75108_0779_00012_51
# 75108_0779_00040_29
# 75108_0779_00040_29
# 75108_0900_00006_15
# 75108_0900_00006_15
# 75108_0900_00017_20
# 75108_0900_00017_20
# 75108_0900_00027_8
# 75108_0900_00027_8
# 75108_0904_00050_60
# 75108_0904_00050_60
# 75108_0904_00050_60
# 75108_1081_00031_37
# 75108_1081_00031_37
# 75108_1081_00031_39
# 75108_1081_00031_39
# 75108_1081_00031_39
# 75108_1081_00043_6
# 75108_1081_00043_6
# 75108_1443_00019_11
# 75108_1443_00019_11
# 75108_1701_00004_12
# 75108_1701_00004_12
# 75108_1701_00007_7
# 75108_1701_00007_7
# 75108_1701_00007_7
# 75108_1914_00011_405
# 75108_1914_00011_405
# 75108_1955_00004_19
# 75108_1955_00004_19
# 75108_2049_00021_12
# 75108_2049_00021_12
# 75108_2067_00011_13
# 75108_2067_00011_13
# 75108_2067_00017_13
# 75108_2067_00017_13
# 75108_2185_00022_10
# 75108_2185_00022_10
# 75108_2289_00005_6
# 75108_2289_00005_6
# 75108_2289_00024_14
# 75108_2289_00024_14
# 75108_2289_00026_20
# 75108_2289_00026_20
# 75108_2289_00026_6
# 75108_2289_00026_6
# 75108_2289_00026_9
# 75108_2289_00026_9
# 75108_2306_00010_55
# 75108_2306_00010_55
# 75108_2386_00033_20
# 75108_2386_00033_20
# 75108_2386_00065_61
# 75108_2386_00065_61
# 75108_2386_00087_27
# 75108_2386_00087_27
# 75108_2387_00041_12
# 75108_2387_00041_12
# 75108_2576_00014_103
# 75108_2576_00014_103
# 75108_3118_00023_9
# 75108_3118_00023_9
# 75108_3118_00028_117
# 75108_3118_00028_117
# 75108_3518_00157_101
# 75108_3518_00157_101
# 75108_3518_00161_8
# 75108_3518_00161_8
# 75108_3518_00164_200
# 75108_3518_00164_200
# 75108_3518_00235_6
# 75108_3518_00235_6
# 75108_3518_00235_6
# 75108_3518_00268_10
# 75108_3518_00268_10
# 75108_3518_00268_11
# 75108_3518_00268_11
# 75108_3682_00009_113
# 75108_3682_00009_113
# 75108_3824_00005_20
# 75108_3824_00005_20
# 75108_4041_00003_35
# 75108_4041_00003_35
# 75108_4110_00020_15
# 75108_4110_00020_15
# 75108_4110_00032_160
# 75108_4110_00032_160
# 75108_4110_00032_170
# 75108_4110_00032_170
# 75108_4110_00032_187
# 75108_4110_00032_187
# 75108_4110_00036_47
# 75108_4110_00036_47
# 75108_4110_00038_138
# 75108_4110_00038_138
# 75108_4110_00038_154
# 75108_4110_00038_154
# 75108_4485_00101_9
# 75108_4485_00101_9
# 75108_4897_00018_111
# 75108_4897_00018_111
# 75108_4921_00018_37
# 75108_4921_00018_37
# 75108_4921_00036_5
# 75108_4921_00036_5
# 75108_5020_00003_328
# 75108_5020_00003_328
# 75108_5194_00104_29
# 75108_5194_00104_29
# 75108_5200_00004_63
# 75108_5200_00004_63
# 75108_5200_00004_73
# 75108_5200_00004_73
# 75108_5200_00004_80
# 75108_5200_00004_80
# 75108_5200_00010_83
# 75108_5200_00010_83
# 75108_5300_00017_6
# 75108_5300_00017_6
# 75108_5388_00019_65
# 75108_5388_00019_65
# 75108_5415_00005_19
# 75108_5415_00005_19
# 75108_5415_00005_19
# 75108_5692_00014_240
# 75108_5692_00014_240
# 75108_5741_00058_27
# 75108_5741_00058_27
# 75108_5751_00011_42
# 75108_5751_00011_42
# 75108_5951_00036_20
# 75108_5951_00036_20
# 75108_5951_00037_57
# 75108_5951_00037_57
# 75108_5951_00077_170
# 75108_5951_00077_170
# 75108_5951_00082_24
# 75108_5951_00082_24
# 75108_5951_00082_39
# 75108_5951_00082_39
# 75108_5951_00082_45
# 75108_5951_00082_45
# 75108_5951_00097_65
# 75108_5951_00097_65
# 75108_5993_00007_11
# 75108_5993_00007_11
# 75108_5993_00018_18
# 75108_5993_00018_18
# 75108_5993_00018_31
# 75108_5993_00018_31
# 75108_5993_00025_14
# 75108_5993_00025_14
# 75108_5993_00025_41
# 75108_5993_00025_41
# 75108_5993_00025_43
# 75108_5993_00025_43
# 75108_5993_00025_52
# 75108_5993_00025_52
# 75108_5993_00029_147
# 75108_5993_00029_147
# 75108_6176_00057_11
# 75108_6176_00057_11
# 75108_6176_00057_29
# 75108_6176_00057_29
# 75108_6296_00010_175
# 75108_6296_00010_175
# 75108_6296_00010_180
# 75108_6296_00010_180
# 75108_6387_00004_25
# 75108_6387_00004_25
# 75108_6387_00018_23
# 75108_6387_00018_23
# 75108_6387_00063_5
# 75108_6387_00063_5
# 75108_6387_00078_26
# 75108_6387_00078_26
# 75108_6387_00081_24
# 75108_6387_00081_24
# 75108_6387_00086_98
# 75108_6387_00086_98
# 75108_6387_00096_78
# 75108_6387_00096_78
# 75108_6419_00007_4
# 75108_6419_00007_4
# 75108_6419_00066_46
# 75108_6419_00066_46
# 75108_6450_00008_666
# 75108_6450_00008_666
# 75108_6450_00026_5
# 75108_6450_00026_5
# 75108_6450_00028_55
# 75108_6450_00028_55
# 75108_6450_00028_55
# 75108_6573_00015_48
# 75108_6573_00015_48
# 75108_6573_00021_20
# 75108_6573_00021_20
# 75108_6573_00025_9
# 75108_6573_00025_9
# 75108_6573_00027_7
# 75108_6573_00027_7
# 75108_6573_00046_21
# 75108_6573_00046_21
# 75108_6645_00022_16
# 75108_6645_00022_16
# 75108_6645_00022_16
# 75108_6675_00014_7
# 75108_6675_00014_7
# 75108_7082_00032_14
# 75108_7082_00032_14
# 75108_7237_00022_97
# 75108_7237_00022_97
# 75108_7237_00034_114
# 75108_7237_00034_114
# 75108_7237_00038_46
# 75108_7237_00038_46
# 75108_7237_00038_47
# 75108_7237_00038_47
# 75108_7612_00027_46
# 75108_7612_00027_46
# 75108_7612_00028_12
# 75108_7612_00028_12
# 75108_7612_00045_10
# 75108_7612_00045_10
# 75108_7612_00045_6
# 75108_7612_00045_6
# 75108_7954_00001_9
# 75108_7954_00001_9
# 75108_8256_00003_22
# 75108_8256_00003_22
# 75108_8256_00003_8
# 75108_8256_00003_8
# 75108_8256_00005_22
# 75108_8256_00005_22
# 75108_8256_00006_18
# 75108_8256_00006_18
# 75108_8256_00006_23
# 75108_8256_00006_23
# 75108_8291_00012_56
# 75108_8291_00012_56
# 75108_8291_00014_8
# 75108_8291_00014_8
# 75108_8291_00021_154
# 75108_8291_00021_154
# 75108_8291_00033_20
# 75108_8291_00033_20
# 75108_8291_00033_20
# 75108_8291_00033_22
# 75108_8291_00033_22
# 75108_8291_00051_45
# 75108_8291_00051_45
# 75108_8291_00060_11
# 75108_8291_00060_11
# 75108_8291_00062_15
# 75108_8291_00062_15
# 75108_8291_00070_25
# 75108_8291_00070_25
# 75108_8291_00081_21
# 75108_8291_00081_21
# 75108_8339_00068_26
# 75108_8339_00068_26
# 75108_8339_00082_8
# 75108_8339_00082_8
# 75108_8843_00005_12
# 75108_8843_00005_12
# 75108_9129_00035_15
# 75108_9129_00035_15
# 75108_9185_00024_16
# 75108_9185_00024_16
# 75108_9185_00024_44
# 75108_9185_00024_44
# 75108_9470_00002_40
# 75108_9470_00002_40
# 75108_9470_00002_40
# 75108_9470_00018_9
# 75108_9470_00018_9
# 75108_9470_00025_25
# 75108_9470_00025_25
# 75108_9510_00006_18
# 75108_9510_00006_18
# 75108_9723_00006_11
# 75108_9723_00006_11
# 75108_9723_00006_7
# 75108_9723_00006_7
# 75108_9723_00006_9
# 75108_9723_00006_9
# 75108_9723_00016_19
# 75108_9723_00016_19
# 75108_9785_00005_35
# 75108_9785_00005_35
# 75108_9804_00015_12
# 75108_9804_00015_12
# 75108_9830_00024_5
# 75108_9830_00024_5
# ...
# 75120_4553_00004_28
# 75120_4553_00004_28
# 75120_4553_00005_20
# 75120_4553_00005_20
# 75120_4553_00007_11
# 75120_4553_00007_11
# 75120_4581_00008_28
# 75120_4581_00008_28
# 75120_4581_00020_2
# 75120_4581_00020_2
# 75120_4581_00020_6
# 75120_4581_00020_6
# 75120_4581_00024_146
# 75120_4581_00024_146
# 75120_4672_00017_30
# 75120_4672_00017_30
# 75120_4704_00007_2
# 75120_4704_00007_2
# 75120_5035_00007_18
# 75120_5035_00007_18
# 75120_5046_00003_15
# 75120_5046_00003_15
# 75120_5046_00004_12
# 75120_5046_00004_12
# 75120_5046_00005_102
# 75120_5046_00005_102
# 75120_5046_00009_16
# 75120_5046_00009_16
# 75120_5046_00009_3
# 75120_5046_00009_3
# 75120_5046_00012_19
# 75120_5046_00012_19
# 75120_5077_00004_25
# 75120_5077_00004_25
# 75120_5077_00004_25
# 75120_5077_00012_17
# 75120_5077_00012_17
# 75120_5112_00008_59
# 75120_5112_00008_59
# 75120_5112_00011_3
# 75120_5112_00011_3
# 75120_5112_00021_2601
# 75120_5112_00021_2601
# 75120_5112_00037_22
# 75120_5112_00037_22
# 75120_5112_00038_33
# 75120_5112_00038_33
# 75120_5112_00057_87
# 75120_5112_00057_87
# 75120_5112_00103_23
# 75120_5112_00103_23
# 75120_5134_00010_102
# 75120_5134_00010_102
# 75120_5134_00040_135
# 75120_5134_00040_135
# 75120_5134_00040_141
# 75120_5134_00040_141
# 75120_5134_00040_262
# 75120_5134_00040_262
# 75120_5134_00040_55
# 75120_5134_00040_55
# 75120_5134_00040_59
# 75120_5134_00040_59
# 75120_5134_00040_67
# 75120_5134_00040_67
# 75120_5134_00050_111
# 75120_5134_00050_111
# 75120_5134_00050_132
# 75120_5134_00050_132
# 75120_5134_00050_54
# 75120_5134_00050_54
# 75120_5266_00002_17
# 75120_5266_00002_17
# 75120_5266_00011_169
# 75120_5266_00011_169
# 75120_5266_00011_3
# 75120_5266_00011_3
# 75120_5266_00042_47
# 75120_5266_00042_47
# 75120_5266_00077_11
# 75120_5266_00077_11
# 75120_5266_00077_58
# 75120_5266_00077_58
# 75120_5266_00077_61
# 75120_5266_00077_61
# 75120_5266_00083_11
# 75120_5266_00083_11
# 75120_5266_00087_103
# 75120_5266_00087_103
# 75120_5266_00104_11
# 75120_5266_00104_11
# 75120_5435_00023_16
# 75120_5435_00023_16
# 75120_5435_00023_16
# 75120_5435_00026_50
# 75120_5435_00026_50
# 75120_5612_00006_15
# 75120_5612_00006_15
# 75120_5612_00011_131
# 75120_5612_00011_131
# 75120_5612_00026_16
# 75120_5612_00026_16
# 75120_5638_00018_62
# 75120_5638_00018_62
# 75120_5659_00001_13
# 75120_5659_00001_13
# 75120_5659_00001_13
# 75120_5659_00001_14
# 75120_5659_00001_14
# 75120_5659_00001_14
# 75120_5659_00001_16
# 75120_5659_00001_16
# 75120_5659_00008_6
# 75120_5659_00008_6
# 75120_5669_00004_105
# 75120_5669_00004_105
# 75120_5679_00026_12
# 75120_5679_00026_12
# 75120_5703_00011_11
# 75120_5703_00011_11
# 75120_5703_00011_6
# 75120_5703_00011_6
# 75120_5985_00018_237
# 75120_5985_00018_237
# 75120_5985_00060_6
# 75120_5985_00060_6
# 75120_5985_00068_13
# 75120_5985_00068_13
# 75120_5985_00073_28
# 75120_5985_00073_28
# 75120_5985_00084_24
# 75120_5985_00084_24
# 75120_5985_00091_10
# 75120_5985_00091_10
# 75120_5985_00102_18
# 75120_5985_00102_18
# 75120_5985_00102_32
# 75120_5985_00102_32
# 75120_5985_00104_1
# 75120_5985_00104_1
# 75120_5985_00104_6
# 75120_5985_00104_6
# 75120_6039_00006_17
# 75120_6039_00006_17
# 75120_6039_00008_59
# 75120_6039_00008_59
# 75120_6039_00032_15
# 75120_6039_00032_15
# 75120_6039_00040_60
# 75120_6039_00040_60
# 75120_6039_00046_24
# 75120_6039_00046_24
# 75120_6039_00078_19
# 75120_6039_00078_19
# 75120_6116_00029_649
# 75120_6116_00029_649
# 75120_6116_00035_2722
# 75120_6116_00035_2722
# 75120_6116_00038_6
# 75120_6116_00038_6
# 75120_6137_00006_61
# 75120_6137_00006_61
# 75120_6143_00004_18
# 75120_6143_00004_18
# 75120_6267_00022_11
# 75120_6267_00022_11
# 75120_6267_00074_9
# 75120_6267_00074_9
# 75120_6267_00080_101
# 75120_6267_00080_101
# 75120_6267_00080_103
# 75120_6267_00080_103
# 75120_6267_00080_105
# 75120_6267_00080_105
# 75120_6267_00084_28
# 75120_6267_00084_28
# 75120_6267_00108_47
# 75120_6267_00108_47
# 75120_6267_00146_43
# 75120_6267_00146_43
# 75120_6270_00014_9
# 75120_6270_00014_9
# 75120_6270_00026_36
# 75120_6270_00026_36
# 75120_6270_00040_27
# 75120_6270_00040_27
# 75120_6270_00042_35
# 75120_6270_00042_35
# 75120_6270_00042_46
# 75120_6270_00042_46
# 75120_6270_00050_13
# 75120_6270_00050_13
# 75120_6270_00050_154
# 75120_6270_00050_154
# 75120_6270_00050_60
# 75120_6270_00050_60
# 75120_6270_00055_9
# 75120_6270_00055_9
# 75120_6270_00070_23
# 75120_6270_00070_23
# 75120_6270_00093_10
# 75120_6270_00093_10
# 75120_6270_00100_16
# 75120_6270_00100_16
# 75120_6270_00103_15
# 75120_6270_00103_15
# 75120_6270_00103_31
# 75120_6270_00103_31
# 75120_6270_00112_28
# 75120_6270_00112_28
# 75120_6270_00116_25
# 75120_6270_00116_25
# 75120_6270_00124_9
# 75120_6270_00124_9
# 75120_6270_00137_9
# 75120_6270_00137_9
# 75120_6270_00143_36
# 75120_6270_00143_36
# 75120_6270_00153_112
# 75120_6270_00153_112
# 75120_6270_00155_25
# 75120_6270_00155_25
# 75120_6270_00157_2329
# 75120_6270_00157_2329
# 75120_6301_00005_47
# 75120_6301_00005_47
# 75120_6475_00004_3
# 75120_6475_00004_3
# 75120_6475_00005_21
# 75120_6475_00005_21
# 75120_6475_00009_9
# 75120_6475_00009_9
# 75120_6503_00023_108
# 75120_6503_00023_108
# 75120_6503_00026_3
# 75120_6503_00026_3
# 75120_6610_00048_33
# 75120_6610_00048_33
# 75120_6610_00048_33
# 75120_6856_00002_340
# 75120_6856_00002_340
# 75120_6891_00051_12
# 75120_6891_00051_12
# 75120_6891_00051_15
# 75120_6891_00051_15
# 75120_6891_00051_15
# 75120_6891_00058_1003
# 75120_6891_00058_1003
# 75120_6891_00058_1028
# 75120_6891_00058_1028
# 75120_6891_00067_13
# 75120_6891_00067_13
# 75120_6924_00011_20
# 75120_6924_00011_20
# 75120_6924_00020_133
# 75120_6924_00020_133
# 75120_6924_00031_6
# 75120_6924_00031_6
# 75120_6924_00046_12
# 75120_6924_00046_12
# 75120_6924_00050_36
# 75120_6924_00050_36
# 75120_6924_00051_77
# 75120_6924_00051_77
# 75120_6924_00059_29
# 75120_6924_00059_29
# 75120_6924_00099_4
# 75120_6924_00099_4
# 75120_6924_00103_173
# 75120_6924_00103_173
# 75120_6958_00004_116
# 75120_6958_00004_116
# 75120_6958_00042_11
# 75120_6958_00042_11
# 75120_6958_00071_13
# 75120_6958_00071_13
# 75120_6958_00090_31
# 75120_6958_00090_31
# 75120_7032_00018_11
# 75120_7032_00018_11
# 75120_7032_00018_11
# 75120_7032_00025_8
# 75120_7032_00025_8
# 75120_7228_00004_125
# 75120_7228_00004_125
# 75120_7228_00017_162
# 75120_7228_00017_162
# 75120_7228_00017_166
# 75120_7228_00017_166
# 75120_7228_00017_218
# 75120_7228_00017_218
# 75120_7228_00017_221
# 75120_7228_00017_221
# 75120_7228_00020_9
# 75120_7228_00020_9
# 75120_7228_00023_409
# 75120_7228_00023_409
# 75120_7228_00032_15
# 75120_7228_00032_15
# 75120_7228_00034_13
# 75120_7228_00034_13
# 75120_7228_00060_31
# 75120_7228_00060_31
# 75120_7228_00068_24
# 75120_7228_00068_24
# 75120_7228_00068_26
# 75120_7228_00068_26
# 75120_7228_00074_7
# 75120_7228_00074_7
# 75120_7228_00074_7
# 75120_7228_00089_33
# 75120_7228_00089_33
# 75120_7228_00089_96
# 75120_7228_00089_96
# 75120_7228_00097_323
# 75120_7228_00097_323
# 75120_7228_00098_176
# 75120_7228_00098_176
# 75120_7228_00098_210
# 75120_7228_00098_210
# 75120_7228_00098_211
# 75120_7228_00098_211
# 75120_7228_00116_185
# 75120_7228_00116_185
# 75120_7228_00125_111
# 75120_7228_00125_111
# 75120_7228_00128_146
# 75120_7228_00128_146
# 75120_7228_00132_12
# 75120_7228_00132_12
# 75120_7228_00137_29
# 75120_7228_00137_29
# 75120_7228_00137_63
# 75120_7228_00137_63
# 75120_7228_00137_63
# 75120_7228_00154_27
# 75120_7228_00154_27
# 75120_7228_00163_39
# 75120_7228_00163_39
# 75120_7228_00163_41
# 75120_7228_00163_41
# 75120_7228_00186_1
# 75120_7228_00186_1
# 75120_7261_00009_24
# 75120_7261_00009_24
# 75120_7261_00011_6
# 75120_7261_00011_6
# 75120_7261_00011_7
# 75120_7261_00011_7
# 75120_7261_00013_15
# 75120_7261_00013_15
# 75120_7393_00051_529
# 75120_7393_00051_529
# 75120_7393_00053_107
# 75120_7393_00053_107
# 75120_7409_00001_105
# 75120_7409_00001_105
# 75120_7409_00007_702
# 75120_7409_00007_702
# 75120_7504_00057_11
# 75120_7504_00057_11
# 75120_7504_00057_14
# 75120_7504_00057_14
# 75120_7504_00059_155
# 75120_7504_00059_155
# 75120_7504_00062_3066
# 75120_7504_00062_3066
# 75120_7504_00062_3066
# 75120_7504_00067_12
# 75120_7504_00067_12
# 75120_7504_00070_118
# 75120_7504_00070_118
# 75120_7504_00084_37
# 75120_7504_00084_37
# 75120_7508_00017_305
# 75120_7508_00017_305
# 75120_7508_00017_305
# 75120_7508_00037_258
# 75120_7508_00037_258
# 75120_7512_00022_48
# 75120_7512_00022_48
# 75120_7512_00029_309
# 75120_7512_00029_309
# 75120_7512_00051_5
# 75120_7512_00051_5
# 75120_7512_00051_9
# 75120_7512_00051_9
# 75120_7512_00053_167
# 75120_7512_00053_167
# 75120_7512_00055_15
# 75120_7512_00055_15
# 75120_7512_00055_16
# 75120_7512_00055_16
# 75120_7512_00055_16
# 75120_7512_00064_217
# 75120_7512_00064_217
# 75120_7785_00027_283
# 75120_7785_00027_283
# 75120_7785_00028_54
# 75120_7785_00028_54
# 75120_7785_00031_251
# 75120_7785_00031_251
# 75120_7785_00041_120
# 75120_7785_00041_120
# 75120_7785_00043_222
# 75120_7785_00043_222
# 75120_7785_00044_3
# 75120_7785_00044_3
# 75120_7785_00062_13
# 75120_7785_00062_13
# 75120_7785_00070_95
# 75120_7785_00070_95
# 75120_7810_00011_23
# 75120_7810_00011_23
# 75120_7810_00014_634
# 75120_7810_00014_634
# 75120_7899_00022_15
# 75120_7899_00022_15
# 75120_7899_00028_4
# 75120_7899_00028_4
# 75120_7904_00043_4
# 75120_7904_00043_4
# 75120_7904_00044_28
# 75120_7904_00044_28
# 75120_7904_00050_14
# 75120_7904_00050_14
# 75120_7904_00054_11
# 75120_7904_00054_11
# 75120_7904_00055_11
# 75120_7904_00055_11
# 75120_7904_00055_120
# 75120_7904_00055_120
# 75120_7904_00055_120
# 75120_7904_00055_36
# 75120_7904_00055_36
# 75120_7904_00055_9
# 75120_7904_00055_9
# 75120_7904_00062_16
# 75120_7904_00062_16
# 75120_7904_00063_42
# 75120_7904_00063_42
# 75120_7904_00064_15
# 75120_7904_00064_15
# 75120_7904_00072_147
# 75120_7904_00072_147
# 75120_7904_00078_31
# 75120_7904_00078_31
# 75120_7904_00086_6
# 75120_7904_00086_6
# 75120_7904_00088_7
# 75120_7904_00088_7
# 75120_7904_00089_38
# 75120_7904_00089_38
# 75120_7904_00089_427
# 75120_7904_00089_427
# 75120_7904_00094_18
# 75120_7904_00094_18
# 75120_7904_00102_27
# 75120_7904_00102_27
# 75120_7904_00104_19
# 75120_7904_00104_19
# 75120_7904_00108_16
# 75120_7904_00108_16
# 75120_7904_00108_22
# 75120_7904_00108_22
# 75120_7904_00108_3
# 75120_7904_00108_3
# 75120_7904_00108_9
# 75120_7904_00108_9
# 75120_7904_00119_153
# 75120_7904_00119_153
# 75120_7904_00119_167
# 75120_7904_00119_167
# 75120_7904_00136_16
# 75120_7904_00136_16
# 75120_7904_00136_9
# 75120_7904_00136_9
# 75120_7904_00157_15
# 75120_7904_00157_15
# 75120_7904_00161_10
# 75120_7904_00161_10
# 75120_7904_00161_3
# 75120_7904_00161_3
# 75120_7904_00164_169
# 75120_7904_00164_169
# 75120_7904_00164_171
# 75120_7904_00164_171
# 75120_7904_00180_212
# 75120_7904_00180_212
# 75120_7904_00181_29
# 75120_7904_00181_29
# 75120_7904_00181_30
# 75120_7904_00181_30
# 75120_7904_00181_38
# 75120_7904_00181_38
# 75120_7904_00183_75
# 75120_7904_00183_75
# 75120_7904_00191_50
# 75120_7904_00191_50
# 75120_7904_00209_322
# 75120_7904_00209_322
# 75120_7904_00216_9
# 75120_7904_00216_9
# 75120_7904_00226_27
# 75120_7904_00226_27
# 75120_7904_00226_48
# 75120_7904_00226_48
# 75120_7904_00232_34
# 75120_7904_00232_34
# 75120_7904_00234_35
# 75120_7904_00234_35
# 75120_7904_00239_27
# 75120_7904_00239_27
# 75120_7904_00239_27
# 75120_7904_00243_22
# 75120_7904_00243_22
# 75120_7904_00249_15
# 75120_7904_00249_15
# 75120_7904_00249_6
# 75120_7904_00249_6
# 75120_7904_00252_108
# 75120_7904_00252_108
# 75120_7904_00261_18
# 75120_7904_00261_18
# 75120_7904_00262_191
# 75120_7904_00262_191
# 75120_7904_00262_4
# 75120_7904_00262_4
# 75120_7904_00265_10
# 75120_7904_00265_10
# 75120_7904_00269_14
# 75120_7904_00269_14
# 75120_7904_00269_9
# 75120_7904_00269_9
# 75120_7904_00271_14
# 75120_7904_00271_14
# 75120_7904_00271_21
# 75120_7904_00271_21
# 75120_7904_00271_22
# 75120_7904_00271_22
# 75120_7904_00271_7
# 75120_7904_00271_7
# 75120_7904_00271_8
# 75120_7904_00271_8
# 75120_7904_00283_1206
# 75120_7904_00283_1206
# 75120_7904_00283_1217
# 75120_7904_00283_1217
# 75120_7904_00284_32
# 75120_7904_00284_32
# 75120_7904_00285_63
# 75120_7904_00285_63
# 75120_7904_00288_7
# 75120_7904_00288_7
# 75120_7904_00289_25
# 75120_7904_00289_25
# 75120_7904_00299_11
# 75120_7904_00299_11
# 75120_7904_00304_23
# 75120_7904_00304_23
# 75120_7904_00330_24
# 75120_7904_00330_24
# 75120_7904_00333_34
# 75120_7904_00333_34
# 75120_7904_00333_42
# 75120_7904_00333_42
# 75120_7904_00340_11
# 75120_7904_00340_11
# 75120_7904_00340_5
# 75120_7904_00340_5
# 75120_7904_00343_13
# 75120_7904_00343_13
# 75120_7904_00343_21
# 75120_7904_00343_21
# 75120_7904_00350_205
# 75120_7904_00350_205
# 75120_7904_00350_207
# 75120_7904_00350_207
# 75120_7904_00395_113
# 75120_7904_00395_113
# 75120_8022_00029_2
# 75120_8022_00029_2
# 75120_8022_00040_6
# 75120_8022_00040_6
# 75120_8047_00037_35
# 75120_8047_00037_35
# 75120_8096_00018_2
# 75120_8096_00018_2
# 75120_8096_00018_2
# 75120_8156_00006_5
# 75120_8156_00006_5
# 75120_8156_00006_6
# 75120_8156_00006_6
# 75120_8156_00017_10
# 75120_8156_00017_10
# 75120_8156_00021_91
# 75120_8156_00021_91
# 75120_8172_00033_1
# 75120_8172_00033_1
# 75120_8180_00011_404
# 75120_8180_00011_404
# 75120_8180_00038_22
# 75120_8180_00038_22
# 75120_8180_00038_8
# 75120_8180_00038_8
# 75120_8180_00038_8
# 75120_8180_00041_25
# 75120_8180_00041_25
# 75120_8180_00043_7
# 75120_8180_00043_7
# 75120_8180_00043_7
# 75120_8180_00092_10
# 75120_8180_00092_10
# 75120_8180_00107_17
# 75120_8180_00107_17
# 75120_8180_00107_26
# 75120_8180_00107_26
# 75120_8232_00021_31
# 75120_8232_00021_31
# 75120_8232_00063_1
# 75120_8232_00063_1
# 75120_8232_00065_5
# 75120_8232_00065_5
# 75120_8232_00086_11
# 75120_8232_00086_11
# 75120_8275_00004_8
# 75120_8275_00004_8
# 75120_8345_00066_13
# 75120_8345_00066_13
# 75120_8503_00006_1011
# 75120_8503_00006_1011
# 75120_8503_00006_1011
# 75120_8503_00007_34
# 75120_8503_00007_34
# 75120_8503_00054_14
# 75120_8503_00054_14
# 75120_8503_00054_27
# 75120_8503_00054_27
# 75120_8503_00057_5
# 75120_8503_00057_5
# 75120_8503_00067_41
# 75120_8503_00067_41
# 75120_8503_00071_23
# 75120_8503_00071_23
# 75120_8503_00071_23
# 75120_8503_00071_57
# 75120_8503_00071_57
# 75120_8503_00071_76
# 75120_8503_00071_76
# 75120_8503_00071_79
# 75120_8503_00071_79
# 75120_8503_00071_86
# 75120_8503_00071_86
# 75120_8503_00072_18
# 75120_8503_00072_18
# 75120_8503_00078_15
# 75120_8503_00078_15
# 75120_8603_00003_38
# 75120_8603_00003_38
# 75120_8603_00028_219
# 75120_8603_00028_219
# 75120_8603_00028_232
# 75120_8603_00028_232
# 75120_8603_00039_1124
# 75120_8603_00039_1124
# 75120_8603_00039_320
# 75120_8603_00039_320
# 75120_8603_00039_358
# 75120_8603_00039_358
# 75120_8603_00051_9
# 75120_8603_00051_9
# 75120_8603_00058_11
# 75120_8603_00058_11
# 75120_8603_00058_3
# 75120_8603_00058_3
# 75120_8603_00063_252
# 75120_8603_00063_252
# 75120_8603_00083_34
# 75120_8603_00083_34
# 75120_9005_00015_9
# 75120_9005_00015_9
# 75120_9029_00003_103
# 75120_9029_00003_103
# 75120_9029_00010_20
# 75120_9029_00010_20
# 75120_9085_00001_128
# 75120_9085_00001_128
# 75120_9085_00007_2020
# 75120_9085_00007_2020
# 75120_9085_00016_10
# 75120_9085_00016_10
# 75120_9085_00016_6
# 75120_9085_00016_6
# 75120_9085_00016_70
# 75120_9085_00016_70
# 75120_9085_00016_72
# 75120_9085_00016_72
# 75120_9085_00016_72
# 75120_9085_00016_76
# 75120_9085_00016_76
# 75120_9085_00039_32
# 75120_9085_00039_32
# 75120_9085_00056_14
# 75120_9085_00056_14
# 75120_9086_00003_40
# 75120_9086_00003_40
# 75120_9086_00005_6
# 75120_9086_00005_6
# 75120_9086_00011_20
# 75120_9086_00011_20
# 75120_9132_00011_2029
# 75120_9132_00011_2029
# 75120_9132_00015_17
# 75120_9132_00015_17
# 75120_9132_00015_17
# 75120_9132_00034_8
# 75120_9132_00034_8
# 75120_9132_00037_201
# 75120_9132_00037_201
# 75120_9132_00037_206
# 75120_9132_00037_206
# 75120_9132_00037_218
# 75120_9132_00037_218
# 75120_9132_00038_18
# 75120_9132_00038_18
# 75120_9132_00058_13
# 75120_9132_00058_13
# 75120_9132_00058_4
# 75120_9132_00058_4
# 75120_9132_00058_6
# 75120_9132_00058_6
# 75120_9132_00058_9
# 75120_9132_00058_9
# 75120_9146_00003_8
# 75120_9146_00003_8
# 75120_9328_00022_23
# 75120_9328_00022_23
# 75120_9333_00006_79
# 75120_9333_00006_79
# 75120_9333_00007_21
# 75120_9333_00007_21
# 75120_9333_00007_6
# 75120_9333_00007_6
# 75120_9333_00013_14
# 75120_9333_00013_14
# 75120_9372_00004_21
# 75120_9372_00004_21
# 75120_9391_00045_37
# 75120_9391_00045_37
# 75120_9771_00002_15
# 75120_9771_00002_15
# 75120_9771_00012_29
# 75120_9771_00012_29
# 75120_9802_00032_22
# 75120_9802_00032_22
# 75120_9802_00032_9
# 75120_9802_00032_9
# 75120_9802_00059_16
# 75120_9802_00059_16
# 75120_9802_00063_11
# 75120_9802_00063_11
# 75120_9844_00016_48
# 75120_9844_00016_48
# 75120_9844_00038_6
# 75120_9844_00038_6
# 75120_9844_00042_43
# 75120_9844_00042_43
# 75120_9844_00042_60
# 75120_9844_00042_60
# 75120_9844_00051_6
# 75120_9844_00051_6
# 75120_9844_00067_8
# 75120_9844_00067_8
# 75120_9844_00069_4
# 75120_9844_00069_4
# 75120_9850_00009_119
# 75120_9850_00009_119
# 75120_9850_00009_89
# 75120_9850_00009_89
# 75120_9850_00037_80
# 75120_9850_00037_80
# 75120_9850_00039_71
# 75120_9850_00039_71
# 75120_9850_00041_76
# 75120_9850_00041_76
# 75120_9850_00043_19
# 75120_9850_00043_19
# 75120_9888_00033_301
# 75120_9888_00033_301
# 75120_9888_00033_85
# 75120_9888_00033_85
# 75120_9888_00046_2
# 75120_9888_00046_2
# 75120_9888_00084_104
# 75120_9888_00084_104
# 75120_9898_00055_22
# 75120_9898_00055_22

# %%
t["range_revente_first"].value_counts()
# Out:
# not first    10056
# first         9627
# Name: range_revente_first, dtype: int64

# %%
t.head()
# Out:
#                      etaban_lot  anneemut    valeurfonc range_revente_first
# idmutation
# 8269301      75101_0407_00049_4      2018 660000.000000           not first
# 8105917      75101_0407_00049_4      2019 853370.000000           not first
# 8439768      75101_0407_00049_5      2017 660000.000000               first
# 8119208      75101_0407_00049_5      2019 880000.000000           not first
# 8712767     75101_0407_00056_21      2015 200000.000000               first

# %%
# Renommer la valeur de "range_revente_first" en 1ère ligne du df pq elle a servi à la mise en place du compteur
# Elle était donc restée en "not first"

t["range_revente_first"].iloc[0]="first"
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# Calcul du pourcentage d'évolution de la valeur foncière, d'une ligne à l'autre

t["Evol_val"]=t["valeurfonc"].pct_change()

# %%
t.head()
# Out:
#                      etaban_lot  anneemut    valeurfonc range_revente_first  \
# idmutation
# 8269301      75101_0407_00049_4      2018 660000.000000               first
# 8105917      75101_0407_00049_4      2019 853370.000000           not first
# 8439768      75101_0407_00049_5      2017 660000.000000               first
# 8119208      75101_0407_00049_5      2019 880000.000000           not first
# 8712767     75101_0407_00056_21      2015 200000.000000               first
#
#             Evol_val
# idmutation
# 8269301          NaN
# 8105917     0.292985
# 8439768    -0.226596
# 8119208     0.333333
# 8712767    -0.772727

# %%
# Mise à 0 de la variable "Evol_val" pour le rang "first"

t["Evol_val"][t["range_revente_first"]=="first"]=0
# Out:
# C:\Users\Anne\AppData\Local\Temp/ipykernel_3380/2330405644.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t["Evol_val"][t["range_revente_first"]=="first"]=0

# %%
t.head()
# Out:
#                      etaban_lot  anneemut    valeurfonc range_revente_first  \
# idmutation
# 8269301      75101_0407_00049_4      2018 660000.000000               first
# 8105917      75101_0407_00049_4      2019 853370.000000           not first
# 8439768      75101_0407_00049_5      2017 660000.000000               first
# 8119208      75101_0407_00049_5      2019 880000.000000           not first
# 8712767     75101_0407_00056_21      2015 200000.000000               first
#
#             Evol_val
# idmutation
# 8269301     0.000000
# 8105917     0.292985
# 8439768     0.000000
# 8119208     0.333333
# 8712767     0.000000

# %%
# Réduction du dataframe t aux colonnes "range_revente_first" et "Evol_val"

t=t[["range_revente_first","Evol_val"]]

# %%
t
# Out:
#            range_revente_first  Evol_val
# idmutation
# 8269301                  first  0.000000
# 8105917              not first  0.292985
# 8439768                  first  0.000000
# 8119208              not first  0.333333
# 8712767                  first  0.000000
# ...                        ...       ...
# 7981775              not first  0.889474
# 8699817                  first  0.000000
# 8117120              not first  0.584366
# 8838640                  first  0.000000
# 8421910              not first  0.065357
#
# [19683 rows x 2 columns]

# %%
# Fusion des dataframes df_selec_2 et t par un merge left sur l'index "Idmutation"

df_selec_2=df_selec_2.merge(right=t, on="idmutation", how="left")

# %%
df_selec_2[["etaban_lot","anneemut","valeurfonc","range_revente_first", "Evol_val"]].sort_values(by=["etaban_lot","anneemut"])
# Out:
#                       etaban_lot  anneemut     valeurfonc range_revente_first  \
# idmutation
# 8817315     75101_0191_00003_110      2014  575700.000000                 NaN
# 8715762       75101_0191_00003_4      2015  442000.000000                 NaN
# 8449734      75101_0191_00005_14      2017  700000.000000                 NaN
# 8412777       75101_0191_00006_4      2017 1094000.000000                 NaN
# 8442593      75101_0191_00010_55      2017  789730.000000                 NaN
# ...                          ...       ...            ...                 ...
# 8565959      75120_9898_00055_27      2016  260000.000000                 NaN
# 8827580      75120_9898_00055_28      2014  400000.000000                 NaN
# 7979060       75120_9898_00077_3      2020  325000.000000                 NaN
# 7862739       75120_9898_00077_5      2021  495900.000000                 NaN
# 8125836       75120_9898_00077_6      2019  282000.000000                 NaN
#
#             Evol_val
# idmutation
# 8817315          NaN
# 8715762          NaN
# 8449734          NaN
# 8412777          NaN
# 8442593          NaN
# ...              ...
# 8565959          NaN
# 8827580          NaN
# 7979060          NaN
# 7862739          NaN
# 8125836          NaN
#
# [105240 rows x 5 columns]

# %%
# Pour les biens qui n'ont pas été revendus pendant la période, nous allons établir une valeur estimée à partir
# du prix au m² standardisés des appartements à Paris au 4e trimestre 2021
# https://paris.notaires.fr/fr/carte-des-prix
df_selec_2.shape
# Out:
# (105240, 53)

# %%
df_selec_2.head()
# Out:
#                      etaban_lot  qty_of_mut  Revente     datemut  anneemut  \
# idmutation
# 7819809     75101_4901_00019_93           0        0  2021-06-04      2021
# 7819821     75117_5503_00103_24           0        0  2021-03-18      2021
# 7819822     75115_2521_00008_19           0        0  2021-11-12      2021
# 7819824     75118_2113_00110_19           1        1  2021-01-08      2021
# 8563148     75118_2113_00110_19           1        1  2016-09-09      2016
#
#             moismut  Immeuble_neuf    valeurfonc  nblot  nbcomm  ...  \
# idmutation                                                       ...
# 7819809           6              0 370000.000000      1       1  ...
# 7819821           3              0 451000.000000      1       1  ...
# 7819822          11              0 433000.000000      3       1  ...
# 7819824           1              0 561076.000000      1       1  ...
# 8563148           9              0 375980.000000      1       1  ...
#
#             adedpe202006_logtype_s_hab  adedpe202006_logtype_ch_type_inst  \
# idmutation
# 7819809                      75.000000                         individuel
# 7819821                      36.000000                         individuel
# 7819822                      49.000000                         individuel
# 7819824                     100.000000                         individuel
# 8563148                     100.000000                         individuel
#
#             adedpe202006_logtype_ecs_type_inst  \
# idmutation
# 7819809                             individuel
# 7819821                             individuel
# 7819822                             individuel
# 7819824                             individuel
# 8563148                             individuel
#
#             adedpe202006_logtype_mur_ep_mat_ext  \
# idmutation
# 7819809                                     NaN
# 7819821                                     NaN
# 7819822                                     NaN
# 7819824                                     NaN
# 8563148                                     NaN
#
#             adedpe202006_logtype_mur_mat_ext  \
# idmutation
# 7819809                        Mur en brique
# 7819821                        Mur en pierre
# 7819822                        Mur en pierre
# 7819824                        Mur en pierre
# 8563148                        Mur en pierre
#
#             adedpe202006_logtype_mur_pos_isol_ext  Commerces_bruyants  \
# idmutation
# 7819809                                       ITI                   1
# 7819821                                       ITI                   0
# 7819822                                       ITI                   0
# 7819824                                       ITI                   1
# 8563148                                       ITI                   1
#
#                      cat_valeur  range_revente_first  Evol_val
# idmutation
# 7819809     Entre 320 & 436k€ €                  NaN       NaN
# 7819821       Entre 436 & 600k€                  NaN       NaN
# 7819822     Entre 320 & 436k€ €                  NaN       NaN
# 7819824       Entre 436 & 600k€            not first  0.492303
# 8563148     Entre 320 & 436k€ €                first  0.000000
#
# [5 rows x 53 columns]

# %%
# Extraction en CSV de la page 10 de ce document : https://notairesdugrandparis.fr/sites/default/files/Prix%20T4%202021_0.pdf
prix_notaire=pd.read_csv("Carte_prix_notaires_idf.csv",sep=";", encoding= 'unicode_escape')
prix_notaire
# Out:
#     l_codinsee  Estimation_prix_m2
# 0        75101               13560
# 1        75102               12020
# 2        75103               12780
# 3        75104               12770
# 4        75105               12340
# 5        75106               13980
# 6        75107               13300
# 7        75108               11810
# 8        75109               10800
# 9        75110               10050
# 10       75111               10510
# 11       75112                9690
# 12       75113                9230
# 13       75114               10060
# 14       75115               10100
# 15       75116               10810
# 16       75117               10450
# 17       75118                9750
# 18       75119                8940
# 19       75120                9330

# %%
# Fusion des dataframes df_selec_2 et du prix_notaire par un merge left sur l'index "idmutation"

df_selec_2=df_selec_2.reset_index().merge(prix_notaire, on="l_codinsee", how="left").set_index('idmutation')

# %%
df_selec_2.head()
# Out:
#                      etaban_lot  qty_of_mut  Revente     datemut  anneemut  \
# idmutation
# 7819809     75101_4901_00019_93           0        0  2021-06-04      2021
# 7819821     75117_5503_00103_24           0        0  2021-03-18      2021
# 7819822     75115_2521_00008_19           0        0  2021-11-12      2021
# 7819824     75118_2113_00110_19           1        1  2021-01-08      2021
# 8563148     75118_2113_00110_19           1        1  2016-09-09      2016
#
#             moismut  Immeuble_neuf    valeurfonc  nblot  nbcomm  ...  \
# idmutation                                                       ...
# 7819809           6              0 370000.000000      1       1  ...
# 7819821           3              0 451000.000000      1       1  ...
# 7819822          11              0 433000.000000      3       1  ...
# 7819824           1              0 561076.000000      1       1  ...
# 8563148           9              0 375980.000000      1       1  ...
#
#             adedpe202006_logtype_ch_type_inst  \
# idmutation
# 7819809                            individuel
# 7819821                            individuel
# 7819822                            individuel
# 7819824                            individuel
# 8563148                            individuel
#
#             adedpe202006_logtype_ecs_type_inst  \
# idmutation
# 7819809                             individuel
# 7819821                             individuel
# 7819822                             individuel
# 7819824                             individuel
# 8563148                             individuel
#
#             adedpe202006_logtype_mur_ep_mat_ext  \
# idmutation
# 7819809                                     NaN
# 7819821                                     NaN
# 7819822                                     NaN
# 7819824                                     NaN
# 8563148                                     NaN
#
#             adedpe202006_logtype_mur_mat_ext  \
# idmutation
# 7819809                        Mur en brique
# 7819821                        Mur en pierre
# 7819822                        Mur en pierre
# 7819824                        Mur en pierre
# 8563148                        Mur en pierre
#
#             adedpe202006_logtype_mur_pos_isol_ext  Commerces_bruyants  \
# idmutation
# 7819809                                       ITI                   1
# 7819821                                       ITI                   0
# 7819822                                       ITI                   0
# 7819824                                       ITI                   1
# 8563148                                       ITI                   1
#
#                      cat_valeur  range_revente_first  Evol_val  \
# idmutation
# 7819809     Entre 320 & 436k€ €                  NaN       NaN
# 7819821       Entre 436 & 600k€                  NaN       NaN
# 7819822     Entre 320 & 436k€ €                  NaN       NaN
# 7819824       Entre 436 & 600k€            not first  0.492303
# 8563148     Entre 320 & 436k€ €                first  0.000000
#
#             Estimation_prix_m2
# idmutation
# 7819809                  13560
# 7819821                  10450
# 7819822                  10100
# 7819824                   9750
# 8563148                   9750
#
# [5 rows x 54 columns]

# %%
df_selec_2.shape
# Out:
# (105240, 54)

# %%
df_selec_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105240 entries, 7819809 to 8843172
# Data columns (total 54 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   etaban_lot                                   105240 non-null  object
#  1   qty_of_mut                                   105240 non-null  int64
#  2   Revente                                      105240 non-null  int64
#  3   datemut                                      105240 non-null  object
#  4   anneemut                                     105240 non-null  int64
#  5   moismut                                      105240 non-null  int64
#  6   Immeuble_neuf                                105240 non-null  int64
#  7   valeurfonc                                   105240 non-null  float64
#  8   nblot                                        105240 non-null  int64
#  9   nbcomm                                       105240 non-null  int64
#  10  l_codinsee                                   105240 non-null  int64
#  11  nblocapt                                     105240 non-null  int64
#  12  nblocdep                                     105240 non-null  int64
#  13  nbapt2pp                                     105240 non-null  int64
#  14  nbapt3pp                                     105240 non-null  int64
#  15  sbati                                        105240 non-null  int64
#  16  sbatapt                                      105240 non-null  int64
#  17  sbatact                                      105240 non-null  int64
#  18  sapt2pp                                      105240 non-null  int64
#  19  sapt3pp                                      105240 non-null  int64
#  20  scarrez                                      105240 non-null  float64
#  21  anarnc202012_nb_log                          105240 non-null  float64
#  22  anarnc202012_nb_lot_garpark                  105240 non-null  float64
#  23  anarnc202012_nb_lot_tertiaire                105240 non-null  float64
#  24  anarnc202012_nb_lot_tot                      105240 non-null  float64
#  25  adedpe202006_logtype_baie_type_vitrage       100317 non-null  object
#  26  adedpe202006_logtype_ch_gen_lib_princ        100676 non-null  object
#  27  adedpe202006_mean_class_conso_ener           101430 non-null  object
#  28  adedpe202006_mean_class_estim_ges            101430 non-null  object
#  29  adedpe202006_logtype_traversant              88022 non-null   object
#  30  adedpe202006_logtype_ecs_type_ener           99621 non-null   object
#  31  adedpe202006_logtype_perc_surf_vitree_ext    16956 non-null   float64
#  32  adedpe202006_logtype_ph_pos_isol             76553 non-null   object
#  33  adedpe202006_logtype_presence_balcon         18459 non-null   float64
#  34  adedpe202006_logtype_presence_climatisation  101410 non-null  float64
#  35  adedpe202006_logtype_type_batiment           101410 non-null  object
#  36  ancqpv201410_is_qpv                          105029 non-null  float64
#  37  cerffo2020_annee_construction                95770 non-null   object
#  38  cerffo2020_usage_niveau_1_txt                105240 non-null  object
#  39  cerffo2020_nb_log                            105240 non-null  int64
#  40  georad2020_alea                              105029 non-null  object
#  41  igntop202103_bat_hauteur                     105016 non-null  float64
#  42  mcumer202007_is_mer                          105029 non-null  float64
#  43  adedpe202006_logtype_s_hab                   101252 non-null  float64
#  44  adedpe202006_logtype_ch_type_inst            88371 non-null   object
#  45  adedpe202006_logtype_ecs_type_inst           89412 non-null   object
#  46  adedpe202006_logtype_mur_ep_mat_ext          18026 non-null   object
#  47  adedpe202006_logtype_mur_mat_ext             105240 non-null  object
#  48  adedpe202006_logtype_mur_pos_isol_ext        105240 non-null  object
#  49  Commerces_bruyants                           105240 non-null  int64
#  50  cat_valeur                                   105240 non-null  category
#  51  range_revente_first                          19683 non-null   object
#  52  Evol_val                                     19683 non-null   float64
#  53  Estimation_prix_m2                           105240 non-null  int64
# dtypes: category(1), float64(14), int64(20), object(19)
# memory usage: 43.5+ MB

# %%
df_selec_2["Estimation_prix_m2"].isna().sum()
# Out:
# 0

# %%
# Création d'une variable "Valeur_estimée" :
df_selec_2["Valeur_estimée"]=df_selec_2["scarrez"]*df_selec_2["Estimation_prix_m2"]

# %%
df_selec_2["Evol_val"].isna().sum()
# Out:
# 85557

# %%
# La variable "Evol_val" = "nan" pour tous les biens qui n'ont pas été revendus => Remplacement de ces nan par le pourcentage
# d'évolution entre la valeur foncière initiale et la valeur estimée au 31/12/2021 selon carte notaires

df_selec_2["Evol_val"]=df_selec_2["Evol_val"].fillna((df_selec_2["Valeur_estimée"]-df_selec_2["valeurfonc"])/df_selec_2["valeurfonc"])

# %%
# On obtient donc une variable Evol_val qui sera égale à :
# (Valeur estimée-Valeur foncière)/valeurfoncière pour tous les lots qui n'ont pas été revendus
# - 0 pour la 1ère mutation des lots qui ont été revendus
# - % d'augmentation pour les mutations suivantes des lots qui ont été revendus

# %%
# Vérification sur qty_of_mut=0
df_selec_2[(df_selec_2["qty_of_mut"]==0)][["etaban_lot","anneemut","valeurfonc","range_revente_first","Estimation_prix_m2","scarrez", "Valeur_estimée", "Evol_val"]].sort_values(by=["etaban_lot","anneemut"])
# Out:
#                       etaban_lot  anneemut     valeurfonc range_revente_first  \
# idmutation
# 8817315     75101_0191_00003_110      2014  575700.000000                 NaN
# 8715762       75101_0191_00003_4      2015  442000.000000                 NaN
# 8449734      75101_0191_00005_14      2017  700000.000000                 NaN
# 8412777       75101_0191_00006_4      2017 1094000.000000                 NaN
# 8442593      75101_0191_00010_55      2017  789730.000000                 NaN
# ...                          ...       ...            ...                 ...
# 8565959      75120_9898_00055_27      2016  260000.000000                 NaN
# 8827580      75120_9898_00055_28      2014  400000.000000                 NaN
# 7979060       75120_9898_00077_3      2020  325000.000000                 NaN
# 7862739       75120_9898_00077_5      2021  495900.000000                 NaN
# 8125836       75120_9898_00077_6      2019  282000.000000                 NaN
#
#             Estimation_prix_m2   scarrez  Valeur_estimée  Evol_val
# idmutation
# 8817315                  13560 46.740000   633794.400000  0.100911
# 8715762                  13560 44.200000   599352.000000  0.356000
# 8449734                  13560 63.290000   858212.400000  0.226018
# 8412777                  13560 81.300000  1102428.000000  0.007704
# 8442593                  13560 66.460000   901197.600000  0.141146
# ...                        ...       ...             ...       ...
# 8565959                   9330 33.460000   312181.800000  0.200699
# 8827580                   9330 50.510000   471258.300000  0.178146
# 7979060                   9330 50.860000   474523.800000  0.460073
# 7862739                   9330 53.270000   497009.100000  0.002237
# 8125836                   9330 35.750000   333547.500000  0.182793
#
# [85557 rows x 8 columns]

# %%
# Vérification sur qty_of_mut=1
df_selec_2[(df_selec_2["qty_of_mut"]==1)][["etaban_lot","anneemut","valeurfonc","range_revente_first","Estimation_prix_m2","scarrez", "Valeur_estimée", "Evol_val"]].sort_values(by=["etaban_lot","anneemut"])
# Out:
#                       etaban_lot  anneemut    valeurfonc range_revente_first  \
# idmutation
# 8269301       75101_0407_00049_4      2018 660000.000000               first
# 8105917       75101_0407_00049_4      2019 853370.000000           not first
# 8439768       75101_0407_00049_5      2017 660000.000000               first
# 8119208       75101_0407_00049_5      2019 880000.000000           not first
# 8712767      75101_0407_00056_21      2015 200000.000000               first
# ...                          ...       ...           ...                 ...
# 7981775       75120_9888_00046_2      2020 394900.000000           not first
# 8699817     75120_9888_00084_104      2015 320000.000000               first
# 8117120     75120_9888_00084_104      2019 506997.000000           not first
# 8838640      75120_9898_00055_22      2014 280000.000000               first
# 8421910      75120_9898_00055_22      2017 298300.000000           not first
#
#             Estimation_prix_m2   scarrez  Valeur_estimée  Evol_val
# idmutation
# 8269301                  13560 62.460000   846957.600000  0.000000
# 8105917                  13560 62.620000   849127.200000  0.292985
# 8439768                  13560 69.040000   936182.400000  0.000000
# 8119208                  13560 69.070000   936589.200000  0.333333
# 8712767                  13560 22.450000   304422.000000  0.000000
# ...                        ...       ...             ...       ...
# 7981775                   9330 39.810000   371427.300000  0.889474
# 8699817                   9330 56.880000   530690.400000  0.000000
# 8117120                   9330 56.900000   530877.000000  0.584366
# 8838640                   9330 35.940000   335320.200000  0.000000
# 8421910                   9330 36.090000   336719.700000  0.065357
#
# [18407 rows x 8 columns]

# %%
# Vérification sur qty_of_mut=2
df_selec_2[(df_selec_2["qty_of_mut"]==2)][["etaban_lot","anneemut","valeurfonc","range_revente_first","Estimation_prix_m2","scarrez", "Valeur_estimée", "Evol_val"]].sort_values(by=["etaban_lot","anneemut"])
# Out:
#                      etaban_lot  anneemut    valeurfonc range_revente_first  \
# idmutation
# 8693949     75101_0632_00006_13      2015  85000.000000               first
# 7972144     75101_0632_00006_13      2020 570000.000000           not first
# 7857085     75101_0632_00006_13      2021 571500.000000           not first
# 8812325     75101_6513_00026_42      2014 189000.000000               first
# 8266468     75101_6513_00026_42      2018 288830.000000           not first
# ...                         ...       ...           ...                 ...
# 8722097     75120_9085_00016_72      2015 235000.000000           not first
# 7838868     75120_9085_00016_72      2021 298000.000000           not first
# 8698021     75120_9132_00015_17      2015 207000.000000               first
# 8285264     75120_9132_00015_17      2018 228000.000000           not first
# 7994587     75120_9132_00015_17      2020 303785.000000           not first
#
#             Estimation_prix_m2   scarrez  Valeur_estimée  Evol_val
# idmutation
# 8693949                  13560 38.640000   523958.400000  0.000000
# 7972144                  13560 38.830000   526534.800000  5.705882
# 7857085                  13560 39.850000   540366.000000  0.002632
# 8812325                  13560 24.130000   327202.800000  0.000000
# 8266468                  13560 24.170000   327745.200000  0.528201
# ...                        ...       ...             ...       ...
# 8722097                   9330 28.820000   268890.600000  0.305556
# 7838868                   9330 28.760000   268330.800000  0.268085
# 8698021                   9330 32.330000   301638.900000  0.000000
# 8285264                   9330 31.930000   297906.900000  0.101449
# 7994587                   9330 31.920000   297813.600000  0.332390
#
# [1232 rows x 8 columns]

# %%
# Vérification sur qty_of_mut=3
df_selec_2[(df_selec_2["qty_of_mut"]==3)][["etaban_lot","anneemut","valeurfonc","range_revente_first","Estimation_prix_m2","scarrez", "Valeur_estimée", "Evol_val"]].sort_values(by=["etaban_lot","anneemut"])
# Out:
#                        etaban_lot  anneemut    valeurfonc range_revente_first  \
# idmutation
# 8585796     75111_3700_00020_1004      2016 250000.000000               first
# 8117972     75111_3700_00020_1004      2019 400000.000000           not first
# 7972157     75111_3700_00020_1004      2020 400000.000000           not first
# 7989750     75111_3700_00020_1004      2020 540000.000000           not first
# 8711853       75113_0563_00020_11      2015 325000.000000               first
# 8561774       75113_0563_00020_11      2016 499000.000000           not first
# 8143650       75113_0563_00020_11      2019 550000.000000           not first
# 7983865       75113_0563_00020_11      2020 550000.000000           not first
# 8815968       75114_2665_00006_16      2014 280000.000000               first
# 8835306       75114_2665_00006_16      2014 210000.000000           not first
# 8572266       75114_2665_00006_16      2016 421550.000000           not first
# 8426991       75114_2665_00006_16      2017 432550.000000           not first
# 8578830       75114_5465_00022_19      2016 227350.000000               first
# 8441874       75114_5465_00022_19      2017 450000.000000           not first
# 7831807       75114_5465_00022_19      2021 294000.000000           not first
# 7831932       75114_5465_00022_19      2021 300000.000000           not first
# 8711656      75115_5456_00332_286      2015 410000.000000               first
# 8565922      75115_5456_00332_286      2016 550000.000000           not first
# 8428363      75115_5456_00332_286      2017 571000.000000           not first
# 8135942      75115_5456_00332_286      2019 629000.000000           not first
# 8822660        75117_4440_00008_6      2014 469360.000000               first
# 8264434        75117_4440_00008_6      2018 615000.000000           not first
# 8116696        75117_4440_00008_6      2019 640000.000000           not first
# 7840657        75117_4440_00008_6      2021 750145.000000           not first
# 8700271        75118_2974_00023_4      2015 429750.000000               first
# 8555709        75118_2974_00023_4      2016 470000.000000           not first
# 8582225        75118_2974_00023_4      2016 535000.000000           not first
# 7830682        75118_2974_00023_4      2021 630000.000000           not first
# 8816522       75118_5010_00078_10      2014 460000.000000               first
# 8565043       75118_5010_00078_10      2016 533000.000000           not first
# 8444884       75118_5010_00078_10      2017 534200.000000           not first
# 7833765       75118_5010_00078_10      2021 685650.000000           not first
# 8439263        75118_6467_00091_9      2017 285000.000000               first
# 7982305        75118_6467_00091_9      2020 360000.000000           not first
# 7830344        75118_6467_00091_9      2021 450200.000000           not first
# 7856004        75118_6467_00091_9      2021 417500.000000           not first
# 8687655        75119_0833_00099_3      2015 220000.000000               first
# 8132612        75119_0833_00099_3      2019 412000.000000           not first
# 7834073        75119_0833_00099_3      2021 470000.000000           not first
# 7849661        75119_0833_00099_3      2021 433000.000000           not first
# 8837536        75119_3417_00011_7      2014 377000.000000               first
# 8444185        75119_3417_00011_7      2017 397900.000000           not first
# 8122014        75119_3417_00011_7      2019 270000.000000           not first
# 8145023        75119_3417_00011_7      2019 465000.000000           not first
#
#             Estimation_prix_m2   scarrez  Valeur_estimée  Evol_val
# idmutation
# 8585796                  10510 49.920000   524659.200000  0.000000
# 8117972                  10510 49.950000   524974.500000  0.600000
# 7972157                  10510 49.950000   524974.500000  0.000000
# 7989750                  10510 49.950000   524974.500000  0.350000
# 8711853                   9230 49.730000   459007.900000  0.000000
# 8561774                   9230 51.170000   472299.100000  0.535385
# 8143650                   9230 50.100000   462423.000000  0.102204
# 7983865                   9230 50.100000   462423.000000  0.000000
# 8815968                  10060 36.750000   369705.000000  0.000000
# 8835306                  10060 36.770000   369906.200000 -0.250000
# 8572266                  10060 38.500000   387310.000000  1.007381
# 8426991                  10060 38.500000   387310.000000  0.026094
# 8578830                  10060 29.140000   293148.400000  0.000000
# 8441874                  10060 52.940000   532576.400000  0.979327
# 7831807                  10060 29.090000   292645.400000 -0.346667
# 7831932                  10060 29.090000   292645.400000  0.020408
# 8711656                  10100 80.490000   812949.000000  0.000000
# 8565922                  10100 80.490000   812949.000000  0.341463
# 8428363                  10100 79.150000   799415.000000  0.038182
# 8135942                  10100 79.160000   799516.000000  0.101576
# 8822660                  10450 67.300000   703285.000000  0.000000
# 8264434                  10450 67.150000   701717.500000  0.310295
# 8116696                  10450 67.150000   701717.500000  0.040650
# 7840657                  10450 67.330000   703598.500000  0.172102
# 8700271                   9750 52.910000   515872.500000  0.000000
# 8555709                   9750 52.910000   515872.500000  0.093659
# 8582225                   9750 67.070000   653932.500000  0.138298
# 7830682                   9750 53.020000   516945.000000  0.177570
# 8816522                   9750 57.110000   556822.500000  0.000000
# 8565043                   9750 59.740000   582465.000000  0.158696
# 8444884                   9750 57.300000   558675.000000  0.002251
# 7833765                   9750 58.170000   567157.500000  0.283508
# 8439263                   9750 35.040000   341640.000000  0.000000
# 7982305                   9750 35.000000   341250.000000  0.263158
# 7830344                   9750 35.280000   343980.000000  0.250556
# 7856004                   9750 34.390000   335302.500000 -0.072634
# 8687655                   8940 45.600000   407664.000000  0.000000
# 8132612                   8940 47.850000   427779.000000  0.872727
# 7834073                   8940 47.850000   427779.000000  0.140777
# 7849661                   8940 47.850000   427779.000000 -0.078723
# 8837536                   8940 49.040000   438417.600000  0.000000
# 8444185                   8940 49.060000   438596.400000  0.055438
# 8122014                   8940 48.740000   435735.600000 -0.321438
# 8145023                   8940 49.050000   438507.000000  0.722222

# %%
df_selec_2["Evol_val"].describe().to_frame()
# Out:
#            Evol_val
# count 105240.000000
# mean       0.212370
# std        1.467480
# min       -1.000000
# 25%        0.000000
# 50%        0.115717
# 75%        0.300033
# max      159.210800

# %%
# Dataviz 1= on isole les "not first" des biens qui ont été revendus pendant la période
selec=df_selec_2[(df_selec_2["qty_of_mut"]>0)&(df_selec_2["range_revente_first"]=="not first")]
selec.shape
# Out:
# (10055, 55)

# %%
g=selec.groupby("anneemut", as_index=False).agg({"Evol_val":"mean"})
g
# Out:
#    anneemut  Evol_val
# 0      2014  0.088457
# 1      2015  1.013034
# 2      2016  0.284725
# 3      2017  0.264426
# 4      2018  0.353840
# 5      2019  0.373932
# 6      2020  0.425401
# 7      2021  0.390626

# %%
plt.figure(figsize=(5,5))
plt.plot(g["anneemut"],g["Evol_val"])
plt.title("Evolution moyenne des prix par année de mutation")
plt.xlabel("Année de mutation")
plt.ylabel("Evolution des valeurs foncières (%)")
# Out:
# Text(0, 0.5, 'Evolution des valeurs foncières (%)')

# %%
g=selec.groupby("l_codinsee").agg({"Evol_val":"mean"})

list_arrond=g.index.tolist()
x_ticks=np.arange(len(g))

plt.figure(figsize=(7,5))
plt.bar(range(len(g)), g["Evol_val"], linewidth=5, color="#dfa801")
plt.xticks(x_ticks, list_arrond, rotation=60)
plt.xlabel("Arrondissements")
plt.ylabel("Pourcentage moyen d'évolution des prix")
plt.title("Evolution des valeurs foncières, \n entre 2 mutations, \n sur la période 2014-2021", fontsize=15);

# %%
# Dataviz 2 = on isole les biens qui n'ont pas été revendus pendant la période
selec_2=df_selec_2[df_selec_2["qty_of_mut"]==0]
selec_2.shape
# Out:
# (85557, 55)

# %%
m=selec_2.groupby("l_codinsee").agg({"Evol_val":"mean"})

list_arrond=m.index.tolist()
x_ticks=np.arange(len(m))

plt.figure(figsize=(7,5))
plt.bar(range(len(m)), m["Evol_val"], linewidth=5, color="#dfa801")
plt.xticks(x_ticks, list_arrond, rotation=60)
plt.xlabel("Arrondissements")
plt.ylabel("Pourcentage moyen d'évolution des prix")
plt.title("Estimation de l'évolution des valeurs foncières \n pour les biens qui n'ont pas été revendus sur la période 2014-2021", fontsize=15);

# %%
# Analyse de la variable "nblot" => nombre total de lots dans la mutation
df_selec_2["nblot"].value_counts().to_frame()
# Out:
#     nblot
# 2   51764
# 1   36083
# 3   14428
# 4    2037
# 5     590
# 6     187
# 7      68
# 8      35
# 9      16
# 12      6
# 10      6
# 14      5
# 11      3
# 18      3
# 13      2
# 16      2
# 20      1
# 24      1
# 21      1
# 19      1
# 15      1

# %%
# Regroupement des catégories > 3

def filtre (x) :
    if x >3 :
        return ">3"
    else :
        return x
    
df_selec_2["nblot"]=df_selec_2["nblot"].apply(filtre)

# %%
df_selec_2["nblot"].value_counts()
# Out:
# 2     51764
# 1     36083
# 3     14428
# >3     2965
# Name: nblot, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='nblot', data=df_selec_2, order=[1, 2, 3, ">3"])
plt.title("Nbre de lots par mutation", fontsize=15)
plt.xlabel('Nombre de lots');

# %%
# Analyse de la variable "nbcomm" => nombre de communes concernées par la mutation
df_selec_2["nbcomm"].value_counts()
# Out:
# 1    105240
# Name: nbcomm, dtype: int64

# %%
# Aucun intérêt. Suppression de cette variable

df_selec_2=df_selec_2.drop("nbcomm", axis=1)

# %%
# Analyse de la variable "l_codinsee" => liste des codes INSEE des communes concernées par la mutation
df_selec_2["l_codinsee"].value_counts(ascending=True).to_frame()
# Out:
#        l_codinsee
# 75101         977
# 75102        1427
# 75104        1545
# 75108        1849
# 75106        1943
# 75107        2316
# 75103        2319
# 75105        2401
# 75109        3024
# 75113        4803
# 75110        5127
# 75112        5948
# 75114        6000
# 75119        6240
# 75116        7308
# 75120        7528
# 75111        9110
# 75117       10220
# 75115       10480
# 75118       14675

# %%
plt.figure(figsize=(10,5))

sns.countplot(x='l_codinsee', data=df_selec_2)
plt.title("Nbre de mutations par arrondissement", fontsize=20)
plt.xticks(rotation=45)
plt.xlabel('Arrondissements');

# %%
df_selec_2["Revente"].value_counts()
# Out:
# 0    85557
# 1    19683
# Name: Revente, dtype: int64

# %%
g=df_selec_2.groupby("l_codinsee").agg({"Revente":"mean"})
g
# Out:
#             Revente
# l_codinsee
# 75101      0.151484
# 75102      0.191310
# 75103      0.183269
# 75104      0.146926
# 75105      0.129529
# 75106      0.163150
# 75107      0.161917
# 75108      0.175230
# 75109      0.208003
# 75110      0.191925
# 75111      0.179802
# 75112      0.151479
# 75113      0.127837
# 75114      0.159667
# 75115      0.157252
# 75116      0.183634
# 75117      0.222701
# 75118      0.237956
# 75119      0.200801
# 75120      0.205632

# %%
list_arrond=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(8,8))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#71d3de")
plt.xticks(x_ticks, list_arrond, rotation=60)
plt.xlabel("Arrondissements")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot par arrondissement \n sur la période 2014-2021", fontsize=15);

# %%
# Analyse de la variable "nblocapt" => nombre d'appartements ayant muté
df_selec_2["nblocapt"].value_counts()
# Out:
# 1    105240
# Name: nblocapt, dtype: int64

# %%
# Aucun intérêt. Suppression de cette variable
df_selec_2=df_selec_2.drop("nblocapt", axis=1)

# %%
# Analyse de la variable "nblocdep" => nombre de dépendances ayant muté
df_selec_2["nblocdep"].value_counts().to_frame()
# Out:
#     nblocdep
# 0      86527
# 1      16921
# 2       1546
# 3        194
# 4         35
# 5          8
# 7          3
# 6          2
# 12         1
# 9          1
# 14         1
# 8          1

# %%
# Regroupement des catégories > 1

def filtre (x) :
    if x >1 :
        return ">1"
    else :
        return x
    
df_selec_2["nblocdep"]=df_selec_2["nblocdep"].apply(filtre)

# %%
df_selec_2["nblocdep"].value_counts().to_frame()
# Out:
#     nblocdep
# 0      86527
# 1      16921
# >1      1792

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='nblocdep', data=df_selec_2, order=[0,1, ">1"])
plt.title("Nbre de dépendances par mutation", fontsize=15)
plt.xlabel('Nombre de dépendances');

# %%
 # Analyse de la variable "nbapt2pp" => nombre d'appartements avec 2 pièces principales ayant muté
df_selec_2["nbapt2pp"].value_counts().to_frame()
# Out:
#    nbapt2pp
# 1     63944
# 0     41296

# %%
df_selec_2["nbapt2pp"].isna().sum()
# Out:
# 0

# %%
df_selec_2["nbapt2pp"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
 # Analyse de la variable "nbapt3pp" => nombre d'appartements avec 3 pièces principales ayant muté
df_selec_2["nbapt3pp"].value_counts().to_frame()
# Out:
#    nbapt3pp
# 0     63944
# 1     41296

# %%
df_selec_2["nbapt3pp"].isna().sum()
# Out:
# 0

# %%
# Regroupement des variables "nbapt2pp" et "nbapt3pp" => "Type_appart"

df_selec_2=df_selec_2.rename({"nbapt2pp":"Type_appart"}, axis=1)

# %%
df_selec_2["Type_appart"].value_counts().to_frame()
# Out:
#    Type_appart
# 1        63944
# 0        41296

# %%
df_selec_2["Type_appart"]=df_selec_2["Type_appart"].replace({0:"3P", 1:"2P"})

# %%
df_selec_2["Type_appart"].value_counts().to_frame()
# Out:
#     Type_appart
# 2P        63944
# 3P        41296

# %%
# Suppression de la variable "nbapt3pp"  
df_selec_2=df_selec_2.drop("nbapt3pp", axis=1)

# %%
plt.figure(figsize=(7,7))
x=df_selec_2["Type_appart"].value_counts()

plt.pie(x, labels=["Appart 2 Pièces", "Appart 3 Pièces"], 
        colors=["#e0c0f7", "#84ae57"], 
        explode=[0.05,0.05],
        autopct=lambda x : str(round(x,2))+ "%", 
        pctdistance=0.7, 
        shadow=True)
plt.title("Proportion de mutations par type d'appartement", fontsize=20)
plt.legend(loc="best");

# %%
g=df_selec_2.groupby("Type_appart").agg({"Revente":"mean"})
g
# Out:
#              Revente
# Type_appart
# 2P          0.180079
# 3P          0.197792

# %%
list_appart=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure()
plt.bar(range(len(g)), g["Revente"], color="#f890e7")
plt.xticks(x_ticks, list_appart)
plt.xlabel("Type d'appartement")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot par type d'appartement \n sur la période 2014-2021", fontsize=15);

# %%
# Analyse de la variable "sbati" => surface de l'ensemble du bâti ayant muté
df_selec_2["sbati"].value_counts()
# Out:
# 40     3891
# 30     3520
# 50     3464
# 35     3278
# 45     3262
#        ...
# 220       1
# 190       1
# 166       1
# 350       1
# 214       1
# Name: sbati, Length: 191, dtype: int64

# %%
# Analyse de la variable "sbatapt" => surface de l'ensemble du bâti ayant muté
df_selec_2["sbatapt"].value_counts()
# Out:
# 40     3891
# 30     3520
# 50     3464
# 35     3278
# 45     3262
#        ...
# 220       1
# 190       1
# 166       1
# 350       1
# 214       1
# Name: sbatapt, Length: 191, dtype: int64

# %%
# Ces 2 variables donnent les mêmes infos. Suppression de l'une
df_selec_2=df_selec_2.drop("sbati", axis=1)

# %%
# Analyse de la variable "sbatact" => surface de l'ensemble du bâti ayant muté
df_selec_2["sbatact"].value_counts()
# Out:
# 0    105240
# Name: sbatact, dtype: int64

# %%
# Pas d'intérêt => suppression
df_selec_2=df_selec_2.drop("sbatact", axis=1)

# %%
# Analyse de la variable "sapt2pp" => surface de l'ensemble du bâti ayant muté
df_selec_2["sapt2pp"].describe().to_frame()
# Out:
#             sapt2pp
# count 105240.000000
# mean      24.201539
# std       22.134034
# min        0.000000
# 25%        0.000000
# 50%       28.000000
# 75%       40.000000
# max      340.000000

# %%
df_selec_2["sapt2pp"].value_counts()
# Out:
# 0      41296
# 30      3360
# 40      3075
# 35      2986
# 32      2466
#        ...
# 195        1
# 175        1
# 131        1
# 135        1
# 214        1
# Name: sapt2pp, Length: 150, dtype: int64

# %%
# Analyse de la variable "sapt3pp" => surface de l'ensemble du bâti ayant muté
df_selec_2["sapt3pp"].describe().to_frame()
# Out:
#             sapt3pp
# count 105240.000000
# mean      24.453516
# std       32.652491
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       55.000000
# max      495.000000

# %%
# Addition des 2 variables
df_selec_2["surface_appart"]=df_selec_2["sapt2pp"]+df_selec_2["sapt3pp"]

# %%
df_selec_2["surface_appart"].describe().to_frame()
# Out:
#        surface_appart
# count   105240.000000
# mean        48.655055
# std         19.299325
# min         10.000000
# 25%         35.000000
# 50%         45.000000
# 75%         59.000000
# max        495.000000

# %%
#Comparaison "surface_appart" et "sbatapt"

compar=df_selec_2["surface_appart"]-df_selec_2["sbatapt"]
compar.sum()
# Out:
# 0

# %%
# Suppression de "sbatapt", "sapt2pp", "sapt3pp"
df_selec_2=df_selec_2.drop("sbatapt", axis=1)
df_selec_2=df_selec_2.drop("sapt2pp", axis=1)
df_selec_2=df_selec_2.drop("sapt3pp", axis=1)

# %%
sns.boxplot(x="surface_appart", data=df_selec_2)
plt.title("Distribution de la surface des appartements", fontsize=15)
plt.xlabel('Surface des appartements');

# %%
df_selec_2[df_selec_2["surface_appart"]>220].shape
# Out:
# (11, 48)

# %%
# Suppression valeurs aberrantes
df_selec_2=df_selec_2[df_selec_2["surface_appart"]<220]

# %%
sns.boxplot(x="surface_appart", data=df_selec_2)
plt.title("Distribution de la surface des appartements", fontsize=15)
plt.xlabel('Surface des appartements');

# %%
# Analyse de la variable "scarrez" => Surface Loi Carrez du lot
df_selec_2["scarrez"].describe().to_frame()
# Out:
#             scarrez
# count 105228.000000
# mean      48.641474
# std       45.672267
# min        0.000000
# 25%       34.440000
# 50%       45.310000
# 75%       58.850000
# max     7392.000000

# %%
sns.boxplot(x = 'scarrez', data = df_selec_2)
plt.title("Distribution de la surface Carrez des appartements", fontsize=15)
plt.xlabel('Surface Carrez des appartements');

# %%
df_selec_2[df_selec_2["scarrez"]==0].shape
# Out:
# (24, 48)

# %%
df_selec_2[df_selec_2["scarrez"]>220].shape
# Out:
# (19, 48)

# %%
#Suppression des valeurs aberrantes

# %%
df_selec_2=df_selec_2[(df_selec_2["scarrez"]>0)&(df_selec_2["scarrez"]<220)]

# %%
sns.boxplot(x = 'scarrez', data = df_selec_2)
plt.title("Distribution de la surface Carrez des appartements", fontsize=10)
plt.xlabel('Surface Carrez des appartements');

# %%
plt.figure(figsize = (7,7))
plt.boxplot(df_selec_2["scarrez"])
plt.title( 'Boxplot')
plt.axes([0.65, 0.65, 0.2, 0.15], facecolor='#ffe5c1')
plt.hist(df_selec_2["scarrez"], color='#FFC575')
plt.xlabel('Distribution')
plt.xticks([])
plt.yticks([]);

# %%
# Relation entre valeur foncière et surface
plt.figure(figsize=(15,15))
sns.relplot(x="valeurfonc", y="surface_appart", hue="Revente", data=df_selec_2, s=30, palette=["b", "r"]);
plt.xlabel("Valeur foncière du lot en €")
plt.ylabel("Surface de l'appartement en m²")
plt.title("Relation entre surface et valeur des appartements", fontsize=15);

# %%
# IRINA = trouver comment faire pour que quand bcp de points au même endroit ca fasse un gros point (weight-den

# %%
# Vérifier linéarité entre les variables "scarrez" et "surface_appart"
#plt.figure(figsize=(8,8))
#sns.lmplot(x="scarrez", y="surface_appart", lowess=True,scatter_kws={"s": 2}, data=df_selec_2)

# %%
# Scarrez et surface_appart sont très corrélés. Suppression de surface_appart
df_selec_2=df_selec_2.drop("surface_appart", axis=1)

# %%
plt.figure(figsize=(8,8))
plt.scatter(x=df_selec_2["valeurfonc"], y=df_selec_2["scarrez"], color="#28a27e", s=2)
plt.xticks(rotation=70)
plt.xlabel("Valeur foncière en €")
plt.ylabel("Surface loi Carrez en m²")
plt.title("Relation entre Surface loi Carrez et Valeur foncière");

# %%
# Analyse de la variable  "anarnc202012_nb_log"=> Nombre de logements dans le bâtiment
df_selec_2["anarnc202012_nb_log"].describe().to_frame()
# Out:
#        anarnc202012_nb_log
# count        105185.000000
# mean            109.684169
# std             363.545874
# min               0.000000
# 25%              18.000000
# 50%              30.000000
# 75%              61.000000
# max            4791.000000

# %%
df_selec_2["anarnc202012_nb_log"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_log"])
plt.title("Nombre de logements dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre de logement dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_selec_2[df_selec_2["anarnc202012_nb_log"]==0].shape
# Out:
# (1254, 47)

# %%
df_selec_2[df_selec_2["anarnc202012_nb_log"]==1].shape
# Out:
# (124, 47)

# %%
df_selec_2[(df_selec_2["anarnc202012_nb_log"]>1) & (df_selec_2["anarnc202012_nb_log"]<100)].median()
# Out:
# C:\Users\Anne\AppData\Local\Temp/ipykernel_3380/4177864215.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_selec_2[(df_selec_2["anarnc202012_nb_log"]>1) & (df_selec_2["anarnc202012_nb_log"]<100)].median()
# etaban_lot                                    7511372510001885.000000
# qty_of_mut                                                   0.000000
# Revente                                                      0.000000
# anneemut                                                  2018.000000
# moismut                                                      7.000000
# Immeuble_neuf                                                0.000000
# valeurfonc                                              400000.000000
# l_codinsee                                               75115.000000
# scarrez                                                     43.825000
# anarnc202012_nb_log                                         26.000000
# anarnc202012_nb_lot_garpark                                  0.000000
# anarnc202012_nb_lot_tertiaire                               25.000000
# anarnc202012_nb_lot_tot                                     45.000000
# adedpe202006_logtype_perc_surf_vitree_ext                    0.249000
# adedpe202006_logtype_presence_balcon                         0.000000
# adedpe202006_logtype_presence_climatisation                  0.000000
# ancqpv201410_is_qpv                                          0.000000
# cerffo2020_nb_log                                           22.000000
# igntop202103_bat_hauteur                                    19.800000
# mcumer202007_is_mer                                          1.000000
# adedpe202006_logtype_s_hab                                  42.000000
# Commerces_bruyants                                           0.000000
# Evol_val                                                     0.110009
# Estimation_prix_m2                                       10100.000000
# Valeur_estimée                                          450910.550000
# dtype: float64

# %%
df_selec_2[(df_selec_2["anarnc202012_nb_log"]>0) & (df_selec_2["anarnc202012_nb_log"]<1)].shape
# Out:
# (98, 47)

# %%
df_selec_2[df_selec_2["anarnc202012_nb_log"]>2500].shape
# Out:
# (755, 47)

# %%
# Suppression des valeurs aberrantes
df_selec_2=df_selec_2[(df_selec_2["anarnc202012_nb_log"]>=1)&(df_selec_2["anarnc202012_nb_log"]<2500)]

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_log"])
plt.title("Nombre de logements dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre de logement dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_selec_2["anarnc202012_nb_log"].describe().to_frame()
# Out:
#        anarnc202012_nb_log
# count        103078.000000
# mean             85.281164
# std             193.985854
# min               1.000000
# 25%              19.000000
# 50%              30.000000
# 75%              61.000000
# max            2488.640000

# %%
# Création d'une variable "Taille_copro" à partir des quartiles obtenus après suppression des valeurs extrêmes

def filtre (x) :
    if x<=19 :
        return "Petite"
    elif x >19 and x<=30 :
        return "Moyenne"
    elif x >30 and x<=61 :
        return "Grande"
    else : 
        return "Très grande"

df_selec_2["Taille_copro"]=df_selec_2["anarnc202012_nb_log"].apply(filtre)

# %%
df_selec_2["Taille_copro"].value_counts().to_frame()
# Out:
#              Taille_copro
# Petite              27975
# Très grande         25528
# Grande              25463
# Moyenne             24112

# %%
plt.figure(figsize=(8,5))

sns.countplot(x='Taille_copro', data=df_selec_2, palette="Set2", order=["Petite", "Moyenne", "Grande", "Très grande"])
plt.title("Taille des copropriétés", fontsize=15)
plt.xlabel("Taille des copropriétés");

# %%
g=df_selec_2.groupby("Taille_copro", as_index=False).agg({"Revente":"mean"})
g
# Out:
#   Taille_copro  Revente
# 0       Grande 0.188862
# 1      Moyenne 0.202389
# 2       Petite 0.191993
# 3  Très grande 0.166836

# %%
plt.figure(figsize=(15,15))
sns.catplot(x = 'Taille_copro', y = 'Revente', kind="bar", data = g, order=["Petite", "Moyenne", "Grande", "Très grande"])
plt.xticks(rotation=60)
plt.xlabel("Taille copropriété")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot par taille de copropriété \n sur la période 2014-2021", fontsize=15);

# %%
# Analyse de la variable  "anarnc202012_nb_lot_garpark"=> (rnc) Nombre de lots de stationnement dans le bâtiment
df_selec_2["anarnc202012_nb_lot_garpark"].describe().to_frame()
# Out:
#        anarnc202012_nb_lot_garpark
# count                103078.000000
# mean                     35.389493
# std                     150.323691
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                    3513.000000

# %%
df_selec_2[df_selec_2["anarnc202012_nb_lot_garpark"]==0].shape
# Out:
# (77597, 48)

# %%
# 80% des appts n'ont pas de parking ce qui ne me semble pas improbable dans Paris

# %%
df_selec_2["anarnc202012_nb_lot_garpark"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_lot_garpark"])
plt.title("Nombre de places de parking dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre de places de parking dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_selec_2[df_selec_2["anarnc202012_nb_lot_garpark"]>1500].shape
# Out:
# (148, 48)

# %%
# Suppression des valeurs aberrantes
df_selec_2=df_selec_2[(df_selec_2["anarnc202012_nb_lot_garpark"]<1500)]

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_lot_garpark"])
plt.title("Nombre de places de parking dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre de places de parking dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Analyse de la variable  "anarnc202012_nb_lot_tertiaire"=>(rnc) Nombre de lots de type bureau et commerce dans le bâtiment
df_selec_2["anarnc202012_nb_lot_tertiaire"].describe()
# Out:
# count   102930.000000
# mean        72.023806
# std        167.518387
# min          0.000000
# 25%         14.000000
# 50%         28.000000
# 75%         56.000000
# max       2464.000000
# Name: anarnc202012_nb_lot_tertiaire, dtype: float64

# %%
df_selec_2["anarnc202012_nb_lot_tertiaire"].isna().sum()
# Out:
# 0

# %%
df_selec_2[df_selec_2["anarnc202012_nb_lot_tertiaire"]==0].shape
# Out:
# (20192, 48)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_lot_tertiaire"])
plt.title("Nombre de commerces dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre de commerces dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_selec_2[df_selec_2["anarnc202012_nb_lot_tertiaire"]>2000].shape
# Out:
# (69, 48)

# %%
# Suppression des valeurs aberrantes
df_selec_2=df_selec_2[(df_selec_2["anarnc202012_nb_lot_tertiaire"]<2000)]

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_lot_tertiaire"])
plt.title("Nombre de commerces dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre de commerces dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Décision prise de supprimer la variable "anarnc202012_nb_lot_tertiaire"
# qui n'apporte rien à la modélisation. On va s'intéresser plutôt aux type d'équipement bruyant

df_selec_2=df_selec_2.drop("anarnc202012_nb_lot_tertiaire", axis=1)

# %%
# Analyse de la variable  "anarnc202012_nb_lot_tot"=>(rnc) Nombre total de lots dans le bâtiment
df_selec_2["anarnc202012_nb_lot_tot"].describe().to_frame()
# Out:
#        anarnc202012_nb_lot_tot
# count            102861.000000
# mean                173.081196
# std                 421.345853
# min                   0.880000
# 25%                  31.000000
# 50%                  53.940000
# 75%                 116.000000
# max                7264.000000

# %%
df_selec_2["anarnc202012_nb_lot_tot"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_lot_tot"])
plt.title("Nombre total de lots dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre total de lots dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_selec_2[df_selec_2["anarnc202012_nb_lot_tot"]==0].shape
# Out:
# (0, 47)

# %%
df_selec_2[df_selec_2["anarnc202012_nb_lot_tot"]>3500].shape
# Out:
# (279, 47)

# %%
# Suppression des valeurs extrêmes
df_selec_2=df_selec_2[(df_selec_2["anarnc202012_nb_lot_tot"]>=1)&(df_selec_2["anarnc202012_nb_lot_tot"]<3500)]

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["anarnc202012_nb_lot_tot"])
plt.title("Nombre total de lots dans le bâtiment auquel appartient l'appart qui a muté")
plt.xlabel("Nombre total de lots dans le bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Création d'une variable pour connaitre le ratio de place de parking par logement dans l'immeuble

df_selec_2["ratio_log_park"]=df_selec_2["anarnc202012_nb_log"]/df_selec_2["anarnc202012_nb_lot_garpark"]

# %%
def filtre(x) :
    if x > 1 :
        return "pas de parking pour tous"
    elif x==1 :
        return "parking"
    else :
        return "plus de parking que d'appart"
    
df_selec_2["park_log"]=df_selec_2["ratio_log_park"].apply(filtre)
df_selec_2["park_log"].value_counts().to_frame()
# Out:
#                               park_log
# pas de parking pour tous         94275
# plus de parking que d'appart      7642
# parking                            660

# %%
df_selec_2.groupby(["Type_appart", "park_log"]).agg({"park_log":"count"})
# Out:
#                                           park_log
# Type_appart park_log
# 2P          parking                            364
#             pas de parking pour tous         57847
#             plus de parking que d'appart      4178
# 3P          parking                            296
#             pas de parking pour tous         36428
#             plus de parking que d'appart      3464

# %%
# Au final, il ne nous sera pas possible de savoir si l'appart concerné par la mutation a ou non un parking...
# Suppression de cette variable "ratio_log_park", "park_log"  et "anarnc202012_nb_lot_garpark"

df_selec_2=df_selec_2.drop(["ratio_log_park", "park_log","anarnc202012_nb_lot_garpark"], axis=1)

# %%
# Analyse de la variable  "adedpe202006_logtype_baie_type_vitrage"=> vitrages d'un logement représentatif du bâtiment
df_selec_2["adedpe202006_logtype_baie_type_vitrage"].value_counts(ascending=False)
# Out:
# double vitrage                      72296
# simple vitrage                      24709
# triple vitrage                        747
# survitrage                            162
# brique de verre ou polycarbonate       11
# Name: adedpe202006_logtype_baie_type_vitrage, dtype: int64

# %%
df_selec_2["adedpe202006_logtype_baie_type_vitrage"].isna().sum()
# Out:
# 4652

# %%
# Remplacement des Nan par le mode
df_selec_2["adedpe202006_logtype_baie_type_vitrage"]=df_selec_2["adedpe202006_logtype_baie_type_vitrage"].fillna(df_selec_2["adedpe202006_logtype_baie_type_vitrage"].mode()[0])

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='adedpe202006_logtype_baie_type_vitrage', data=df_selec_2, palette="Set2", dodge=False)
plt.title("Type de vitrage d'un logement représentatif du bâtiment auquel appartient l'appart muté")
plt.xlabel("Type de vitrage");

# %%
# Suppression de la variable parce qu'elle concerne uniquement un logement représentatif du bâtiment

df_selec_2=df_selec_2.drop("adedpe202006_logtype_baie_type_vitrage", axis=1)

# %%
# Analyse de la variable  "adedpe202006_logtype_ch_gen_lib_princ"=> Type de générateur de chauffage principal du bâtiment
df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"].value_counts(ascending=False)
# Out:
# generateurs a effet joule                          50472
# chaudiere gaz standard                             30455
# reseau de chaleur                                   5711
# chaudiere gaz basse temperature                     3557
# chaudiere gaz condensation                          2616
# chaudiere fioul standard                            2319
# chaudiere electrique                                 894
# pac air/air                                          701
# pac indetermine                                      446
# chaudiere energie indetermine standard               258
# radiateurs gaz                                       219
# chaudiere energie indetermine indetermine            195
# chaudiere fioul basse temperature                    140
# autres                                                87
# chauffage autre indetermine                           73
# pac air/eau                                           66
# chaudiere energie indetermine basse temperature       44
# chaudiere fioul condensation                          32
# Name: adedpe202006_logtype_ch_gen_lib_princ, dtype: int64

# %%
df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"].isna().sum()
# Out:
# 4292

# %%
# Remplacement des nan par le mode
df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"]=df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"].fillna(df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"].mode()[0])

# %%
def filtre(x) :
    if "gaz" in x :
        return "chaudière gaz"
    elif "joule" in x or "electrique" in x:
        return "chaudière électrique"
    elif "fioul" in x :
        return "chaudière fioul"
    elif "reseau" in x :
        return "réseau de chaleur"
    else :
        return "indeterminé"

# %%
df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"]=df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"].apply(filtre)

# %%
df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"].value_counts().to_frame()
# Out:
#                       adedpe202006_logtype_ch_gen_lib_princ
# chaudière électrique                                  55658
# chaudière gaz                                         36847
# réseau de chaleur                                      5711
# chaudière fioul                                        2491
# indeterminé                                            1870

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='adedpe202006_logtype_ch_gen_lib_princ', data=df_selec_2, palette="Set1", order=df_selec_2["adedpe202006_logtype_ch_gen_lib_princ"].value_counts().index)
plt.title("Type de générateur de chauffage principal du bâtiment auquel appartient l'appart qui a muté")
plt.xticks(rotation=70)
plt.xlabel("Type de générateur");

# %%
# Analyse de la variable  "adedpe202006_mean_class_conso_ener"=>
# classe déduite de la moyenne des consommations énergétiques sur l'ensemble des DPE [kWhEP/m².an]
df_selec_2["adedpe202006_mean_class_conso_ener"].value_counts().sort_index().to_frame()
# Out:
#    adedpe202006_mean_class_conso_ener
# A                                 108
# B                                 541
# C                                2937
# D                               24556
# E                               41502
# F                               18452
# G                                6204
# N                                4727

# %%
df_selec_2["adedpe202006_mean_class_conso_ener"].isna().sum()
# Out:
# 3550

# %%
# Remplacement des Nan par le mode
df_selec_2["adedpe202006_mean_class_conso_ener"]=df_selec_2["adedpe202006_mean_class_conso_ener"].fillna(df_selec_2["adedpe202006_mean_class_conso_ener"].mode()[0])

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='adedpe202006_mean_class_conso_ener', data=df_selec_2, palette="Set2", order=df_selec_2["adedpe202006_mean_class_conso_ener"].value_counts().index.sort_values())
plt.title("Classe déduite de la moyenne des consommations \n énergétiques sur l'ensemble des DPE du bâtiment")
plt.xlabel("Classe de consommation énergie");

# %%
g=df_selec_2.groupby("adedpe202006_mean_class_conso_ener").agg({"Revente":"mean"})
g
# Out:
#                                     Revente
# adedpe202006_mean_class_conso_ener
# A                                  0.166667
# B                                  0.147874
# C                                  0.181137
# D                                  0.179182
# E                                  0.189048
# F                                  0.200033
# G                                  0.188749
# N                                  0.178126

# %%
list_conso=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(8,8))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#fbb93f")
plt.xticks(x_ticks, list_conso)
plt.xlabel("Classe de consommation énergie")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot selon la classe de consommation énergie \n du bâtiment, sur la période 2014-2021", fontsize=15);

# %%
# Analyse de la variable  "adedpe202006_mean_class_estim_ges"=>
# classe déduite de la moyenne des émissions de Gaz à Effet de Serre sur l'ensemble des DPE [kgC02eq/m².an]
# La classe GES figure sur l’étiquette climat d’un logement et permet de connaître la quantité de gaz à effet de serre émise par an.

df_selec_2["adedpe202006_mean_class_estim_ges"].value_counts().sort_index().to_frame()
# Out:
#    adedpe202006_mean_class_estim_ges
# A                                795
# B                               9167
# C                              26311
# D                              22848
# E                              23220
# F                              10032
# G                               1921
# N                               4733

# %%
# La réforme de Juillet 2021 : Les étiquettes énergie du DPE ne sont plus uniquement exprimées en énergie primaire. 
# Les seuils sont calculés en fonction de deux facteurs : 
# l'énergie primaire mais également les émissions de gaz à effet de serre. 
# Un logement est donc classé sur l'échelle de classe énergétique (de A à G) sur un « double-seuil ». 
# Sa plus mauvaise performance, en énergie primaire ou en gaz à effet de serre, définit la classe du logement.
# Un logement classé F ou G en DPE "Consommation Energétiques" ou "Emission de GES" est considéré comme une passoire thermique.

# %%
df_selec_2["adedpe202006_mean_class_estim_ges"].isna().sum()
# Out:
# 3550

# %%
# Remplacement des nans par le mode
df_selec_2["adedpe202006_mean_class_estim_ges"]=df_selec_2["adedpe202006_mean_class_estim_ges"].fillna(df_selec_2["adedpe202006_mean_class_estim_ges"].mode()[0])

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='adedpe202006_mean_class_estim_ges', data=df_selec_2, palette="Set2", order=df_selec_2["adedpe202006_mean_class_estim_ges"].value_counts().index.sort_values())
plt.title("Classe déduite de la moyenne des émissions de GES sur l'ensemble des DPE du bâtiment")
plt.xlabel("Classe de consommation GES DPE");

# %%
g=df_selec_2.groupby("adedpe202006_mean_class_estim_ges").agg({"Revente":"mean"})
g
# Out:
#                                    Revente
# adedpe202006_mean_class_estim_ges
# A                                 0.163522
# B                                 0.199193
# C                                 0.189545
# D                                 0.197391
# E                                 0.174376
# F                                 0.181619
# G                                 0.213431
# N                                 0.178322

# %%
list_ges=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(8,8))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#71d3de")
plt.xticks(x_ticks, list_ges)
plt.xlabel("Classe de consommation GES DPE")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot selon la classe de consommation GES DPE \n  du bâtiment, sur la période 2014-2021", fontsize=15);

# %%
# Analyse de la variable  "adedpe202006_logtype_traversant"=> caractère traversant des logements du bâtiment
df_selec_2["adedpe202006_logtype_traversant"].value_counts(ascending=False).to_frame()
# Out:
#                                  adedpe202006_logtype_traversant
# non traversant                                             70342
# traversant nord sud (faible)                                3231
# traversant est ouest (faible)                               2630
# traversant tout venant (faible)                             2125
# traversant nord sud                                         2047
# traversant tout venant                                      2001
# traversant est ouest                                        1869
# traversant 90° (faible)                                      788
# traversant 90°                                               703

# %%
df_selec_2["adedpe202006_logtype_traversant"].isna().sum()
# Out:
# 16841

# %%
# Remplacement des nans par une classe inconnue
df_selec_2["adedpe202006_logtype_traversant"]=df_selec_2["adedpe202006_logtype_traversant"].fillna("Inconnu")

# %%
df_selec_2["adedpe202006_logtype_traversant"].value_counts(ascending=False).to_frame()
# Out:
#                                  adedpe202006_logtype_traversant
# non traversant                                             70342
# Inconnu                                                    16841
# traversant nord sud (faible)                                3231
# traversant est ouest (faible)                               2630
# traversant tout venant (faible)                             2125
# traversant nord sud                                         2047
# traversant tout venant                                      2001
# traversant est ouest                                        1869
# traversant 90° (faible)                                      788
# traversant 90°                                               703

# %%
def filtre(x) :
    if "non" in x:
        return "Non traversant"
    elif x=="Inconnu" :
        return "Inconnu"
    else :
        return "Traversant"

df_selec_2["adedpe202006_logtype_traversant"]=df_selec_2["adedpe202006_logtype_traversant"].apply(filtre)
df_selec_2["adedpe202006_logtype_traversant"].value_counts(ascending=False)
# Out:
# Non traversant    70342
# Inconnu           16841
# Traversant        15394
# Name: adedpe202006_logtype_traversant, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='adedpe202006_logtype_traversant', data=df_selec_2, palette="Set2", order = df_selec_2['adedpe202006_logtype_traversant'].value_counts().index)
plt.title("Caractère traversant des logements du bâtiment auquel appartient l'appart qui a muté")
plt.xticks(rotation=70)
plt.xlabel("Caractère traversant des logements");

# %%
# Analyse de la variable  "adedpe202006_logtype_ecs_type_ener"=> Type d'énergie de eau chaude (concaténé + ) du bâtiment
df_selec_2["adedpe202006_logtype_ecs_type_ener"].value_counts(ascending=False).to_frame()
# Out:
#                                                adedpe202006_logtype_ecs_type_ener
# electricite                                                                 55482
# gaz                                                                         34449
# reseau de chaleur                                                            4994
# fioul                                                                        1738
# ecs thermodynamique electrique(pac ou ballon)                                 289
# autres                                                                        156
# bois                                                                          140

# %%
df_selec_2["adedpe202006_logtype_ecs_type_ener"].isna().sum()
# Out:
# 5329

# %%
# Remplacement des nans par le mode
df_selec_2["adedpe202006_logtype_ecs_type_ener"]=df_selec_2["adedpe202006_logtype_ecs_type_ener"].fillna(df_selec_2["adedpe202006_logtype_ecs_type_ener"].mode()[0])

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='adedpe202006_logtype_ecs_type_ener', data=df_selec_2, palette="Set2", order = df_selec_2['adedpe202006_logtype_ecs_type_ener'].value_counts().index)
plt.title("Type d'énergie de ecs (concaténé + ) du bâtiment auquel appartient l'appart qui a muté")
plt.xticks(rotation=70)
plt.xlabel("Type d'énergie de ecs (concaténé + )");

# %%
# Analyse de la variable  "adedpe202006_logtype_perc_surf_vitree_ext"=> Pourcentage de surface vitrée d'un logement du bâtiment
df_selec_2["adedpe202006_logtype_perc_surf_vitree_ext"].describe()
# Out:
# count   15801.000000
# mean        0.279824
# std         0.161936
# min         0.000000
# 25%         0.153000
# 50%         0.258000
# 75%         0.369000
# max         0.937000
# Name: adedpe202006_logtype_perc_surf_vitree_ext, dtype: float64

# %%
df_selec_2["adedpe202006_logtype_perc_surf_vitree_ext"].isna().sum()
# Out:
# 86776

# %%
# Suppression de cette variable compte tenu du nombre de nan
df_selec_2=df_selec_2.drop("adedpe202006_logtype_perc_surf_vitree_ext", axis=1)

# %%
# Analyse de la variable  "adedpe202006_logtype_ph_pos_isol"=> Type d'isolation de la toiture du bâtiment
df_selec_2["adedpe202006_logtype_ph_pos_isol"].value_counts(ascending=False).to_frame()
# Out:
#            adedpe202006_logtype_ph_pos_isol
# non isole                             57936
# ITI                                   15785
# ITE                                     450
# isole                                   183
# ITE+ITI                                  35

# %%
df_selec_2["adedpe202006_logtype_ph_pos_isol"].isna().sum()
# Out:
# 28188

# %%
# Remplacement des nans par une classe inconnue
df_selec_2["adedpe202006_logtype_ph_pos_isol"]=df_selec_2["adedpe202006_logtype_ph_pos_isol"].fillna("Inconnu")

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='adedpe202006_logtype_ph_pos_isol', data=df_selec_2, palette="Set2", order = df_selec_2['adedpe202006_logtype_ph_pos_isol'].value_counts().index)
plt.title("Type d'isolation de la toiture du bâtiment auquel appartient l'appart qui a muté")
plt.xticks(rotation=45)
plt.xlabel("Type d'isolation de la toiture");

# %%
# Variable qui ne nous semble pas pertinente => on l'annule
df_selec_2=df_selec_2.drop("adedpe202006_logtype_ph_pos_isol", axis=1)

# %%
# Analyse de la variable "adedpe202006_logtype_presence_balcon"=> présence de balcons dans les logements du bâtiment
df_selec_2["adedpe202006_logtype_presence_balcon"].value_counts(ascending=False)
# Out:
# 0.000000    16071
# 1.000000     1201
# Name: adedpe202006_logtype_presence_balcon, dtype: int64

# %%
df_selec_2["adedpe202006_logtype_presence_balcon"].isna().sum()
# Out:
# 85305

# %%
# Trop de Nan => suppression de la variable
df_selec_2=df_selec_2.drop("adedpe202006_logtype_presence_balcon", axis=1)

# %%
# Analyse de la variable  "adedpe202006_logtype_presence_climatisation"=> Booléen présence de climatisation dans le bâtiment
df_selec_2["adedpe202006_logtype_presence_climatisation"].value_counts(ascending=False)
# Out:
# 0.000000    97525
# 1.000000     1482
# Name: adedpe202006_logtype_presence_climatisation, dtype: int64

# %%
df_selec_2["adedpe202006_logtype_presence_climatisation"].isna().sum()
# Out:
# 3570

# %%
# Remplacement des nan par le mode le plus fréquent
df_selec_2["adedpe202006_logtype_presence_climatisation"]=df_selec_2["adedpe202006_logtype_presence_climatisation"].fillna(df_selec_2["adedpe202006_logtype_presence_climatisation"].mode()[0])

# %%
# Suppression de cette variable parce qu'elle n'est pas représentative 
# => il suffit d'une climatisation dans le bâtiment pour que ce soit un oui

df_selec_2=df_selec_2.drop("adedpe202006_logtype_presence_climatisation", axis=1)

# %%
# Analyse de la variable  "adedpe202006_logtype_type_batiment"=> Type de construction (batiment)
df_selec_2["adedpe202006_logtype_type_batiment"].value_counts(ascending=False)
# Out:
# Appartement             89852
# Non résidentiel          4046
# Maison                   3792
# Logements collectifs     1220
# Centres commerciaux        97
# Name: adedpe202006_logtype_type_batiment, dtype: int64

# %%
df_selec_2["adedpe202006_logtype_type_batiment"].isna().sum()
# Out:
# 3570

# %%
# Remplacement des nans par le mode le plus fréquent
df_selec_2["adedpe202006_logtype_type_batiment"]=df_selec_2["adedpe202006_logtype_type_batiment"].fillna(df_selec_2["adedpe202006_logtype_type_batiment"].mode()[0])

# %%
# Suppression de cette variable parce que difficile à interpréter

df_selec_2=df_selec_2.drop("adedpe202006_logtype_type_batiment", axis=1)

# %%
# Analuse de la variable  "ancqpv201410_is_qpv"=> Est-ce que le bâtiment est dans un quartier prioritaire de la ville ?
df_selec_2["ancqpv201410_is_qpv"].value_counts(ascending=False)
# Out:
# 0.000000    99214
# 1.000000     3173
# Name: ancqpv201410_is_qpv, dtype: int64

# %%
df_selec_2["ancqpv201410_is_qpv"].isna().sum()
# Out:
# 190

# %%
# Suppression de la variable parce que très déséquilibrée
df_selec_2=df_selec_2.drop("ancqpv201410_is_qpv", axis=1)

# %%
# Analyse de la variable  "cerffo2020_annee_construction"=> Année de construction du bâtiment
df_selec_2["cerffo2020_annee_construction"].value_counts(ascending=False).to_frame()
# Out:
#            cerffo2020_annee_construction
# <1948                              75935
# 1948-1974                          10279
# 1974-2000                           4458
# >2000                               2880

# %%
df_selec_2["cerffo2020_annee_construction"].isna().sum()
# Out:
# 9025

# %%
# Remplacement des nans par le mode le plus fréquent
df_selec_2["cerffo2020_annee_construction"]=df_selec_2["cerffo2020_annee_construction"].fillna(df_selec_2["cerffo2020_annee_construction"].mode()[0])

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='cerffo2020_annee_construction', data=df_selec_2, palette="Paired", order = df_selec_2['cerffo2020_annee_construction'].value_counts().index)
plt.title("Périodes de construction du bâtiment auquel appartient l'appart qui a muté")
plt.xticks(rotation=45)
plt.xlabel("Périodes de construction du bâtiment");

# %%
g=df_selec_2.groupby("cerffo2020_annee_construction", as_index=False).agg({"Revente":"mean"})
g
# Out:
#   cerffo2020_annee_construction  Revente
# 0                     1948-1974 0.167526
# 1                     1974-2000 0.158367
# 2                         <1948 0.191902
# 3                         >2000 0.180208

# %%
plt.figure(figsize=(15,15))
sns.catplot(x = 'cerffo2020_annee_construction', y = 'Revente', kind="bar", data = g, order=["<1948", "1948-1974", "1974-2000", ">2000"])
plt.xticks(rotation=60)
plt.xlabel("Période de construction")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot \n selon sa période de construction", fontsize=15);

# %%
# Analyse de la variable  "cerffo2020_usage_niveau_1_txt"=> indicateurs d'usage simplifié du bâtiment 
df_selec_2["cerffo2020_usage_niveau_1_txt"].value_counts(ascending=False)
# Out:
# Résidentiel collectif     100121
# Tertiaire & Autres          2158
# Résidentiel individuel       279
# Autres                        19
# Name: cerffo2020_usage_niveau_1_txt, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='cerffo2020_usage_niveau_1_txt', data=df_selec_2, palette="husl", order = df_selec_2['cerffo2020_usage_niveau_1_txt'].value_counts().index)
plt.title("Indicateurs d'usage simplifié du bâtiment auquel appartient l'appartement qui a muté")
plt.xticks(rotation=45)
plt.xlabel("Indicateurs d'usage simplifié du bâtiment");

# %%
# Suppression de cette variable pq très déséuilibrée et pq la variable "Commerces_bruyants" nous donne 
# déjà une info sur l'utilisation en tertiaire de ce niveau 1
df_selec_2=df_selec_2.drop("cerffo2020_usage_niveau_1_txt", axis=1)

# %%
# Analyse de la variable  "cerffo2020_nb_log"=> (ffo) Nombre de logements dans le bâtiment

# %%
df_selec_2["cerffo2020_nb_log"].describe()
# Out:
# count   102577.000000
# mean        44.403375
# std         68.128363
# min          0.000000
# 25%         16.000000
# 50%         25.000000
# 75%         44.000000
# max        964.000000
# Name: cerffo2020_nb_log, dtype: float64

# %%
df_selec_2[df_selec_2["cerffo2020_nb_log"]==0].shape
# Out:
# (115, 38)

# %%
g=sns.catplot(x="cerffo2020_nb_log", kind="box", data=df_selec_2)
plt.title("Distribution du nombre de logements par bâtiment", fontsize=15)
plt.xlabel('Nombre de logements');

# %%
# Suppression des valeurs extrêmes
df_selec_2=df_selec_2[(df_selec_2["cerffo2020_nb_log"]>1)&(df_selec_2["cerffo2020_nb_log"]<600)]

# %%
g=sns.catplot(x="cerffo2020_nb_log", kind="box", data=df_selec_2)
plt.title("Distribution du nombre de logements par bâtiment", fontsize=15)
plt.xlabel('Nombre de logements');

# %%
df_selec_2.groupby("cerffo2020_annee_construction").agg({"cerffo2020_nb_log" :'mean'})
# Out:
#                                cerffo2020_nb_log
# cerffo2020_annee_construction
# 1948-1974                             100.676349
# 1974-2000                              85.091586
# <1948                                  33.718861
# >2000                                  57.405585

# %%
# Nb de logements construits par bâtiment, selon les périodes

plt.figure(figsize=(15,15))
sns.catplot(x = 'cerffo2020_annee_construction', y = 'anarnc202012_nb_log', kind="bar", data = df_selec_2, order=df_selec_2["cerffo2020_annee_construction"].value_counts().index)
plt.xticks(rotation=45)
plt.xlabel('Période construction')
plt.ylabel('Nb de logements par bâtiment')
plt.title('Quantité de logements par bâtiment \nselon les périodes de construction', fontsize=15);

# %%
# Analyse de la variable  "georad2020_alea"=> Niveau de risque radon
df_selec_2["georad2020_alea"].value_counts(ascending=False)
# Out:
# Faible    101950
# Name: georad2020_alea, dtype: int64

# %%
df_selec_2["georad2020_alea"].isna().sum()
# Out:
# 188

# %%
# Pas d'intérêt. Suppression
df_selec_2=df_selec_2.drop("georad2020_alea", axis=1)

# %%
# Analyse de la variable  "igntop202103_bat_hauteur"=> Hauteur du bâtiment [m]
df_selec_2["igntop202103_bat_hauteur"].describe().to_frame()
# Out:
#        igntop202103_bat_hauteur
# count             101937.000000
# mean                  20.636245
# std                    7.076138
# min                    0.000000
# 25%                   17.200000
# 50%                   20.100000
# 75%                   23.000000
# max                  104.000000

# %%
df_selec_2["igntop202103_bat_hauteur"].isna().sum()
# Out:
# 201

# %%
# Remplacement des Nan par la médiane
df_selec_2["igntop202103_bat_hauteur"]=df_selec_2["igntop202103_bat_hauteur"].fillna(df_selec_2["igntop202103_bat_hauteur"].median())

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df_selec_2["igntop202103_bat_hauteur"])
plt.title("Hauteur du bâtiment")
plt.xlabel("Hauteur du bâtiment");
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Suppression des valeurs aberrantes
df_selec_2=df_selec_2[df_selec_2["igntop202103_bat_hauteur"]>4]

# %%
# Hauteur des bâtiments construits selon les périodes

plt.figure(figsize=(15,15))
sns.catplot(x = 'cerffo2020_annee_construction', y = 'igntop202103_bat_hauteur', kind="bar", data = df_selec_2, order=df_selec_2["cerffo2020_annee_construction"].value_counts().index)
plt.xticks(rotation=45)
plt.xlabel('Période construction')
plt.ylabel('Huteur des bâtiments en m')
plt.title('Hauteur des bâtiments \n selon périodes de construction', fontsize=15);

# %%
df_selec_2["cerffo2020_annee_construction"].value_counts()
# Out:
# <1948        84229
# 1948-1974    10048
# 1974-2000     4421
# >2000         2809
# Name: cerffo2020_annee_construction, dtype: int64

# %%
#Création d'une variable "Nbre d'étages"
#La hauteur des étages la plus standard correspond au type de fonction du bâtiment, tour ou édifice :
#2,66 mètres, soit 16 marches pour un immeuble d'habitation récent, hôtel ou parking ;
#3 mètres, soit 18 marches pour un immeuble d'habitation ancien ;

# Source : https://fr.wikipedia.org/wiki/%C3%89tage_(architecture)

df_selec_2["nbre_etages_ancien"]=round(df_selec_2.loc[df_selec_2["cerffo2020_annee_construction"]=="<1948"]["igntop202103_bat_hauteur"]/3)
df_selec_2["nbre_etages_recent"]=round(df_selec_2.loc[(df_selec_2["cerffo2020_annee_construction"]=="1948-1974")|
                                           (df_selec_2["cerffo2020_annee_construction"]=="1974-2000")|
                                           (df_selec_2["cerffo2020_annee_construction"]==">2000")]["igntop202103_bat_hauteur"]/2.66)

# %%
df_selec_2["nbre_etages_ancien"].isna().sum()
# Out:
# 17278

# %%
df_selec_2["nbre_etages_ancien"]=df_selec_2["nbre_etages_ancien"].fillna(0)

# %%
df_selec_2["nbre_etages_recent"].isna().sum()
# Out:
# 84229

# %%
df_selec_2["nbre_etages_recent"]=df_selec_2["nbre_etages_recent"].fillna(0)

# %%
df_selec_2["nbre_etages"]=df_selec_2["nbre_etages_ancien"]+ df_selec_2["nbre_etages_recent"]

# %%
df_selec_2["nbre_etages"].isna().sum()
# Out:
# 0

# %%
df_selec_2["nbre_etages"].value_counts()
# Out:
# 7.000000     26528
# 6.000000     23569
# 8.000000     15824
# 5.000000     10642
# 9.000000      6919
# 4.000000      4617
# 10.000000     3283
# 3.000000      2236
# 11.000000     2052
# 12.000000     1541
# 2.000000      1223
# 14.000000      832
# 13.000000      737
# 15.000000      392
# 17.000000      199
# 20.000000      145
# 16.000000      122
# 18.000000       94
# 1.000000        90
# 28.000000       84
# 29.000000       71
# 30.000000       55
# 23.000000       52
# 24.000000       46
# 27.000000       26
# 33.000000       25
# 19.000000       24
# 25.000000       23
# 36.000000       19
# 39.000000       18
# 21.000000       15
# 22.000000        4
# Name: nbre_etages, dtype: int64

# %%
# On regroupe 

def filtre (x) :
    if x >=0 and x <4 :
        return "De 0 à 3"
    elif x>=4 and x <8 :
        return "De 4 à 7"
    elif x>=8 and x<=10 :
        return "De 8 à 10"
    else :
        return " >10"
    
df_selec_2["nbre_etages"]=df_selec_2["nbre_etages"].apply(filtre)
df_selec_2["nbre_etages"].value_counts()
# Out:
# De 4 à 7     65356
# De 8 à 10    26026
#  >10          6576
# De 0 à 3      3549
# Name: nbre_etages, dtype: int64

# %%
df_selec_2["nbre_etages"].value_counts().to_frame()
# Out:
#            nbre_etages
# De 4 à 7         65356
# De 8 à 10        26026
#  >10              6576
# De 0 à 3          3549

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='nbre_etages', data=df_selec_2, order=["De 0 à 3", "De 4 à 7", "De 8 à 10", " >10"])
plt.title("Nombre d'étages par bâtiment", fontsize=15)
plt.xticks(rotation=60)
plt.xlabel("Nombre d'étages");

# %%
# Suppression des variables "nbre_etages_ancien" et nbre_etages_recent

df_selec_2=df_selec_2.drop(["nbre_etages_ancien", "nbre_etages_recent"], axis=1)

# %%
# Analyse de la variable  "mcumer202007_is_mer"=> 
# Le bâtiment est situé dans un périmètre ABF monument historique ? (<= 500 m)
df_selec_2["mcumer202007_is_mer"].value_counts(ascending=False).to_frame()
# Out:
#           mcumer202007_is_mer
# 1.000000                96123
# 0.000000                 5196

# %%
df_selec_2["mcumer202007_is_mer"].isna().sum()
# Out:
# 188

# %%
# Remplacement des Nan par la médiane
df_selec_2["mcumer202007_is_mer"]=df_selec_2["mcumer202007_is_mer"].fillna(df_selec_2["mcumer202007_is_mer"].median())

# %%
plt.figure(figsize=(7,7))
x=df_selec_2["mcumer202007_is_mer"].value_counts()

plt.pie(x, labels=["Dans périmètre ABF", "Hors périmètre ABF"], 
        colors=["#e0c0f7", "#84ae57"], 
        explode=[0.05,0.05],
        autopct=lambda x : str(round(x,2))+ "%", 
        pctdistance=0.7, 
        shadow=True)
plt.title("Proportion de bâtiments dans un périmètre ABF monument historique", fontsize=15)
plt.legend(loc="best");

# %%
# Analyse de la variable  "adedpe202006_logtype_s_hab"=> Surface habitable du DPE
df_selec_2["adedpe202006_logtype_s_hab"].describe()
# Out:
# count   97835.000000
# mean       74.111565
# std       367.441220
# min         0.000000
# 25%        30.000000
# 50%        43.000000
# 75%        62.000000
# max     15999.000000
# Name: adedpe202006_logtype_s_hab, dtype: float64

# %%
df_selec_2["adedpe202006_logtype_s_hab"].isna().sum()
# Out:
# 3672

# %%
# On a déjà 2 variables d'indication de surface. Suppression de celle-ci
df_selec_2=df_selec_2.drop("adedpe202006_logtype_s_hab", axis=1)

# %%
# Analyse de la variable "Commerces_bruyants"
df_selec_2["Commerces_bruyants"].unique()
# Out:
# array([1, 0, 2, 3], dtype=int64)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Commerces_bruyants', data=df_selec_2)
plt.title("Nombre de commerces bruyants dans le bâtiment", fontsize=15)
plt.xticks(rotation=60)
plt.xlabel("Nombre de commerces bruyants");

# %%
g=df_selec_2.groupby("Commerces_bruyants").agg({"Revente":"mean"})
g
# Out:
#                     Revente
# Commerces_bruyants
# 0                  0.186141
# 1                  0.192747
# 2                  0.190134
# 3                  0.167082

# %%
list_equip=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(8,8))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#71d3de")
plt.xticks(x_ticks, list_equip, rotation=60)
plt.xlabel("Nombre de commerces bruyants dans le bâtiment")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot selon le nombre de commerces bruyants \n  dans le bâtiment, sur la période 2014-2021", fontsize=15);

# %%
df_selec_2["qty_of_mut"].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df_selec_2["qty_of_mut"].value_counts()
# Out:
# 0    82436
# 1    17816
# 2     1211
# 3       44
# Name: qty_of_mut, dtype: int64

# %%
plt.figure(figsize=(10,5))

sns.countplot(x='qty_of_mut', data=df_selec_2, palette="Set2")
plt.title("Nbre de reventes par lot, sur la période 2014-2021", fontsize=20)
plt.xlabel("Nbre de reventes par lot ")

plt.xticks(rotation=45);

# %%
df_selec_2["anneemut"].value_counts().to_frame().sort_index()
# Out:
#       anneemut
# 2014     10627
# 2015     12957
# 2016     12519
# 2017     14528
# 2018     13365
# 2019     13923
# 2020     11193
# 2021     12395

# %%
plt.figure(figsize=(10,5))

sns.countplot(x='anneemut', data=df_selec_2, palette="husl")
plt.title("Nbre de mutations par année", fontsize=20)
plt.xlabel("Nbre de mutations par année")

plt.xticks(rotation=45);

# %%
#Valeur foncière en fonction de l'arrondissement
plt.figure(figsize=(20,20))
sns.catplot(x = 'l_codinsee', y = 'valeurfonc', kind="bar", height=8, data = df_selec_2)
plt.xticks(rotation=45)
plt.xlabel('Arrondissement')
plt.ylabel('Valeur foncière en €')
plt.title('Valeur moyenne des transactions par arrondissement', fontsize=20);

# %%
# Le graphique précédent représente la moyenne des valeurs des transactions, sur la période 2014-2021, par arrondissement. 
# Un même bien peut donc y être représenté plusieurs fois s'il a été revendu pendant la période. Faisons une coupe transervale 
# sur les transactions de 2017 par exemple

selec=df_selec_2[df_selec_2["anneemut"]==2017]
plt.figure(figsize=(20,20))
sns.catplot(x = 'l_codinsee', y = 'valeurfonc', kind="bar", height=8, data = selec)
plt.xticks(rotation=45)
plt.xlabel('Arrondissement')
plt.ylabel('Valeur foncière en €')
plt.title('Valeur moyenne des transactions en 2017, par arrondissement', fontsize=20);

# %%
#Valeur en fonction de l'arrondissement et par type d'appartement
plt.figure(figsize=(8,8))
sns.catplot(x = 'l_codinsee', y = 'valeurfonc', kind="bar", hue = "Type_appart", height=8, data = df_selec_2)
plt.xticks(rotation=45)
plt.xlabel('Arrondissement')
plt.ylabel('Valeur foncière en €')
plt.title("Valeur moyenne des transactions par arrondissement \n selon type d'appartement \n sur la période 2014-2021", fontsize=15);

# %%
# Même remarque que pour graphique précédent. Faisons une coupe transervale sur les transactions de 2018 par exemple

selec=df_selec_2[df_selec_2["anneemut"]==2018]
#Valeur en fonction de l'arrondissement et par type d'appartement
plt.figure(figsize=(8,8))
sns.catplot(x = 'l_codinsee', y = 'valeurfonc', kind="bar", hue = "Type_appart", height=8, data = selec)
plt.xticks(rotation=45)
plt.xlabel('Arrondissement')
plt.ylabel('Valeur foncière en €')
plt.title("Valeur moyenne des transactions par arrondissement \n selon type d'appartement en 2018", fontsize=15);

# %%
# Revente selon surface Carrez
plt.figure(figsize=(5,5))
sns.catplot(x = 'Revente', y = 'scarrez', kind="bar", data = df_selec_2)
plt.xlabel('Revente sur la période 2014 -2021')
plt.ylabel('Surface loi Carrez en m²')
plt.title('Revente selon surface', fontsize=20);

# %%
# Faire des catégories de surface et regarder la proportion de vendu ou pas pour chaque catégorie
df_selec_2["scarrez"].describe()
# Out:
# count   101507.000000
# mean        48.123070
# std         19.227589
# min          0.300000
# 25%         34.235000
# 50%         45.080000
# 75%         58.560000
# max        215.000000
# Name: scarrez, dtype: float64

# %%
df_selec_2["cat_scarrez"]=pd.cut(df_selec_2["scarrez"], 
bins=[0, 35, 47, 60,215], 
labels=["<35 m²", "Entre 35 & 47 m²", "Entre 47 & 60m²", ">60m²"])

# %%
df_selec_2["cat_scarrez"].value_counts().to_frame()
# Out:
#                   cat_scarrez
# Entre 35 & 47 m²        27655
# <35 m²                  27094
# >60m²                   23533
# Entre 47 & 60m²         23225

# %%
df_selec_2["cat_scarrez"].value_counts().index
# Out:
# CategoricalIndex(['Entre 35 & 47 m²', '<35 m²', '>60m²', 'Entre 47 & 60m²'], categories=['<35 m²', 'Entre 35 & 47 m²', 'Entre 47 & 60m²', '>60m²'], ordered=True, dtype='category')

# %%
plt.figure(figsize=(10,10))
x=df_selec_2["cat_scarrez"].value_counts()
lab=df_selec_2["cat_scarrez"].value_counts().index
color=["#e0c0f7", "#84ae57","#90aacc","#fd9283"]
plt.pie(x, labels=lab, 
        colors=color, 
        explode=[0.05,0.05,0.05,0.05],
        autopct=lambda x : str(round(x,2))+ "%", 
        pctdistance=0.7, 
        shadow=True)
plt.title("Surface loi Carrez des appartements", fontsize=15)
plt.legend(loc="best");

# %%
g=df_selec_2.groupby("cat_scarrez").agg({"Revente":"mean"})
g
# Out:
#                   Revente
# cat_scarrez
# <35 m²           0.168045
# Entre 35 & 47 m² 0.189731
# Entre 47 & 60m²  0.210807
# >60m²            0.185909

# %%
list_scarrez=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(5,5))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#aedaed")
plt.xticks(x_ticks, list_scarrez, rotation=60)
plt.xlabel("Catégorie Surface Loi Carrez")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot selon sa surface Carrez \n sur la période 2014-2021", fontsize=10);

# %%
# Valeur foncière selon année de construction 

plt.figure(figsize=(5,5))
sns.catplot(x = 'cerffo2020_annee_construction', y = 'valeurfonc', hue="Type_appart", kind="bar", data = df_selec_2, order=["<1948", "1948-1974", "1974-2000", ">2000"])
plt.xticks(rotation=45)
plt.xlabel('Année de construction')
plt.ylabel('Valeur foncière en €')
plt.title('Valeur moyenne des transactions sur la période 2014-2021, \n selon année de construction du bâtiment ', fontsize=15);

# %%
# Le graphique précédent représente la moyenne des valeurs des transactions, sur la période 2014-2021,
# selon la période de construction du bâtiment.
# Faisons une coupe transervale sur l'année 2019

selec=df_selec_2[df_selec_2["anneemut"]==2019]
plt.figure(figsize=(5,5))
sns.catplot(x = 'cerffo2020_annee_construction', y = 'valeurfonc', hue="Type_appart", kind="bar", data = selec, order=["<1948", "1948-1974", "1974-2000", ">2000"])
plt.xticks(rotation=45)
plt.xlabel('Année de construction')
plt.ylabel('Valeur foncière en €')
plt.title('Valeur moyenne des transactions en 2019, \n selon année de construction du bâtiment ', fontsize=15);

# %%
#Valeur foncière selon classe énergétique

plt.figure(figsize=(8,8))
sns.catplot(x = 'adedpe202006_mean_class_conso_ener', 
            y = 'valeurfonc', 
            kind="bar", 
            data = df_selec_2, 
            order=df_selec_2["adedpe202006_mean_class_conso_ener"].value_counts().index.sort_values())
plt.xticks(rotation=45)
plt.xlabel('Classe de consommation énergetique')
plt.ylabel('Valeur foncière (€)')
plt.title("Valeur moyenne des transactions selon \n classe énergétique moyenne du bâtiment", fontsize=15);

# %%
# Faisons une coupe transervale sur l'année 2018
selec=df_selec_2[df_selec_2["anneemut"]==2018]
plt.figure(figsize=(8,8))
sns.catplot(x = 'adedpe202006_mean_class_conso_ener', 
            y = 'valeurfonc', 
            kind="bar", 
            data = selec, 
            order=df_selec_2["adedpe202006_mean_class_conso_ener"].value_counts().index.sort_values())
plt.xticks(rotation=45)
plt.xlabel('Classe de consommation énergetique')
plt.ylabel('Valeur foncière (€)')
plt.title("Valeur moyenne des transactions en 2018 selon \n classe énergétique moyenne du bâtiment", fontsize=15);

# %%
#Valeur foncière selon la Classe de consommation GES DPE d'un logement représentatif du bâtiment
plt.figure(figsize=(8,8))
sns.catplot(x = 'adedpe202006_mean_class_estim_ges', 
            y = 'valeurfonc', 
            kind="bar", 
            data = df_selec_2, 
            order=df_selec_2["adedpe202006_mean_class_estim_ges"].value_counts().index.sort_values())
plt.xticks(rotation=45)
plt.xlabel('Classe de consommation GES DPE')
plt.ylabel('Valeur foncière (€)')
plt.title("Valeur moyenne des transactions selon \n la classe GES moyenne du bâtiment", fontsize=15);

# %%
# Relation entre hauteur et nombre de logements dans le bâtiment

plt.figure(figsize=(15,15))
sns.relplot(x="cerffo2020_nb_log", y="igntop202103_bat_hauteur", data=df_selec_2, s=2, palette=["b", "r"]);
plt.xlabel("Hauteur du bâtiment (m)")
plt.ylabel("Nombre de logements dans le bâtiment")
plt.title("Relation entre hauteur et \n nombre de logements dans le bâtiment", fontsize=15);

# %%
# Valeur foncière moyenne par année de transaction
sns.catplot(x = 'anneemut', 
            y = 'valeurfonc', 
            kind="bar", 
            data = df_selec_2)
            
plt.xticks(rotation=45)
plt.xlabel('Année')
plt.ylabel('Valeur foncière (€)')
plt.title("Valeur moyenne des transactions entre 2014 et 2021", fontsize=15);

# %%
# Valeur foncière moyenne par année de transaction
sns.catplot(x = 'anneemut', 
            y = 'valeurfonc', 
            kind="bar", 
            hue="Type_appart",
            data = df_selec_2)
            
plt.xticks(rotation=45)
plt.xlabel('Année')
plt.ylabel('Valeur foncière (€)')
plt.title("Valeur moyenne des transactions entre 2014 et 2021 \n selon le type d'appartement", fontsize=15);

# %%
# Analyse de la variable  "adedpe202006_logtype_ch_type_inst"=> Type d'installation de chauffage

# %%
df_selec_2["adedpe202006_logtype_ch_type_inst"].isna().sum()
# Out:
# 16262

# %%
df_selec_2["adedpe202006_logtype_ch_type_inst"]=df_selec_2["adedpe202006_logtype_ch_type_inst"].fillna("Inconnu")

# %%
plt.figure(figsize=(5,5))
sns.countplot(x = 'adedpe202006_logtype_ch_type_inst', data = df_selec_2, palette="husl");
plt.title("Type d'installation de chauffage dans le bâtiment")
plt.xlabel("Type d'installation de chauffage");

# %%
g=df_selec_2.groupby("adedpe202006_logtype_ch_type_inst").agg({"Revente":"mean"})
g
# Out:
#                                    Revente
# adedpe202006_logtype_ch_type_inst
# Inconnu                           0.179806
# collectif                         0.170635
# individuel                        0.195033

# %%
list_chauffage=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(5,5))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#aedaed")
plt.xticks(x_ticks, list_chauffage, rotation=60)
plt.xlabel("Type chauffage")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot selon type de chauffage du bâtiment \n sur la période 2014-2021", fontsize=10);

# %%
# Groupby pour voir dans le détail le type d'installation

df_selec_2.groupby(["adedpe202006_logtype_ch_type_inst", "adedpe202006_logtype_ch_gen_lib_princ"]).agg({"adedpe202006_logtype_ch_gen_lib_princ":"count"})
# Out:
#                                                                          adedpe202006_logtype_ch_gen_lib_princ
# adedpe202006_logtype_ch_type_inst adedpe202006_logtype_ch_gen_lib_princ
# Inconnu                           chaudière fioul                                                          223
#                                   chaudière gaz                                                           3136
#                                   chaudière électrique                                                   11965
#                                   indeterminé                                                              563
#                                   réseau de chaleur                                                        375
# collectif                         chaudière fioul                                                         1888
#                                   chaudière gaz                                                          13157
#                                   chaudière électrique                                                     442
#                                   indeterminé                                                              131
#                                   réseau de chaleur                                                       3997
# individuel                        chaudière fioul                                                          370
#                                   chaudière gaz                                                          20116
#                                   chaudière électrique                                                   42842
#                                   indeterminé                                                             1145
#                                   réseau de chaleur                                                       1157

# %%
j=df_selec_2.groupby(["adedpe202006_logtype_ch_type_inst", "adedpe202006_logtype_ch_gen_lib_princ"]).agg({"adedpe202006_logtype_ch_gen_lib_princ":"count"})
plt.figure(figsize=(10,8))

plt.subplot(221)
list_index_col=j.iloc[5:10,:].index.tolist()
list_index_col=["chaudière fioul", "chaudière gaz", "chaudière électrique", "indeterminé", "réseau de chaleur"]
x_ticks=np.arange(len(j.iloc[5:10,:]))
plt.bar(range(len(j.iloc[5:10,:])), j.iloc[5:10,:]["adedpe202006_logtype_ch_gen_lib_princ"], linewidth=5, color="#c0ffc9")
plt.xticks(x_ticks, list_index_col, rotation=60)
plt.xlabel("Type d'installation de chauffage")
plt.ylabel("Nombre")
plt.title("Type d'installation de chauffage collectif", fontsize=10)

plt.subplot(222)
list_index_ind=j.iloc[10:,:].index.tolist()
list_index_ind=["chaudière fioul", "chaudière gaz", "chaudière électrique", "indeterminé", "réseau de chaleur"]
x_ticks=np.arange(len(j.iloc[10:,:]))
plt.bar(range(len(j.iloc[10:,:])), j.iloc[10:,:]["adedpe202006_logtype_ch_gen_lib_princ"], linewidth=5, color="#ffb7cb")
plt.xticks(x_ticks, list_index_ind, rotation=60)
plt.xlabel("Type d'installation de chauffage")
plt.ylabel("Nombre")
plt.title("Type d'installation de chauffage individuel", fontsize=10)

plt.tight_layout(4)
plt.show()
# Out:
# C:\Users\Anne\AppData\Local\Temp/ipykernel_3380/3718029404.py:24: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %%
# Nous décidons de ne pas prendre cette variable "adedpe202006_logtype_ch_gen_lib_princ" dans la modélisation pq
# ce qui nous semble sutout déterminant c'est le fait que le chauffage soit collectif ou individuel

df_selec_2=df_selec_2.drop("adedpe202006_logtype_ch_gen_lib_princ", axis=1)

# %%
# Analyse de la variable "adedpe202006_logtype_ecs_type_inst"=> Type d'installation d'ECS (individuelle ou collective)

df_selec_2["adedpe202006_logtype_ecs_type_inst"].value_counts().to_frame()
# Out:
#             adedpe202006_logtype_ecs_type_inst
# individuel                               69312
# collectif                                16967

# %%
df_selec_2["adedpe202006_logtype_ecs_type_inst"].isna().sum()
# Contrôle absence d'anomlies, fait en NB 1
# Out:
# 15228

# %%
# On remplace les Nan par Inconnu
df_selec_2["adedpe202006_logtype_ecs_type_inst"]=df_selec_2["adedpe202006_logtype_ecs_type_inst"].fillna("Inconnu")

# %%
plt.figure(figsize=(5,5))
sns.countplot(x = 'adedpe202006_logtype_ecs_type_inst', data = df_selec_2, palette="husl");
plt.title("Type d'installation d'ECS dans le bâtiment")
plt.xlabel("Type d'installation d'ECS");

# %%
g=df_selec_2.groupby("adedpe202006_logtype_ecs_type_inst").agg({"Revente":"mean"})
g
# Out:
#                                     Revente
# adedpe202006_logtype_ecs_type_inst
# Inconnu                            0.174481
# collectif                          0.165792
# individuel                         0.196229

# %%
list_ecs=g.index.tolist()
x_ticks=np.arange(len(g))

# %%
plt.figure(figsize=(5,5))
plt.bar(range(len(g)), g["Revente"], linewidth=5, color="#aedaed")
plt.xticks(x_ticks, list_ecs, rotation=60)
plt.xlabel("Type ECS")
plt.ylabel("Proportion de revente")
plt.title("Proportion de revente d'un lot selon type d'ECS du bâtiment \n sur la période 2014-2021", fontsize=10);

# %%
# Groupby pour voir dans le détail le type d'installation

df_selec_2.groupby(["adedpe202006_logtype_ecs_type_inst", "adedpe202006_logtype_ecs_type_ener"]).agg({"adedpe202006_logtype_ecs_type_ener":"count"})
# Out:
#                                                                                   adedpe202006_logtype_ecs_type_ener
# adedpe202006_logtype_ecs_type_inst adedpe202006_logtype_ecs_type_ener
# Inconnu                            autres                                                                         15
#                                    bois                                                                            9
#                                    ecs thermodynamique electrique(pac ou ballon)                                  18
#                                    electricite                                                                 10854
#                                    fioul                                                                         203
#                                    gaz                                                                          3904
#                                    reseau de chaleur                                                             225
# collectif                          autres                                                                         65
#                                    bois                                                                            4
#                                    ecs thermodynamique electrique(pac ou ballon)                                   4
#                                    electricite                                                                   961
#                                    fioul                                                                        1280
#                                    gaz                                                                         10090
#                                    reseau de chaleur                                                            4563
# individuel                         autres                                                                         76
#                                    bois                                                                          127
#                                    ecs thermodynamique electrique(pac ou ballon)                                 257
#                                    electricite                                                                 48525
#                                    fioul                                                                         245
#                                    gaz                                                                         20061
#                                    reseau de chaleur                                                              21

# %%
g=df_selec_2.groupby(["adedpe202006_logtype_ecs_type_inst", "adedpe202006_logtype_ecs_type_ener"]).agg({"adedpe202006_logtype_ecs_type_ener":"count"})

# %%
plt.figure(figsize=(10,8))

plt.subplot(221)
list_index_col=g.iloc[7:14,:].index.tolist()
list_index_col=["autres", "bois", "ecs thermodynamique electrique(pac ou ballon)", "électricité", "fioul", "gaz", "reseau de chaleur"]
x_ticks=np.arange(len(g.iloc[7:14,:]))
plt.bar(range(len(g.iloc[7:14,:])), g.iloc[7:14,:]["adedpe202006_logtype_ecs_type_ener"], linewidth=5, color="#c0ffc9")
plt.xticks(x_ticks, list_index_col, rotation=60)
plt.xlabel("Type d'installation d'ECS")
plt.ylabel("Nombre")
plt.title("Type d'installation d'ECS collectif", fontsize=10)

plt.subplot(222)
list_index_ind=g.iloc[14:,:].index.tolist()
list_index_ind=["autres", "bois", "ecs thermodynamique electrique(pac ou ballon)", "électricité", "fioul", "gaz", "reseau de chaleur"]
x_ticks=np.arange(len(g.iloc[14:,:]))
plt.bar(range(len(g.iloc[14:,:])), g.iloc[14:,:]["adedpe202006_logtype_ecs_type_ener"], linewidth=5, color="#ffb7cb")
plt.xticks(x_ticks, list_index_ind, rotation=60)
plt.xlabel("Type d'installation d'ECS")
plt.ylabel("Nombre")
plt.title("Type d'installation d'ECS individuel", fontsize=10)

plt.tight_layout(4)
plt.show()
# Out:
# C:\Users\Anne\AppData\Local\Temp/ipykernel_3380/4142035953.py:23: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %%
# Comme pour le chauffage, ce qui va nous intéresser pour la mdoélisation, 
# c'est de savoir si le chauffage de l'eau est collectif ou individuel
# On supprime le type d'installation d'ECS pour la modélisation

df_selec_2=df_selec_2.drop("adedpe202006_logtype_ecs_type_ener", axis=1)

# %%
#Analyse de la variable "adedpe202006_logtype_mur_ep_mat_ext" 
# =>Epaisseur de la structure des murs la plus fréquente en surface

df_selec_2["adedpe202006_logtype_mur_ep_mat_ext"].value_counts()
# Out:
# 20 et -       6475
# Sans objet    2629
# 25            1355
# 30            1089
# 22.5           820
# 50             789
# 28             704
# 23             669
# 40             441
# 35             405
# 45             184
# 9 et -         166
# 34             157
# 19             128
# 20              67
# 15 et -         55
# 60              51
# 15              50
# 55              45
# 24              44
# 8 et -          39
# 12              34
# 38              27
# 33              25
# 5               23
# 18              19
# 40 et -         14
# 65              14
# 43               8
# 13               8
# 32               7
# 80               4
# 70               1
# Name: adedpe202006_logtype_mur_ep_mat_ext, dtype: int64

# %%
df_selec_2["adedpe202006_logtype_mur_ep_mat_ext"].isna().sum()
# Out:
# 84961

# %%
# 86% Nan. On supprime
df_selec_2=df_selec_2.drop("adedpe202006_logtype_mur_ep_mat_ext", axis=1)

# %%
#Analyse de la variable "adedpe202006_logtype_mur_mat_ext" => Matériaux de la structure des murs extérieurs

df_selec_2["adedpe202006_logtype_mur_mat_ext"].value_counts()
# Out:
# Mur en pierre               43449
# Mur en béton                24941
# Mur en brique               16097
# Indeterminé                 14036
# Mur en pan de bois           2671
# Mur en cloison de plâtre      313
# Name: adedpe202006_logtype_mur_mat_ext, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.countplot(x = 'adedpe202006_logtype_mur_mat_ext', data = df_selec_2, palette="husl", order=df_selec_2["adedpe202006_logtype_mur_mat_ext"].value_counts().index);
plt.title("Matériaux de la structure des murs extérieurs")
plt.xlabel("Matériaux de la structure des murs extérieurs")
plt.xticks(rotation=60);

# %%
# Croisement de cette variable avec période de construction

j=df_selec_2.groupby(["cerffo2020_annee_construction", "adedpe202006_logtype_mur_mat_ext"]).agg({"adedpe202006_logtype_mur_mat_ext":"count"})
j
# Out:
#                                                                 adedpe202006_logtype_mur_mat_ext
# cerffo2020_annee_construction adedpe202006_logtype_mur_mat_ext
# 1948-1974                     Indeterminé                                                    854
#                               Mur en brique                                                  514
#                               Mur en béton                                                  7701
#                               Mur en pan de bois                                              94
#                               Mur en pierre                                                  885
# 1974-2000                     Indeterminé                                                    406
#                               Mur en brique                                                  278
#                               Mur en béton                                                  2997
#                               Mur en cloison de plâtre                                         6
#                               Mur en pan de bois                                              54
#                               Mur en pierre                                                  680
# <1948                         Indeterminé                                                  12431
#                               Mur en brique                                                15048
#                               Mur en béton                                                 12926
#                               Mur en cloison de plâtre                                       306
#                               Mur en pan de bois                                            2447
#                               Mur en pierre                                                41071
# >2000                         Indeterminé                                                    345
#                               Mur en brique                                                  257
#                               Mur en béton                                                  1317
#                               Mur en cloison de plâtre                                         1
#                               Mur en pan de bois                                              76
#                               Mur en pierre                                                  813

# %%
plt.figure(figsize=(20,10))

plt.subplot(221)
list_index_col=j.iloc[11:17,:].index.tolist()
list_index_col=["Indeterminé", "Mur en brique", "Mur en béton", "Mur en cloison de plâtre", "Mur en pan de bois", "Mur en pierre"]
x_ticks=np.arange(len(j.iloc[11:17,:]))
plt.bar(range(len(j.iloc[11:17,:])), j.iloc[11:17,:]["adedpe202006_logtype_mur_mat_ext"], linewidth=5, color="#c0ffc9")
plt.xticks(x_ticks, list_index_col, rotation=60)
plt.ylabel("Nombre")
plt.title("Matériaux de la structure des murs extérieurs \n des bâtiments construits avant 1948", fontsize=10)

plt.subplot(222)
list_index_col=j.iloc[0:5,:].index.tolist()
list_index_col=["Indeterminé", "Mur en brique", "Mur en béton", "Mur en pan de bois", "Mur en pierre"]
x_ticks=np.arange(len(j.iloc[0:5,:]))
plt.bar(range(len(j.iloc[0:5,:])), j.iloc[0:5,:]["adedpe202006_logtype_mur_mat_ext"], linewidth=5, color="#c0ffc9")
plt.xticks(x_ticks, list_index_col, rotation=60)
plt.ylabel("Nombre")
plt.title("Matériaux de la structure des murs extérieurs \n des bâtiments construits entre 1948-1974", fontsize=10)


plt.subplot(223)
list_index_col=j.iloc[5:11,:].index.tolist()
list_index_col=["Indeterminé", "Mur en brique", "Mur en béton","Mur en cloison de plâtre", "Mur en pan de bois", "Mur en pierre"]
x_ticks=np.arange(len(j.iloc[5:11,:]))
plt.bar(range(len(j.iloc[5:11,:])), j.iloc[5:11,:]["adedpe202006_logtype_mur_mat_ext"], linewidth=5, color="#c0ffc9")
plt.xticks(x_ticks, list_index_col, rotation=60)
plt.xlabel("Matériaux de la structure des murs extérieurs")
plt.ylabel("Nombre")
plt.title("Matériaux de la structure des murs extérieurs \n des bâtiments construits entre 1974-2000", fontsize=10)

plt.subplot(224)
list_index_col=j.iloc[17:,:].index.tolist()
list_index_col=["Indeterminé", "Mur en brique", "Mur en béton", "Mur en cloison de plâtre", "Mur en pan de bois", "Mur en pierre"]
x_ticks=np.arange(len(j.iloc[17:,:]))
plt.bar(range(len(j.iloc[17:,:])), j.iloc[17:,:]["adedpe202006_logtype_mur_mat_ext"], linewidth=5, color="#c0ffc9")
plt.xticks(x_ticks, list_index_col, rotation=60)
plt.xlabel("Matériaux de la structure des murs extérieurs")
plt.ylabel("Nombre")
plt.title("Matériaux de la structure des murs extérieurs \n des bâtiments construits après 2000", fontsize=10)


plt.tight_layout(4)
plt.show()
# Out:
# C:\Users\Anne\AppData\Local\Temp/ipykernel_3380/2231142058.py:43: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(4)

# %%
# IRINA : Le code des figures ci-dessus n'est pas très propre. Cherchez mieux

# %%
#Analyse de la variable "adedpe202006_logtype_mur_pos_isol_ext" => Type d'isolation des murs
df_selec_2["adedpe202006_logtype_mur_pos_isol_ext"].value_counts()
# Out:
# ITI        82868
# Autres     12208
# Inconnu     5961
# ITE          328
# ITR          142
# Name: adedpe202006_logtype_mur_pos_isol_ext, dtype: int64

# %%
df_selec_2["adedpe202006_logtype_mur_pos_isol_ext"].isna().sum()
# Out:
# 0

# %%
type(df_selec_2["adedpe202006_logtype_mur_pos_isol_ext"].value_counts().index.tolist())
# Out:
# list

# %%
df_selec_2["adedpe202006_logtype_mur_pos_isol_ext"]=df_selec_2["adedpe202006_logtype_mur_pos_isol_ext"].fillna("Inconnu")

# %%
df_selec_2["adedpe202006_logtype_mur_pos_isol_ext"].index[0]
# Out:
# 7819809

# %%
plt.figure(figsize=(10,5))

sns.countplot(x='adedpe202006_logtype_mur_pos_isol_ext', data=df_selec_2, palette="Set3")
plt.title("Type d'isolation des murs", fontsize=15)
plt.xlabel("Type d'isolation des murs")
plt.xticks(rotation=60);

# %%
# Suppression de la variable #anarnc202012_nb_log dont on n'a plus besoin et qui sera redondante avec "Taille copro"

df_selec_2=df_selec_2.drop("anarnc202012_nb_log", axis=1)

# %%
# La variable "Hauteur de bâtiment n'a plus d'intérêt. Suppression

df_selec_2=df_selec_2.drop("igntop202103_bat_hauteur", axis=1)

# %%
# Création de la variable "Durée de détention du bien"
# On commence par isoler les lots qui ont été revendus pendant la période
# On les classe par ordre plus vieux au plus récent
z=df_selec_2[df_selec_2["qty_of_mut"]>0][["etaban_lot","anneemut","valeurfonc"]].sort_values(by=["etaban_lot","anneemut"], ascending=False)

# %%
z.head()
# Out:
#                       etaban_lot  anneemut    valeurfonc
# idmutation
# 8421910      75120_9898_00055_22      2017 298300.000000
# 8838640      75120_9898_00055_22      2014 280000.000000
# 8117120     75120_9888_00084_104      2019 506997.000000
# 8699817     75120_9888_00084_104      2015 320000.000000
# 7981775       75120_9888_00046_2      2020 394900.000000

# %%
# On créé une colonne qui va nous permettre de distinguer la dernière mutation (last)
# pour calculer la durée de détention à aujourd'hui

etaban_lot=z["etaban_lot"].iloc[0]
z["range_revente_last"]="not last"

for index, value in enumerate(z["etaban_lot"]) :
    if etaban_lot!=value :
        z["range_revente_last"].iloc[index]="last"
    etaban_lot=value
    print(value)

z["range_revente_last"].value_counts()
# Out:
# 75120_9898_00055_22
# 75120_9898_00055_22
# 75120_9888_00084_104
# 75120_9888_00084_104
# 75120_9888_00046_2
# 75120_9888_00046_2
# 75120_9888_00033_85
# 75120_9888_00033_85
# 75120_9888_00033_301
# 75120_9888_00033_301
# 75120_9850_00043_19
# 75120_9850_00043_19
# 75120_9850_00041_76
# 75120_9850_00041_76
# 75120_9850_00039_71
# 75120_9850_00039_71
# 75120_9850_00037_80
# 75120_9850_00037_80
# 75120_9850_00009_89
# 75120_9850_00009_89
# 75120_9850_00009_119
# 75120_9850_00009_119
# 75120_9844_00069_4
# 75120_9844_00069_4
# 75120_9844_00067_8
# 75120_9844_00067_8
# 75120_9844_00051_6
# 75120_9844_00051_6
# 75120_9844_00042_60
# 75120_9844_00042_60
# 75120_9844_00042_43
# 75120_9844_00042_43
# 75120_9844_00038_6
# 75120_9844_00038_6
# 75120_9844_00016_48
# 75120_9844_00016_48
# 75120_9802_00063_11
# 75120_9802_00063_11
# 75120_9802_00059_16
# 75120_9802_00059_16
# 75120_9802_00032_9
# 75120_9802_00032_9
# 75120_9802_00032_22
# 75120_9802_00032_22
# 75120_9771_00012_29
# 75120_9771_00012_29
# 75120_9771_00002_15
# 75120_9771_00002_15
# 75120_9391_00045_37
# 75120_9391_00045_37
# 75120_9372_00004_21
# 75120_9372_00004_21
# 75120_9333_00013_14
# 75120_9333_00013_14
# 75120_9333_00007_6
# 75120_9333_00007_6
# 75120_9333_00007_21
# 75120_9333_00007_21
# 75120_9333_00006_79
# 75120_9333_00006_79
# 75120_9328_00022_23
# 75120_9328_00022_23
# 75120_9146_00003_8
# 75120_9146_00003_8
# 75120_9132_00058_9
# 75120_9132_00058_9
# 75120_9132_00058_6
# 75120_9132_00058_6
# 75120_9132_00058_4
# 75120_9132_00058_4
# 75120_9132_00058_13
# 75120_9132_00058_13
# 75120_9132_00038_18
# 75120_9132_00038_18
# 75120_9132_00034_8
# 75120_9132_00034_8
# 75120_9132_00015_17
# 75120_9132_00015_17
# 75120_9132_00015_17
# 75120_9132_00011_2029
# 75120_9132_00011_2029
# 75120_9086_00011_20
# 75120_9086_00011_20
# 75120_9086_00005_6
# 75120_9086_00005_6
# 75120_9086_00003_40
# 75120_9086_00003_40
# 75120_9085_00056_14
# 75120_9085_00056_14
# 75120_9085_00039_32
# 75120_9085_00039_32
# 75120_9085_00016_76
# 75120_9085_00016_76
# 75120_9085_00016_72
# 75120_9085_00016_72
# 75120_9085_00016_72
# 75120_9085_00016_70
# 75120_9085_00016_70
# 75120_9085_00016_6
# 75120_9085_00016_6
# 75120_9085_00016_10
# 75120_9085_00016_10
# 75120_9085_00001_128
# 75120_9085_00001_128
# 75120_9029_00010_20
# 75120_9029_00010_20
# 75120_9005_00015_9
# 75120_9005_00015_9
# 75120_8603_00083_34
# 75120_8603_00083_34
# 75120_8603_00063_252
# 75120_8603_00063_252
# 75120_8603_00058_3
# 75120_8603_00058_3
# 75120_8603_00058_11
# 75120_8603_00058_11
# 75120_8603_00051_9
# 75120_8603_00051_9
# 75120_8603_00039_358
# 75120_8603_00039_358
# 75120_8603_00039_320
# 75120_8603_00039_320
# 75120_8603_00039_1124
# 75120_8603_00039_1124
# 75120_8603_00028_232
# 75120_8603_00028_232
# 75120_8603_00028_219
# 75120_8603_00028_219
# 75120_8503_00078_15
# 75120_8503_00078_15
# 75120_8503_00072_18
# 75120_8503_00072_18
# 75120_8503_00071_86
# 75120_8503_00071_86
# 75120_8503_00071_79
# 75120_8503_00071_79
# 75120_8503_00071_76
# 75120_8503_00071_76
# 75120_8503_00071_57
# 75120_8503_00071_57
# 75120_8503_00071_23
# 75120_8503_00071_23
# 75120_8503_00071_23
# 75120_8503_00067_41
# 75120_8503_00067_41
# 75120_8503_00057_5
# 75120_8503_00057_5
# 75120_8503_00054_27
# 75120_8503_00054_27
# 75120_8503_00054_14
# 75120_8503_00054_14
# 75120_8503_00007_34
# 75120_8503_00007_34
# 75120_8503_00006_1011
# 75120_8503_00006_1011
# 75120_8503_00006_1011
# 75120_8345_00066_13
# 75120_8345_00066_13
# 75120_8275_00004_8
# 75120_8275_00004_8
# 75120_8232_00065_5
# 75120_8232_00065_5
# 75120_8232_00063_1
# 75120_8232_00063_1
# 75120_8232_00021_31
# 75120_8232_00021_31
# 75120_8180_00107_26
# 75120_8180_00107_26
# 75120_8180_00107_17
# 75120_8180_00107_17
# 75120_8180_00092_10
# 75120_8180_00092_10
# 75120_8180_00043_7
# 75120_8180_00043_7
# 75120_8180_00043_7
# 75120_8180_00041_25
# 75120_8180_00041_25
# 75120_8180_00038_8
# 75120_8180_00038_8
# 75120_8180_00038_8
# 75120_8180_00038_22
# 75120_8180_00038_22
# 75120_8180_00011_404
# 75120_8180_00011_404
# 75120_8172_00033_1
# 75120_8172_00033_1
# 75120_8156_00006_6
# 75120_8156_00006_6
# 75120_8156_00006_5
# 75120_8156_00006_5
# 75120_8096_00018_2
# 75120_8096_00018_2
# 75120_8096_00018_2
# 75120_8047_00037_35
# 75120_8047_00037_35
# 75120_8022_00040_6
# 75120_8022_00040_6
# 75120_8022_00029_2
# 75120_8022_00029_2
# 75120_7904_00395_113
# 75120_7904_00395_113
# 75120_7904_00350_207
# 75120_7904_00350_207
# 75120_7904_00350_205
# 75120_7904_00350_205
# 75120_7904_00343_21
# 75120_7904_00343_21
# 75120_7904_00343_13
# 75120_7904_00343_13
# 75120_7904_00340_5
# 75120_7904_00340_5
# 75120_7904_00340_11
# 75120_7904_00340_11
# 75120_7904_00333_42
# 75120_7904_00333_42
# 75120_7904_00333_34
# 75120_7904_00333_34
# 75120_7904_00330_24
# 75120_7904_00330_24
# 75120_7904_00304_23
# 75120_7904_00304_23
# 75120_7904_00299_11
# 75120_7904_00299_11
# 75120_7904_00289_25
# 75120_7904_00289_25
# 75120_7904_00288_7
# 75120_7904_00288_7
# 75120_7904_00285_63
# 75120_7904_00285_63
# 75120_7904_00284_32
# 75120_7904_00284_32
# 75120_7904_00283_1217
# 75120_7904_00283_1217
# 75120_7904_00283_1206
# 75120_7904_00283_1206
# 75120_7904_00271_8
# 75120_7904_00271_8
# 75120_7904_00271_7
# 75120_7904_00271_7
# 75120_7904_00271_22
# 75120_7904_00271_22
# 75120_7904_00271_21
# 75120_7904_00271_21
# 75120_7904_00271_14
# 75120_7904_00271_14
# 75120_7904_00269_9
# 75120_7904_00269_9
# 75120_7904_00269_14
# 75120_7904_00269_14
# 75120_7904_00265_10
# 75120_7904_00265_10
# 75120_7904_00262_4
# 75120_7904_00262_4
# 75120_7904_00262_191
# 75120_7904_00262_191
# 75120_7904_00261_18
# 75120_7904_00261_18
# 75120_7904_00252_108
# 75120_7904_00252_108
# 75120_7904_00249_6
# 75120_7904_00249_6
# 75120_7904_00249_15
# 75120_7904_00249_15
# 75120_7904_00243_22
# 75120_7904_00243_22
# 75120_7904_00239_27
# 75120_7904_00239_27
# 75120_7904_00239_27
# 75120_7904_00234_35
# 75120_7904_00234_35
# 75120_7904_00232_34
# 75120_7904_00232_34
# 75120_7904_00226_48
# 75120_7904_00226_48
# 75120_7904_00226_27
# 75120_7904_00226_27
# 75120_7904_00216_9
# 75120_7904_00216_9
# 75120_7904_00209_322
# 75120_7904_00209_322
# 75120_7904_00191_50
# 75120_7904_00191_50
# 75120_7904_00183_75
# 75120_7904_00183_75
# 75120_7904_00181_38
# 75120_7904_00181_38
# 75120_7904_00181_30
# 75120_7904_00181_30
# 75120_7904_00181_29
# 75120_7904_00181_29
# 75120_7904_00180_212
# 75120_7904_00180_212
# 75120_7904_00164_171
# 75120_7904_00164_171
# 75120_7904_00164_169
# 75120_7904_00164_169
# 75120_7904_00161_3
# 75120_7904_00161_3
# 75120_7904_00161_10
# 75120_7904_00161_10
# 75120_7904_00157_15
# 75120_7904_00157_15
# 75120_7904_00136_9
# 75120_7904_00136_9
# 75120_7904_00136_16
# 75120_7904_00136_16
# 75120_7904_00119_167
# 75120_7904_00119_167
# 75120_7904_00119_153
# 75120_7904_00119_153
# 75120_7904_00108_9
# 75120_7904_00108_9
# 75120_7904_00108_3
# 75120_7904_00108_3
# 75120_7904_00108_22
# 75120_7904_00108_22
# 75120_7904_00108_16
# 75120_7904_00108_16
# 75120_7904_00104_19
# 75120_7904_00104_19
# 75120_7904_00102_27
# 75120_7904_00102_27
# 75120_7904_00094_18
# 75120_7904_00094_18
# 75120_7904_00089_427
# 75120_7904_00089_427
# 75120_7904_00089_38
# 75120_7904_00089_38
# 75120_7904_00088_7
# 75120_7904_00088_7
# 75120_7904_00086_6
# 75120_7904_00086_6
# 75120_7904_00078_31
# 75120_7904_00078_31
# 75120_7904_00072_147
# 75120_7904_00072_147
# 75120_7904_00064_15
# 75120_7904_00064_15
# 75120_7904_00063_42
# 75120_7904_00063_42
# 75120_7904_00062_16
# 75120_7904_00062_16
# 75120_7904_00055_9
# 75120_7904_00055_9
# 75120_7904_00055_36
# 75120_7904_00055_36
# 75120_7904_00055_120
# 75120_7904_00055_120
# 75120_7904_00055_120
# 75120_7904_00055_11
# 75120_7904_00055_11
# 75120_7904_00054_11
# 75120_7904_00054_11
# 75120_7904_00050_14
# 75120_7904_00050_14
# 75120_7904_00044_28
# 75120_7904_00044_28
# 75120_7904_00043_4
# 75120_7904_00043_4
# 75120_7899_00028_4
# 75120_7899_00028_4
# 75120_7899_00022_15
# 75120_7899_00022_15
# 75120_7810_00014_634
# 75120_7810_00014_634
# 75120_7810_00011_23
# 75120_7810_00011_23
# 75120_7785_00070_95
# 75120_7785_00070_95
# 75120_7785_00062_13
# 75120_7785_00062_13
# 75120_7785_00044_3
# 75120_7785_00044_3
# 75120_7785_00043_222
# 75120_7785_00043_222
# 75120_7785_00031_251
# 75120_7785_00031_251
# 75120_7785_00028_54
# 75120_7785_00028_54
# 75120_7785_00027_283
# 75120_7785_00027_283
# 75120_7512_00064_217
# 75120_7512_00064_217
# 75120_7512_00055_16
# 75120_7512_00055_16
# 75120_7512_00055_16
# 75120_7512_00055_15
# 75120_7512_00055_15
# 75120_7512_00053_167
# 75120_7512_00053_167
# 75120_7512_00051_9
# 75120_7512_00051_9
# 75120_7512_00051_5
# 75120_7512_00051_5
# 75120_7512_00029_309
# 75120_7512_00029_309
# 75120_7512_00022_48
# 75120_7512_00022_48
# 75120_7508_00037_258
# 75120_7508_00037_258
# 75120_7508_00017_305
# 75120_7508_00017_305
# 75120_7508_00017_305
# 75120_7504_00084_37
# 75120_7504_00084_37
# 75120_7504_00070_118
# 75120_7504_00070_118
# 75120_7504_00067_12
# 75120_7504_00067_12
# 75120_7504_00062_3066
# 75120_7504_00062_3066
# 75120_7504_00062_3066
# 75120_7504_00059_155
# 75120_7504_00059_155
# 75120_7504_00057_14
# 75120_7504_00057_14
# 75120_7504_00057_11
# 75120_7504_00057_11
# 75120_7409_00007_702
# 75120_7409_00007_702
# 75120_7409_00001_105
# 75120_7409_00001_105
# 75120_7393_00053_107
# 75120_7393_00053_107
# 75120_7393_00051_529
# 75120_7393_00051_529
# 75120_7261_00013_15
# 75120_7261_00013_15
# 75120_7261_00011_7
# 75120_7261_00011_7
# 75120_7261_00011_6
# 75120_7261_00011_6
# 75120_7261_00009_24
# 75120_7261_00009_24
# 75120_7228_00186_1
# 75120_7228_00186_1
# 75120_7228_00163_41
# 75120_7228_00163_41
# 75120_7228_00163_39
# 75120_7228_00163_39
# 75120_7228_00154_27
# 75120_7228_00154_27
# 75120_7228_00137_63
# 75120_7228_00137_63
# 75120_7228_00137_63
# 75120_7228_00137_29
# 75120_7228_00137_29
# 75120_7228_00132_12
# 75120_7228_00132_12
# 75120_7228_00128_146
# 75120_7228_00128_146
# 75120_7228_00125_111
# 75120_7228_00125_111
# 75120_7228_00116_185
# 75120_7228_00116_185
# 75120_7228_00098_211
# 75120_7228_00098_211
# 75120_7228_00098_210
# 75120_7228_00098_210
# 75120_7228_00098_176
# 75120_7228_00098_176
# 75120_7228_00097_323
# 75120_7228_00097_323
# 75120_7228_00089_96
# 75120_7228_00089_96
# 75120_7228_00089_33
# 75120_7228_00089_33
# 75120_7228_00074_7
# 75120_7228_00074_7
# 75120_7228_00074_7
# 75120_7228_00068_26
# 75120_7228_00068_26
# 75120_7228_00068_24
# 75120_7228_00068_24
# 75120_7228_00060_31
# 75120_7228_00060_31
# 75120_7228_00034_13
# 75120_7228_00034_13
# 75120_7228_00032_15
# 75120_7228_00032_15
# 75120_7228_00023_409
# 75120_7228_00023_409
# 75120_7228_00020_9
# 75120_7228_00020_9
# 75120_7228_00004_125
# 75120_7228_00004_125
# 75120_7032_00025_8
# 75120_7032_00025_8
# 75120_7032_00018_11
# 75120_7032_00018_11
# 75120_7032_00018_11
# 75120_6958_00090_31
# 75120_6958_00090_31
# 75120_6958_00071_13
# 75120_6958_00071_13
# 75120_6958_00042_11
# 75120_6958_00042_11
# 75120_6958_00004_116
# 75120_6958_00004_116
# 75120_6924_00103_173
# 75120_6924_00103_173
# 75120_6924_00099_4
# 75120_6924_00099_4
# 75120_6924_00059_29
# 75120_6924_00059_29
# 75120_6924_00051_77
# 75120_6924_00051_77
# 75120_6924_00050_36
# 75120_6924_00050_36
# 75120_6924_00031_6
# 75120_6924_00031_6
# 75120_6924_00020_133
# 75120_6924_00020_133
# 75120_6924_00011_20
# 75120_6924_00011_20
# 75120_6891_00067_13
# 75120_6891_00067_13
# 75120_6891_00058_1028
# 75120_6891_00058_1028
# 75120_6891_00058_1003
# 75120_6891_00058_1003
# 75120_6891_00051_15
# 75120_6891_00051_15
# 75120_6891_00051_15
# 75120_6891_00051_12
# 75120_6891_00051_12
# 75120_6856_00002_340
# 75120_6856_00002_340
# 75120_6610_00048_33
# 75120_6610_00048_33
# 75120_6610_00048_33
# 75120_6503_00026_3
# 75120_6503_00026_3
# 75120_6503_00023_108
# 75120_6503_00023_108
# 75120_6475_00009_9
# 75120_6475_00009_9
# 75120_6475_00005_21
# 75120_6475_00005_21
# 75120_6475_00004_3
# 75120_6475_00004_3
# 75120_6270_00157_2329
# 75120_6270_00157_2329
# 75120_6270_00155_25
# 75120_6270_00155_25
# 75120_6270_00153_112
# 75120_6270_00153_112
# 75120_6270_00143_36
# 75120_6270_00143_36
# 75120_6270_00137_9
# 75120_6270_00137_9
# 75120_6270_00124_9
# 75120_6270_00124_9
# 75120_6270_00116_25
# 75120_6270_00116_25
# 75120_6270_00112_28
# 75120_6270_00112_28
# 75120_6270_00103_31
# 75120_6270_00103_31
# 75120_6270_00103_15
# 75120_6270_00103_15
# 75120_6270_00100_16
# 75120_6270_00100_16
# 75120_6270_00093_10
# 75120_6270_00093_10
# 75120_6270_00070_23
# 75120_6270_00070_23
# 75120_6270_00055_9
# 75120_6270_00055_9
# 75120_6270_00050_60
# 75120_6270_00050_60
# 75120_6270_00050_154
# 75120_6270_00050_154
# 75120_6270_00050_13
# 75120_6270_00050_13
# 75120_6270_00042_46
# 75120_6270_00042_46
# 75120_6270_00042_35
# 75120_6270_00042_35
# 75120_6270_00040_27
# 75120_6270_00040_27
# 75120_6270_00026_36
# 75120_6270_00026_36
# 75120_6270_00014_9
# 75120_6270_00014_9
# 75120_6267_00146_43
# 75120_6267_00146_43
# 75120_6267_00108_47
# 75120_6267_00108_47
# 75120_6267_00084_28
# 75120_6267_00084_28
# 75120_6267_00080_105
# 75120_6267_00080_105
# 75120_6267_00080_103
# 75120_6267_00080_103
# 75120_6267_00080_101
# 75120_6267_00080_101
# 75120_6267_00074_9
# 75120_6267_00074_9
# 75120_6267_00022_11
# 75120_6267_00022_11
# 75120_6143_00004_18
# 75120_6143_00004_18
# 75120_6137_00006_61
# 75120_6137_00006_61
# 75120_6116_00038_6
# 75120_6116_00038_6
# 75120_6116_00035_2722
# 75120_6116_00035_2722
# 75120_6116_00029_649
# 75120_6116_00029_649
# 75120_6039_00078_19
# 75120_6039_00078_19
# 75120_6039_00046_24
# 75120_6039_00046_24
# 75120_6039_00040_60
# 75120_6039_00040_60
# 75120_6039_00032_15
# 75120_6039_00032_15
# 75120_6039_00008_59
# 75120_6039_00008_59
# 75120_6039_00006_17
# 75120_6039_00006_17
# 75120_5985_00104_6
# 75120_5985_00104_6
# 75120_5985_00104_1
# 75120_5985_00104_1
# 75120_5985_00102_32
# 75120_5985_00102_32
# 75120_5985_00102_18
# 75120_5985_00102_18
# 75120_5985_00091_10
# 75120_5985_00091_10
# 75120_5985_00084_24
# 75120_5985_00084_24
# 75120_5985_00073_28
# 75120_5985_00073_28
# 75120_5985_00068_13
# 75120_5985_00068_13
# 75120_5985_00060_6
# 75120_5985_00060_6
# 75120_5985_00018_237
# 75120_5985_00018_237
# 75120_5703_00011_6
# 75120_5703_00011_6
# 75120_5703_00011_11
# 75120_5703_00011_11
# 75120_5679_00026_12
# 75120_5679_00026_12
# 75120_5669_00004_105
# 75120_5669_00004_105
# 75120_5659_00008_6
# 75120_5659_00008_6
# 75120_5659_00001_16
# 75120_5659_00001_16
# 75120_5659_00001_14
# 75120_5659_00001_14
# 75120_5659_00001_14
# 75120_5659_00001_13
# 75120_5659_00001_13
# 75120_5659_00001_13
# 75120_5638_00018_62
# 75120_5638_00018_62
# 75120_5612_00011_131
# 75120_5612_00011_131
# 75120_5612_00006_15
# 75120_5612_00006_15
# 75120_5435_00026_50
# 75120_5435_00026_50
# 75120_5435_00023_16
# 75120_5435_00023_16
# 75120_5435_00023_16
# 75120_5266_00104_11
# 75120_5266_00104_11
# 75120_5266_00087_103
# 75120_5266_00087_103
# 75120_5266_00083_11
# 75120_5266_00083_11
# 75120_5266_00077_61
# 75120_5266_00077_61
# 75120_5266_00077_58
# 75120_5266_00077_58
# 75120_5266_00077_11
# 75120_5266_00077_11
# 75120_5266_00042_47
# 75120_5266_00042_47
# 75120_5266_00011_3
# 75120_5266_00011_3
# 75120_5266_00011_169
# 75120_5266_00011_169
# 75120_5266_00002_17
# 75120_5266_00002_17
# 75120_5134_00050_54
# 75120_5134_00050_54
# 75120_5134_00050_132
# 75120_5134_00050_132
# 75120_5134_00050_111
# 75120_5134_00050_111
# 75120_5134_00040_67
# 75120_5134_00040_67
# 75120_5134_00040_59
# 75120_5134_00040_59
# 75120_5134_00040_55
# 75120_5134_00040_55
# 75120_5134_00040_262
# 75120_5134_00040_262
# 75120_5134_00040_141
# 75120_5134_00040_141
# 75120_5134_00040_135
# 75120_5134_00040_135
# 75120_5134_00010_102
# 75120_5134_00010_102
# 75120_5112_00103_23
# 75120_5112_00103_23
# 75120_5112_00057_87
# 75120_5112_00057_87
# 75120_5112_00038_33
# 75120_5112_00038_33
# C:\Users\Anne\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 75120_5112_00037_22
# 75120_5112_00037_22
# 75120_5112_00021_2601
# 75120_5112_00021_2601
# 75120_5112_00011_3
# 75120_5112_00011_3
# 75120_5112_00008_59
# 75120_5112_00008_59
# 75120_5077_00012_17
# 75120_5077_00012_17
# 75120_5077_00004_25
# 75120_5077_00004_25
# 75120_5077_00004_25
# 75120_5046_00012_19
# 75120_5046_00012_19
# 75120_5046_00009_3
# 75120_5046_00009_3
# 75120_5046_00009_16
# 75120_5046_00009_16
# 75120_5046_00005_102
# 75120_5046_00005_102
# 75120_5046_00004_12
# 75120_5046_00004_12
# 75120_5046_00003_15
# 75120_5046_00003_15
# 75120_5035_00007_18
# 75120_5035_00007_18
# 75120_4704_00007_2
# 75120_4704_00007_2
# 75120_4672_00017_30
# 75120_4672_00017_30
# 75120_4581_00024_146
# 75120_4581_00024_146
# 75120_4581_00020_6
# 75120_4581_00020_6
# 75120_4581_00020_2
# 75120_4581_00020_2
# 75120_4581_00008_28
# 75120_4581_00008_28
# 75120_4553_00007_11
# 75120_4553_00007_11
# 75120_4553_00005_20
# 75120_4553_00005_20
# 75120_4553_00004_28
# 75120_4553_00004_28
# 75120_4545_00025_61
# 75120_4545_00025_61
# 75120_4545_00010_42
# 75120_4545_00010_42
# 75120_4510_00109_10
# 75120_4510_00109_10
# 75120_4510_00105_415
# 75120_4510_00105_415
# 75120_4510_00094_326
# 75120_4510_00094_326
# 75120_4510_00090_24
# 75120_4510_00090_24
# 75120_4510_00090_13
# 75120_4510_00090_13
# 75120_4510_00080_13
# 75120_4510_00080_13
# 75120_4510_00078_44
# 75120_4510_00078_44
# 75120_4510_00060_4
# 75120_4510_00060_4
# 75120_4510_00054_6
# 75120_4510_00054_6
# 75120_4510_00054_10
# 75120_4510_00054_10
# 75120_4510_00033_4
# 75120_4510_00033_4
# 75120_4510_00013_3
# 75120_4510_00013_3
# 75120_4452_00084_21
# 75120_4452_00084_21
# 75120_4452_00082_34
# 75120_4452_00082_34
# 75120_4452_00077_47
# 75120_4452_00077_47
# 75120_4452_00030_29
# 75120_4452_00030_29
# 75120_4382_00012_21
# 75120_4382_00012_21
# 75120_4361_00010_111
# 75120_4361_00010_111
# 75120_4352_00026_7
# 75120_4352_00026_7
# 75120_4352_00026_2
# 75120_4352_00026_2
# 75120_4352_00005_17
# 75120_4352_00005_17
# 75120_4352_00005_15
# 75120_4352_00005_15
# 75120_4287_00113_7
# 75120_4287_00113_7
# 75120_4287_00113_14
# 75120_4287_00113_14
# 75120_4287_00074_71
# 75120_4287_00074_71
# 75120_4287_00066_23
# 75120_4287_00066_23
# 75120_4287_00040_15
# 75120_4287_00040_15
# 75120_4287_00036_202
# 75120_4287_00036_202
# 75120_3983_00041_38
# 75120_3983_00041_38
# 75120_3983_00023_12
# 75120_3983_00023_12
# 75120_3983_00017_27
# 75120_3983_00017_27
# 75120_3983_00017_17
# 75120_3983_00017_17
# 75120_3935_00001_14
# 75120_3935_00001_14
# 75120_3933_00203_8
# 75120_3933_00203_8
# 75120_3933_00187_52
# 75120_3933_00187_52
# 75120_3933_00187_52
# 75120_3933_00145_14
# 75120_3933_00145_14
# 75120_3933_00122_18
# 75120_3933_00122_18
# 75120_3933_00121_14
# 75120_3933_00121_14
# 75120_3933_00120_4
# 75120_3933_00120_4
# 75120_3933_00112_10
# 75120_3933_00112_10
# 75120_3933_00090_38
# 75120_3933_00090_38
# 75120_3933_00089_154
# 75120_3933_00089_154
# 75120_3933_00082_7
# 75120_3933_00082_7
# 75120_3933_00080_7
# 75120_3933_00080_7
# 75120_3933_00065_13
# 75120_3933_00065_13
# 75120_3933_00051_42
# 75120_3933_00051_42
# 75120_3933_00051_37
# 75120_3933_00051_37
# 75120_3933_00045_21
# 75120_3933_00045_21
# 75120_3933_00045_15
# 75120_3933_00045_15
# 75120_3933_00025_34
# 75120_3933_00025_34
# 75120_3933_00011_13
# 75120_3933_00011_13
# 75120_3933_00007_19
# 75120_3933_00007_19
# 75120_3933_00001_28
# 75120_3933_00001_28
# 75120_3933_00001_22
# 75120_3933_00001_22
# 75120_3933_00001_20
# 75120_3933_00001_20
# 75120_3925_00007_7
# 75120_3925_00007_7
# 75120_3913_00008_1057
# 75120_3913_00008_1057
# 75120_3836_00029_22
# 75120_3836_00029_22
# 75120_3836_00029_20
# 75120_3836_00029_20
# 75120_3836_00027_16
# 75120_3836_00027_16
# 75120_3759_00021_188
# 75120_3759_00021_188
# 75120_3759_00013_252
# 75120_3759_00013_252
# 75120_3759_00013_239
# 75120_3759_00013_239
# 75120_3725_00040_33
# 75120_3725_00040_33
# 75120_3725_00029_920
# 75120_3725_00029_920
# 75120_3725_00002_36
# 75120_3725_00002_36
# 75120_3690_00024_4
# 75120_3690_00024_4
# 75120_3589_00007_8
# 75120_3589_00007_8
# 75120_3589_00001_8
# 75120_3589_00001_8
# 75120_3589_00001_5
# 75120_3589_00001_5
# 75120_3395_00005_1
# 75120_3395_00005_1
# 75120_3395_00004_2
# 75120_3395_00004_2
# 75120_3394_00051_30
# 75120_3394_00051_30
# 75120_3394_00051_24
# 75120_3394_00051_24
# 75120_3394_00036_18
# 75120_3394_00036_18
# 75120_3394_00002_70
# 75120_3394_00002_70
# 75120_3388_00040_12
# 75120_3388_00040_12
# 75120_3388_00027_3
# 75120_3388_00027_3
# 75120_3388_00027_17
# 75120_3388_00027_17
# 75120_3388_00027_11
# 75120_3388_00027_11
# 75120_3388_00015_165
# 75120_3388_00015_165
# 75120_3388_00007_19
# 75120_3388_00007_19
# 75120_3388_00005_13
# 75120_3388_00005_13
# 75120_3388_00003_22
# 75120_3388_00003_22
# 75120_3370_00018_144
# 75120_3370_00018_144
# 75120_3370_00005_35
# 75120_3370_00005_35
# 75120_3370_00005_34
# 75120_3370_00005_34
# 75120_3324_00054_9
# 75120_3324_00054_9
# 75120_3324_00052_8
# 75120_3324_00052_8
# 75120_3324_00052_23
# 75120_3324_00052_23
# 75120_3324_00050_7
# 75120_3324_00050_7
# 75120_3324_00041_1
# 75120_3324_00041_1
# 75120_3324_00018_1
# 75120_3324_00018_1
# 75120_3293_00054_46
# 75120_3293_00054_46
# 75120_3293_00050_34
# 75120_3293_00050_34
# 75120_3293_00038_105
# 75120_3293_00038_105
# 75120_3293_00037_27
# 75120_3293_00037_27
# 75120_3293_00014_9
# 75120_3293_00014_9
# 75120_3237_00003_9
# 75120_3237_00003_9
# 75120_3237_00003_37
# 75120_3237_00003_37
# 75120_3237_00003_133
# 75120_3237_00003_133
# 75120_3237_00001_37
# 75120_3237_00001_37
# 75120_3192_00007_20
# 75120_3192_00007_20
# 75120_3192_00007_13
# 75120_3192_00007_13
# 75120_3192_00005_19
# 75120_3192_00005_19
# 75120_3192_00004_37
# 75120_3192_00004_37
# 75120_3192_00003_6
# 75120_3192_00003_6
# 75120_3051_00003_624
# 75120_3051_00003_624
# 75120_3051_00001_505
# 75120_3051_00001_505
# 75120_3011_00022_16
# 75120_3011_00022_16
# 75120_3011_00019_29
# 75120_3011_00019_29
# 75120_3011_00012_14
# 75120_3011_00012_14
# 75120_3011_00005_7
# 75120_3011_00005_7
# 75120_3011_00005_7
# 75120_3011_00004_6
# 75120_3011_00004_6
# 75120_3011_00004_10
# 75120_3011_00004_10
# 75120_2960_00045_14
# 75120_2960_00045_14
# 75120_2960_00027_29
# 75120_2960_00027_29
# 75120_2864_00012_9
# 75120_2864_00012_9
# 75120_2864_00010_9
# 75120_2864_00010_9
# 75120_2786_00028_67
# 75120_2786_00028_67
# 75120_2786_00014_28
# 75120_2786_00014_28
# 75120_2786_00014_20
# 75120_2786_00014_20
# 75120_2780_00017_17
# 75120_2780_00017_17
# 75120_2608_00119_88
# 75120_2608_00119_88
# 75120_2608_00119_76
# 75120_2608_00119_76
# 75120_2608_00119_71
# 75120_2608_00119_71
# 75120_2608_00115_22
# 75120_2608_00115_22
# 75120_2608_00069_8
# 75120_2608_00069_8
# 75120_2608_00065_15
# 75120_2608_00065_15
# 75120_2608_00065_11
# 75120_2608_00065_11
# 75120_2608_00015_12
# 75120_2608_00015_12
# 75120_2608_00011_6
# 75120_2608_00011_6
# 75120_2608_00011_3
# 75120_2608_00011_3
# 75120_2608_00011_127
# 75120_2608_00011_127
# 75120_2398_00130_4
# 75120_2398_00130_4
# 75120_2398_00130_10
# 75120_2398_00130_10
# 75120_2398_00130_1
# 75120_2398_00130_1
# 75120_2398_00112_213
# 75120_2398_00112_213
# 75120_2398_00110_8
# 75120_2398_00110_8
# 75120_2398_00093_3
# 75120_2398_00093_3
# 75120_2398_00090_13
# 75120_2398_00090_13
# 75120_2398_00085_3
# 75120_2398_00085_3
# 75120_2398_00085_1
# 75120_2398_00085_1
# 75120_2398_00004_43
# 75120_2398_00004_43
# 75120_2391_00028_15
# 75120_2391_00028_15
# 75120_2391_00028_14
# 75120_2391_00028_14
# 75120_2391_00027_86
# 75120_2391_00027_86
# 75120_2391_00027_57
# 75120_2391_00027_57
# 75120_2391_00021_3
# 75120_2391_00021_3
# 75120_2391_00020_2
# 75120_2391_00020_2
# 75120_2391_00019_18
# 75120_2391_00019_18
# 75120_2391_00012_20
# 75120_2391_00012_20
# 75120_2391_00011_172
# 75120_2391_00011_172
# 75120_2391_00010_116
# 75120_2391_00010_116
# 75120_2391_00010_103
# 75120_2391_00010_103
# 75120_2391_00003_90
# 75120_2391_00003_90
# 75120_2380_00010_16
# 75120_2380_00010_16
# 75120_2380_00010_16
# 75120_2380_00010_15
# 75120_2380_00010_15
# 75120_2380_00010_12
# 75120_2380_00010_12
# 75120_2380_00004_18
# 75120_2380_00004_18
# 75120_2283_00003_14
# 75120_2283_00003_14
# 75120_2135_00029_70
# 75120_2135_00029_70
# 75120_2135_00027_28
# 75120_2135_00027_28
# 75120_2135_00027_20
# 75120_2135_00027_20
# 75120_2135_00025_43
# 75120_2135_00025_43
# 75120_2135_00025_38
# 75120_2135_00025_38
# 75120_2135_00009_39
# 75120_2135_00009_39
# 75120_2135_00001_10
# 75120_2135_00001_10
# 75120_2010_00046_11
# 75120_2010_00046_11
# 75120_2010_00041_10
# 75120_2010_00041_10
# 75120_2010_00035_2
# 75120_2010_00030_27
# 75120_2010_00030_27
# 75120_2010_00027_3
# 75120_2010_00027_3
# 75120_2010_00027_12
# 75120_2010_00027_12
# 75120_2010_00025_2
# 75120_2010_00025_2
# 75120_2010_00025_13
# 75120_2010_00025_13
# 75120_2010_00024_26
# 75120_2010_00024_26
# 75120_2010_00021_25
# 75120_2010_00021_25
# 75120_2010_00018_14
# 75120_2010_00018_14
# 75120_2010_00011_67
# 75120_2010_00011_67
# 75120_2010_00011_56
# 75120_2010_00011_56
# 75120_2010_00011_30
# 75120_2010_00011_30
# 75120_2010_00011_27
# 75120_2010_00011_27
# 75120_2010_00003_4
# 75120_2010_00003_4
# 75120_1887_00212_16
# 75120_1887_00212_16
# 75120_1887_00212_14
# 75120_1887_00212_14
# 75120_1887_00200_13
# 75120_1887_00200_13
# 75120_1887_00196_10
# 75120_1887_00196_10
# 75120_1887_00138_127
# 75120_1887_00138_127
# 75120_1887_00116_47
# 75120_1887_00116_47
# 75120_1887_00116_31
# 75120_1887_00116_31
# 75120_1887_00116_20
# 75120_1887_00116_20
# 75120_1887_00100_125
# 75120_1887_00100_125
# 75120_1887_00086_40
# 75120_1887_00086_40
# 75120_1887_00086_39
# 75120_1887_00086_39
# 75120_1887_00056_117
# 75120_1887_00056_117
# 75120_1887_00056_113
# 75120_1887_00056_113
# 75120_1887_00034_76
# 75120_1887_00034_76
# 75120_1887_00034_63
# 75120_1887_00034_63
# 75120_1887_00034_39
# 75120_1887_00034_39
# 75120_1887_00018_11
# 75120_1887_00018_11
# 75120_1870_00007_8
# 75120_1870_00007_8
# 75120_1836_00015_22
# 75120_1836_00015_22
# 75120_1707_00006_8
# 75120_1707_00006_8
# 75120_1707_00006_3
# 75120_1707_00006_3
# 75120_1585_00081_9
# 75120_1585_00081_9
# 75120_1585_00063_27
# 75120_1585_00063_27
# 75120_1585_00059_3
# 75120_1585_00059_3
# 75120_1506_00050_10
# 75120_1506_00050_10
# 75120_1506_00044_21
# 75120_1506_00044_21
# 75120_1506_00042_9
# 75120_1506_00042_9
# 75120_1506_00031_5
# 75120_1506_00031_5
# 75120_1500_00057_82
# 75120_1500_00057_82
# 75120_1500_00026_161
# 75120_1500_00026_161
# 75120_1500_00025_148
# 75120_1500_00025_148
# 75120_1500_00023_119
# 75120_1500_00023_119
# 75120_1447_00013_5
# 75120_1447_00013_5
# 75120_1447_00012_7
# 75120_1447_00012_7
# 75120_1447_00008_23
# 75120_1447_00008_23
# 75120_1447_00008_13
# 75120_1447_00008_13
# 75120_1398_00094_226
# 75120_1398_00094_226
# 75120_1398_00078_28
# 75120_1398_00078_28
# 75120_1398_00075_3
# 75120_1398_00075_3
# 75120_1398_00067_43
# 75120_1398_00067_43
# 75120_1398_00067_42
# 75120_1398_00067_42
# 75120_1398_00056_19
# 75120_1398_00054_268
# 75120_1398_00054_268
# 75120_1398_00010_205
# 75120_1398_00010_205
# 75120_1398_00008_102
# 75120_1398_00008_102
# 75120_1240_00038_16
# 75120_1240_00038_16
# 75120_1240_00036_54
# 75120_1240_00036_54
# 75120_1240_00030_5
# 75120_1240_00030_5
# 75120_1240_00011_78
# 75120_1240_00011_78
# 75120_1240_00001_166
# 75120_1240_00001_166
# 75120_1112_00047_309
# 75120_1112_00047_309
# 75120_1112_00047_104
# 75120_1112_00047_104
# 75120_1112_00038_36
# 75120_1112_00038_36
# 75120_1112_00032_164
# 75120_1112_00032_164
# 75120_1112_00032_145
# 75120_1112_00032_145
# 75120_1112_00032_136
# 75120_1112_00032_136
# 75120_1112_00032_1018
# 75120_1112_00032_1018
# 75120_1112_00029_103
# 75120_1112_00029_103
# 75120_1112_00029_103
# 75120_1112_00023_134
# 75120_1112_00023_134
# 75120_0954_00046_17
# 75120_0954_00046_17
# 75120_0954_00044_9
# 75120_0954_00044_9
# 75120_0833_00268_66
# 75120_0833_00268_66
# 75120_0833_00238_28
# 75120_0833_00238_28
# 75120_0833_00224_21
# 75120_0833_00224_21
# 75120_0833_00220_73
# 75120_0833_00220_73
# 75120_0833_00220_72
# 75120_0833_00220_72
# 75120_0833_00180_102
# 75120_0833_00180_102
# 75120_0833_00178_52
# 75120_0833_00178_52
# 75120_0833_00174_10
# 75120_0833_00174_10
# 75120_0833_00164_5
# 75120_0833_00164_5
# 75120_0833_00164_5
# 75120_0833_00126_103
# 75120_0833_00126_103
# 75120_0833_00122_24
# 75120_0833_00122_24
# 75120_0833_00110_7
# 75120_0833_00110_7
# 75120_0833_00088_55
# 75120_0833_00088_55
# 75120_0833_00084_11
# 75120_0833_00084_11
# 75120_0833_00082_14
# 75120_0833_00082_14
# 75120_0833_00080_52
# 75120_0833_00080_52
# 75120_0833_00080_18
# 75120_0833_00080_18
# 75120_0833_00080_18
# 75120_0833_00080_11
# 75120_0833_00080_11
# 75120_0833_00078_17
# 75120_0833_00078_17
# 75120_0833_00078_121
# 75120_0833_00078_121
# 75120_0833_00070_123
# 75120_0833_00070_123
# 75120_0833_00058_8
# 75120_0833_00058_8
# 75120_0833_00058_8
# 75120_0833_00058_32
# 75120_0833_00058_32
# 75120_0833_00058_29
# 75120_0833_00058_29
# 75120_0833_00058_28
# 75120_0833_00058_28
# 75120_0833_00050_28
# 75120_0833_00050_28
# 75120_0833_00050_28
# 75120_0833_00050_10
# 75120_0833_00050_10
# 75120_0833_00044_9
# 75120_0833_00044_9
# 75120_0833_00030_29
# 75120_0833_00030_29
# 75120_0833_00022_425
# 75120_0833_00022_425
# 75120_0833_00022_42
# 75120_0833_00022_42
# 75120_0833_00022_385
# 75120_0833_00022_385
# 75120_0833_00022_364
# 75120_0833_00022_364
# 75120_0833_00022_33
# 75120_0833_00022_33
# 75120_0833_00012_25
# 75120_0833_00012_25
# 75120_0833_00006_126
# 75120_0833_00006_126
# 75120_0832_00116_15
# 75120_0832_00116_15
# 75120_0832_00116_12
# 75120_0832_00116_12
# 75120_0832_00082_19
# 75120_0832_00082_19
# 75120_0832_00078_6
# 75120_0832_00078_6
# 75120_0832_00078_21
# 75120_0832_00078_21
# 75120_0832_00022_25
# 75120_0832_00022_25
# 75120_0817_00074_6
# 75120_0817_00074_6
# 75120_0817_00074_13
# 75120_0817_00074_13
# 75120_0817_00047_9
# 75120_0817_00047_9
# 75120_0817_00047_10
# 75120_0817_00047_10
# 75120_0817_00030_51
# 75120_0817_00030_51
# 75120_0817_00030_35
# 75120_0817_00030_35
# 75120_0817_00028_9
# 75120_0817_00028_9
# 75120_0817_00028_7
# 75120_0817_00028_7
# 75120_0817_00028_13
# 75120_0817_00028_13
# 75120_0817_00028_13
# 75120_0817_00017_10
# 75120_0817_00017_10
# 75120_0817_00014_16
# 75120_0817_00014_16
# 75120_0817_00008_8
# 75120_0817_00008_8
# 75120_0626_00179_10
# 75120_0626_00179_10
# 75120_0626_00169_34
# 75120_0626_00169_34
# 75120_0626_00169_25
# 75120_0626_00169_25
# 75120_0626_00169_19
# 75120_0626_00169_19
# 75120_0626_00139_9
# 75120_0626_00139_9
# 75120_0626_00130_109
# 75120_0626_00130_109
# 75120_0626_00122_23
# 75120_0626_00122_23
# 75120_0626_00117_28
# 75120_0626_00117_28
# 75120_0626_00117_25
# 75120_0626_00117_25
# 75120_0626_00094_16
# 75120_0626_00094_16
# 75120_0626_00093_101
# 75120_0626_00093_101
# 75120_0626_00089_20
# 75120_0626_00089_20
# 75120_0626_00089_120
# 75120_0626_00089_120
# 75120_0626_00081_7
# 75120_0626_00081_7
# 75120_0626_00077_10
# 75120_0626_00077_10
# 75120_0626_00068_15
# 75120_0626_00068_15
# 75120_0626_00064_46
# 75120_0626_00064_46
# 75120_0626_00054_26
# 75120_0626_00054_26
# 75120_0626_00054_14
# 75120_0626_00054_14
# 75120_0626_00041_5
# 75120_0626_00041_5
# 75120_0626_00041_4
# 75120_0626_00041_4
# 75120_0626_00041_4
# 75120_0626_00039_9
# 75120_0626_00039_9
# 75120_0626_00022_23
# 75120_0626_00022_23
# 75120_0626_00022_105
# 75120_0626_00022_105
# 75120_0626_00017_9
# 75120_0626_00017_9
# 75120_0626_00008_12
# 75120_0626_00008_12
# 75120_0610_00144_13
# 75120_0610_00144_13
# 75120_0610_00140_3
# 75120_0610_00140_3
# 75120_0610_00140_2
# 75120_0610_00140_2
# 75120_0610_00138_6
# 75120_0610_00138_6
# 75120_0610_00138_5
# 75120_0610_00138_5
# 75120_0610_00132_9
# 75120_0610_00132_9
# 75120_0610_00104_12
# 75120_0610_00104_12
# 75120_0610_00093_11
# 75120_0610_00093_11
# 75120_0610_00065_24
# 75120_0610_00065_24
# 75120_0610_00065_21
# 75120_0610_00065_21
# 75120_0610_00050_56
# 75120_0610_00050_56
# 75120_0610_00044_9
# 75120_0610_00044_9
# 75120_0610_00038_110
# 75120_0610_00038_110
# 75120_0610_00033_9
# 75120_0610_00033_9
# 75120_0610_00021_20
# 75120_0610_00021_20
# 75120_0600_00001_6
# 75120_0600_00001_6
# 75120_0561_00004_5
# 75120_0561_00004_5
# 75120_0561_00004_5
# 75120_0533_00010_53
# 75120_0533_00010_53
# 75120_0533_00006_17
# 75120_0533_00006_17
# 75120_0355_00032_37
# 75120_0355_00032_37
# 75120_0355_00032_1
# 75120_0355_00032_1
# 75120_0355_00024_202
# 75120_0355_00024_202
# 75120_0355_00024_202
# 75120_0355_00024_165
# 75120_0355_00024_165
# 75120_0355_00022_8
# 75120_0355_00022_8
# 75120_0355_00022_6
# 75120_0355_00022_6
# 75120_0355_00022_16
# 75120_0355_00022_16
# 75120_0355_00022_1
# 75120_0355_00022_1
# 75120_0355_00019_8
# 75120_0355_00019_8
# 75120_0245_00026_79
# 75120_0245_00026_79
# 75120_0245_00026_133
# 75120_0245_00026_133
# 75120_0245_00026_101
# 75120_0245_00026_101
# 75120_0245_00019_51
# 75120_0245_00019_51
# 75120_0155_00099_110
# 75120_0155_00099_110
# 75120_0155_00099_107
# 75120_0155_00099_107
# 75120_0155_00098_17
# 75120_0155_00098_17
# 75120_0155_00080_23
# 75120_0155_00080_23
# 75120_0155_00080_18
# 75120_0155_00080_18
# 75119_9839_00076_19
# 75119_9839_00076_19
# 75119_9839_00060_2
# 75119_9839_00060_2
# 75119_9839_00007_59
# 75119_9839_00007_59
# 75119_9839_00005_15
# 75119_9839_00005_15
# 75119_9838_00242_15
# 75119_9838_00242_15
# 75119_9838_00242_121
# 75119_9838_00242_121
# 75119_9838_00242_116
# 75119_9838_00242_116
# 75119_9838_00182_140
# 75119_9838_00182_140
# 75119_9838_00102_56
# 75119_9838_00102_56
# 75119_9838_00048_28
# 75119_9838_00048_28
# 75119_9500_00002_18
# 75119_9500_00002_18
# 75119_9500_00002_15
# 75119_9500_00002_15
# 75119_9284_00032_41
# 75119_9284_00032_41
# 75119_9284_00014_1829
# 75119_9284_00014_1829
# 75119_9284_00014_1472
# 75119_9284_00014_1472
# 75119_9284_00014_1349
# 75119_9284_00014_1349
# 75119_9284_00014_1238
# 75119_9284_00014_1238
# 75119_9284_00012_19
# 75119_9284_00012_19
# 75119_9284_00007_268
# 75119_9284_00007_268
# 75119_9284_00006_17
# 75119_9284_00006_17
# 75119_9284_00005_82
# 75119_9284_00005_82
# 75119_9284_00005_74
# 75119_9284_00005_74
# 75119_9284_00005_73
# 75119_9284_00005_73
# 75119_9284_00005_305
# 75119_9284_00005_305
# 75119_9284_00005_305
# 75119_9171_00033_26
# 75119_9171_00033_26
# 75119_9171_00033_25
# 75119_9171_00033_25
# 75119_9171_00033_25
# 75119_9017_00047_54
# 75119_9017_00047_54
# 75119_9017_00046_4
# 75119_9017_00046_4
# 75119_9017_00023_11
# 75119_9017_00023_11
# 75119_9017_00014_20
# 75119_9017_00014_20
# 75119_9015_00017_264
# 75119_9015_00017_264
# 75119_8978_00116_143
# 75119_8978_00116_143
# 75119_8978_00116_117
# 75119_8978_00116_117
# 75119_8978_00110_29
# 75119_8978_00110_29
# 75119_8978_00107_1028
# 75119_8978_00107_1028
# 75119_8978_00107_1015
# 75119_8978_00107_1015
# 75119_8978_00098_63
# 75119_8978_00098_63
# 75119_8978_00098_33
# 75119_8978_00098_33
# 75119_8978_00079_4
# 75119_8978_00079_4
# 75119_8978_00079_17
# 75119_8978_00079_17
# 75119_8978_00079_110
# 75119_8978_00079_110
# 75119_8978_00064_25
# 75119_8978_00064_25
# 75119_8978_00058_14
# 75119_8978_00058_14
# 75119_8978_00054_110
# 75119_8978_00054_110
# 75119_8978_00045_219
# 75119_8978_00045_219
# 75119_8978_00038_552
# 75119_8978_00038_552
# 75119_8978_00038_552
# 75119_8978_00036_161
# 75119_8978_00036_161
# 75119_8978_00030_26
# 75119_8978_00030_26
# 75119_8978_00030_13
# 75119_8978_00030_13
# 75119_8978_00030_116
# 75119_8978_00030_116
# 75119_8978_00030_11
# 75119_8978_00030_11
# 75119_8978_00028_674
# 75119_8978_00028_674
# 75119_8978_00028_642
# 75119_8978_00028_642
# 75119_8978_00019_17
# 75119_8978_00019_17
# 75119_8939_00073_19
# 75119_8939_00073_19
# 75119_8939_00067_97
# 75119_8939_00067_97
# 75119_8939_00055_1502
# 75119_8939_00055_1502
# 75119_8939_00035_10
# 75119_8939_00035_10
# 75119_8939_00031_53
# 75119_8939_00031_53
# 75119_8924_00006_60
# 75119_8924_00006_60
# 75119_8924_00006_57
# 75119_8924_00006_57
# 75119_8912_00019_7
# 75119_8912_00019_7
# 75119_8896_00091_72
# 75119_8896_00091_72
# 75119_8896_00089_47
# 75119_8896_00089_47
# 75119_8896_00087_34
# 75119_8896_00087_34
# 75119_8896_00080_14
# 75119_8896_00080_14
# 75119_8896_00078_20
# 75119_8896_00078_20
# 75119_8896_00066_5
# 75119_8896_00066_5
# 75119_8896_00066_18
# 75119_8896_00066_18
# 75119_8896_00048_65
# 75119_8896_00048_65
# 75119_8896_00041_65
# 75119_8896_00041_65
# 75119_8896_00040_75
# 75119_8896_00040_75
# 75119_8896_00040_70
# 75119_8896_00040_70
# 75119_8896_00040_69
# 75119_8896_00040_69
# 75119_8896_00023_5
# 75119_8896_00023_5
# 75119_8896_00023_14
# 75119_8896_00023_14
# 75119_8896_00020_35
# 75119_8896_00020_35
# 75119_8896_00013_24
# 75119_8896_00013_24
# 75119_8408_00019_116
# 75119_8408_00019_116
# 75119_8408_00011_37
# 75119_8408_00011_37
# 75119_8408_00011_22
# 75119_8408_00011_22
# 75119_8408_00011_19
# 75119_8408_00011_19
# 75119_8386_00016_58
# 75119_8386_00016_58
# 75119_8333_00049_1534
# 75119_8333_00049_1534
# 75119_8333_00049_1241
# 75119_8333_00049_1241
# 75119_8333_00036_26
# 75119_8333_00036_26
# 75119_8333_00036_172
# 75119_8333_00036_172
# 75119_8333_00023_22
# 75119_8333_00023_22
# 75119_8333_00019_13
# 75119_8333_00019_13
# 75119_8333_00007_5
# 75119_8333_00007_5
# 75119_8241_00062_20
# 75119_8241_00062_20
# 75119_8241_00030_63
# 75119_8241_00030_63
# 75119_8241_00012_26
# 75119_8241_00012_26
# 75119_8241_00012_20
# 75119_8241_00012_20
# 75119_8241_00010_2057
# 75119_8241_00010_2057
# 75119_8241_00010_2033
# 75119_8241_00010_2033
# 75119_8241_00002_38
# 75119_8241_00002_38
# 75119_8183_00027_12
# 75119_8183_00027_12
# 75119_8183_00020_15
# 75119_8183_00020_15
# 75119_8183_00018_32
# 75119_8183_00018_32
# 75119_8183_00007_12
# 75119_8183_00007_12
# 75119_8124_00026_10
# 75119_8124_00026_10
# 75119_8124_00011_9
# 75119_8124_00011_9
# 75119_8124_00009_8
# 75119_8124_00009_8
# 75119_8124_00009_17
# 75119_8124_00009_17
# 75119_8076_00082_71
# 75119_8076_00082_71
# 75119_8076_00079_108
# 75119_8076_00079_108
# 75119_8076_00075_6
# 75119_8076_00075_6
# 75119_8076_00059_2
# 75119_8076_00059_2
# 75119_8076_00053_91
# 75119_8076_00053_91
# 75119_8076_00027_372
# 75119_8076_00027_372
# 75119_8076_00027_13
# 75119_8076_00027_13
# 75119_8076_00027_12
# 75119_8076_00027_12
# 75119_8016_00018_54
# 75119_8016_00018_54
# 75119_8016_00018_108
# 75119_8016_00018_108
# 75119_8016_00004_13
# 75119_8016_00004_13
# 75119_7826_00036_18
# 75119_7826_00036_18
# 75119_7796_00064_35
# 75119_7796_00064_35
# 75119_7796_00064_21
# 75119_7796_00064_21
# 75119_7796_00009_37
# 75119_7796_00009_37
# 75119_7779_00012_54
# 75119_7779_00012_54
# 75119_7779_00012_54
# 75119_7779_00002_16
# 75119_7779_00002_16
# 75119_7697_00007_88
# 75119_7697_00007_88
# 75119_7697_00007_38
# 75119_7697_00007_38
# 75119_7697_00007_113
# 75119_7697_00007_113
# 75119_7528_00034_29
# 75119_7528_00034_29
# 75119_7528_00034_15
# 75119_7528_00034_15
# 75119_7528_00019_18
# 75119_7528_00019_18
# 75119_7528_00019_16
# 75119_7528_00019_16
# 75119_7528_00008_109
# 75119_7528_00008_109
# 75119_7314_00085_2066
# 75119_7314_00085_2066
# 75119_7314_00073_53
# 75119_7314_00073_53
# 75119_7314_00073_44
# 75119_7314_00073_44
# 75119_7314_00073_39
# 75119_7314_00073_39
# 75119_7314_00041_21
# 75119_7314_00041_21
# 75119_7314_00041_14
# 75119_7314_00041_14
# 75119_7314_00011_4
# 75119_7314_00011_4
# 75119_7276_00010_318
# 75119_7276_00010_318
# 75119_7276_00002_188
# 75119_7276_00002_188
# 75119_7189_00015_14
# 75119_7189_00015_14
# 75119_7045_00004_61
# 75119_7045_00004_61
# 75119_7045_00004_48
# 75119_7045_00004_48
# 75119_7045_00003_5
# 75119_7045_00003_5
# 75119_7016_00018_322
# 75119_7016_00018_322
# 75119_7016_00010_1
# 75119_7016_00010_1
# 75119_7016_00003_23
# 75119_7016_00003_23
# 75119_6980_00097_35
# 75119_6980_00097_35
# 75119_6980_00097_34
# 75119_6980_00097_34
# 75119_6980_00092_8
# 75119_6980_00092_8
# 75119_6980_00092_20
# 75119_6980_00092_20
# 75119_6980_00092_11
# 75119_6980_00092_11
# 75119_6980_00067_63
# 75119_6980_00067_63
# 75119_6980_00048_24
# 75119_6980_00048_24
# 75119_6980_00032_155
# 75119_6980_00032_155
# 75119_6980_00028_38
# 75119_6980_00028_38
# 75119_6940_00009_8
# 75119_6940_00009_8
# 75119_6879_00007_94
# 75119_6879_00007_94
# 75119_6879_00007_117
# 75119_6879_00007_117
# 75119_6671_00045_5
# 75119_6671_00045_5
# 75119_6671_00039_24
# 75119_6671_00039_24
# 75119_6671_00037_59
# 75119_6671_00037_59
# 75119_6671_00026_27
# 75119_6671_00026_27
# 75119_6671_00016_16
# 75119_6671_00016_16
# 75119_6671_00015_29
# 75119_6671_00015_29
# 75119_6671_00010_45
# 75119_6671_00010_45
# 75119_6671_00009_6
# 75119_6671_00009_6
# 75119_6671_00006_18
# 75119_6671_00006_18
# 75119_6671_00005_61
# 75119_6671_00005_61
# 75119_6671_00003_203
# 75119_6671_00003_203
# 75119_6671_00003_203
# 75119_6622_00079_20
# 75119_6622_00079_20
# 75119_6622_00070_14
# 75119_6622_00070_14
# 75119_6622_00014_29
# 75119_6622_00014_29
# 75119_6313_00020_15
# 75119_6313_00020_15
# 75119_6313_00019_15
# 75119_6313_00019_15
# 75119_6313_00010_9
# 75119_6313_00010_9
# 75119_6257_00025_710
# 75119_6257_00025_710
# 75119_6257_00010_11
# 75119_6257_00010_11
# 75119_6257_00004_9
# 75119_6257_00004_9
# 75119_6257_00004_58
# 75119_6257_00004_58
# 75119_6236_00118_27
# 75119_6236_00118_27
# 75119_6236_00116_8
# 75119_6236_00116_8
# 75119_6236_00113_39
# 75119_6236_00113_39
# 75119_6236_00113_39
# 75119_6236_00110_14
# 75119_6236_00110_14
# 75119_6236_00106_18
# 75119_6236_00106_18
# 75119_6236_00099_44
# 75119_6236_00099_44
# 75119_6236_00099_316
# 75119_6236_00099_316
# 75119_6236_00070_108
# 75119_6236_00070_108
# 75119_6236_00065_42
# 75119_6236_00065_42
# 75119_6236_00065_42
# 75119_6236_00065_13
# 75119_6236_00065_13
# 75119_6236_00058_13
# 75119_6236_00058_13
# 75119_6236_00050_4
# 75119_6236_00050_4
# 75119_6236_00050_10
# 75119_6236_00050_10
# 75119_6236_00045_30
# 75119_6236_00045_30
# 75119_6236_00043_44
# 75119_6236_00043_44
# 75119_6236_00039_18
# 75119_6236_00039_18
# 75119_6236_00035_7
# 75119_6236_00035_7
# 75119_6236_00035_58
# 75119_6236_00035_58
# 75119_6236_00027_93
# 75119_6236_00027_93
# 75119_6236_00027_34
# 75119_6236_00027_34
# 75119_6236_00027_34
# 75119_6236_00021_9
# 75119_6236_00021_9
# 75119_6236_00021_3
# 75119_6236_00021_3
# 75119_6236_00016_15
# 75119_6236_00016_15
# 75119_6236_00015_12
# 75119_6236_00015_12
# 75119_6236_00012_10
# 75119_6236_00012_10
# 75119_6172_00047_56
# 75119_6172_00047_56
# 75119_6172_00046_343
# 75119_6172_00046_343
# 75119_6170_00038_50
# 75119_6170_00038_50
# 75119_6170_00018_244
# 75119_6170_00018_244
# 75119_6114_00038_5
# 75119_6114_00038_5
# 75119_6114_00028_6
# 75119_6114_00028_6
# 75119_6114_00028_19
# 75119_6114_00028_19
# 75119_6114_00028_19
# 75119_6113_00002_46
# 75119_6113_00002_46
# 75119_6109_00028_5
# 75119_6109_00028_5
# 75119_6109_00016_65
# 75119_6109_00016_65
# 75119_6109_00014_308
# 75119_6109_00014_308
# 75119_5976_00121_293
# 75119_5976_00121_293
# 75119_5976_00121_280
# 75119_5976_00121_280
# 75119_5976_00115_5
# 75119_5976_00115_5
# 75119_5976_00115_5
# 75119_5976_00115_18
# 75119_5976_00115_18
# 75119_5976_00109_39
# 75119_5976_00109_39
# 75119_5976_00109_20
# 75119_5976_00109_20
# 75119_5976_00105_12
# 75119_5976_00105_12
# 75119_5976_00097_13
# 75119_5976_00097_13
# 75119_5976_00085_19
# 75119_5976_00085_19
# 75119_5976_00085_19
# 75119_5976_00068_5
# 75119_5976_00068_5
# 75119_5976_00068_15
# 75119_5976_00068_15
# 75119_5976_00043_356
# 75119_5976_00043_356
# 75119_5976_00042_132
# 75119_5976_00042_132
# 75119_5976_00042_126
# 75119_5976_00042_126
# 75119_5976_00042_126
# 75119_5976_00039_210
# 75119_5976_00039_210
# 75119_5976_00031_47
# 75119_5976_00031_47
# 75119_5976_00022_30
# 75119_5976_00022_30
# 75119_5976_00022_30
# 75119_5976_00022_15
# 75119_5976_00022_15
# 75119_5976_00021_56
# 75119_5976_00021_56
# 75119_5976_00011_88
# 75119_5976_00011_88
# 75119_5976_00011_86
# 75119_5976_00011_86
# 75119_5976_00011_118
# 75119_5976_00011_118
# 75119_5876_00146_34
# 75119_5876_00146_34
# 75119_5781_00008_432
# 75119_5781_00008_432
# 75119_5781_00008_257
# 75119_5781_00008_257
# 75119_5755_00028_24
# 75119_5755_00028_24
# 75119_5755_00017_46
# 75119_5755_00017_46
# 75119_5755_00017_29
# 75119_5755_00017_29
# 75119_5732_00090_29
# 75119_5732_00090_29
# 75119_5732_00082_95
# 75119_5732_00082_95
# 75119_5732_00082_14
# 75119_5732_00082_14
# 75119_5732_00082_126
# 75119_5732_00082_126
# 75119_5732_00082_126
# 75119_5732_00040_43
# 75119_5732_00040_43
# 75119_5732_00014_456
# 75119_5732_00014_456
# 75119_5732_00014_443
# 75119_5732_00014_443
# 75119_5683_00006_9
# 75119_5683_00006_9
# 75119_5661_00012_61
# 75119_5661_00012_61
# 75119_5558_00013_61
# 75119_5558_00013_61
# 75119_5558_00013_23
# 75119_5558_00013_23
# 75119_5558_00013_23
# 75119_5558_00006_71
# 75119_5558_00006_71
# 75119_5558_00006_59
# 75119_5558_00006_59
# 75119_5404_00010_19
# 75119_5404_00010_19
# 75119_5393_00037_34
# 75119_5393_00037_34
# 75119_5393_00027_21
# 75119_5393_00027_21
# 75119_5393_00027_19
# 75119_5393_00027_19
# 75119_5393_00011_7
# 75119_5393_00011_7
# 75119_5393_00011_29
# 75119_5393_00011_29
# 75119_5393_00011_29
# 75119_5393_00009_25
# 75119_5393_00009_25
# 75119_5393_00005_8
# 75119_5393_00005_8
# 75119_5281_00018_19
# 75119_5281_00018_19
# 75119_5281_00016_12
# 75119_5281_00016_12
# 75119_5196_00005_2
# 75119_5196_00005_2
# 75119_5100_00004_20
# 75119_5100_00004_20
# 75119_4990_00015_135
# 75119_4990_00015_135
# 75119_4990_00015_125
# 75119_4990_00015_125
# 75119_4990_00002_92
# 75119_4990_00002_92
# 75119_4990_00002_65
# 75119_4990_00002_65
# 75119_4919_00008_253
# 75119_4919_00008_253
# 75119_4903_00171_1042
# 75119_4903_00171_1042
# 75119_4903_00167_9
# 75119_4903_00167_9
# 75119_4903_00163_91
# 75119_4903_00163_91
# 75119_4903_00156_288
# 75119_4903_00156_288
# 75119_4903_00156_115
# 75119_4903_00156_115
# 75119_4903_00137_47
# 75119_4903_00137_47
# 75119_4903_00133_17
# 75119_4903_00133_17
# 75119_4903_00133_17
# 75119_4903_00132_56
# 75119_4903_00132_56
# 75119_4903_00121_4
# 75119_4903_00121_4
# 75119_4903_00121_4
# 75119_4903_00118_3086
# 75119_4903_00118_3086
# 75119_4903_00118_2589
# 75119_4903_00118_2589
# 75119_4903_00118_240
# 75119_4903_00118_240
# 75119_4903_00118_2185
# 75119_4903_00118_2185
# 75119_4903_00118_216
# 75119_4903_00118_216
# 75119_4903_00118_203
# 75119_4903_00118_203
# 75119_4903_00118_201
# 75119_4903_00118_201
# 75119_4903_00115_105
# 75119_4903_00115_105
# 75119_4903_00114_9
# 75119_4903_00114_9
# 75119_4903_00114_8
# 75119_4903_00114_8
# 75119_4903_00097_16
# 75119_4903_00097_16
# 75119_4903_00097_10
# 75119_4903_00097_10
# 75119_4903_00092_61
# 75119_4903_00092_61
# 75119_4903_00079_46
# 75119_4903_00079_46
# 75119_4903_00079_45
# 75119_4903_00079_45
# 75119_4903_00077_132
# 75119_4903_00077_132
# 75119_4903_00076_49
# 75119_4903_00076_49
# 75119_4903_00074_119
# 75119_4903_00074_119
# 75119_4903_00066_54
# 75119_4903_00066_54
# 75119_4903_00064_44
# 75119_4903_00064_44
# 75119_4903_00064_39
# 75119_4903_00064_39
# 75119_4903_00050_53
# 75119_4903_00050_53
# 75119_4903_00049_32
# 75119_4903_00049_32
# 75119_4903_00037_283
# 75119_4903_00037_283
# 75119_4903_00037_179
# 75119_4903_00037_179
# 75119_4903_00037_137
# 75119_4903_00037_137
# 75119_4903_00017_32
# 75119_4903_00017_32
# 75119_4903_00017_22
# 75119_4903_00017_22
# 75119_4903_00004_13
# 75119_4903_00004_13
# 75119_4903_00003_114
# 75119_4903_00003_114
# 75119_4816_00012_14
# 75119_4816_00012_14
# 75119_4510_00140_8
# 75119_4510_00140_8
# 75119_4510_00126_1164
# 75119_4510_00126_1164
# 75119_4510_00126_1151
# 75119_4510_00126_1151
# 75119_4510_00126_1151
# 75119_4510_00126_1108
# 75119_4510_00126_1108
# 75119_4502_00080_32
# 75119_4502_00080_32
# 75119_4502_00075_5
# 75119_4502_00075_5
# 75119_4502_00025_148
# 75119_4502_00025_148
# 75119_4502_00009_26
# 75119_4502_00009_26
# 75119_4502_00005_2
# 75119_4502_00005_2
# 75119_4481_00009_109
# 75119_4481_00009_109
# 75119_4454_00008_146
# 75119_4454_00008_146
# 75119_4308_00013_63
# 75119_4308_00013_63
# 75119_4197_00015_99
# 75119_4197_00015_99
# 75119_4197_00015_90
# 75119_4197_00015_90
# 75119_4197_00011_96
# 75119_4197_00011_96
# 75119_4197_00011_101
# 75119_4197_00011_101
# 75119_4137_00004_61
# 75119_4137_00004_61
# 75119_4137_00003_18
# 75119_4137_00003_18
# 75119_4061_00016_4
# 75119_4061_00016_4
# 75119_4021_00010_4
# 75119_4021_00010_4
# 75119_3962_00013_63
# 75119_3962_00013_63
# 75119_3773_00002_61
# 75119_3773_00002_61
# 75119_3773_00002_46
# 75119_3773_00002_46
# 75119_3773_00002_3
# 75119_3773_00002_3
# 75119_3773_00002_18
# 75119_3773_00002_18
# 75119_3659_00150_45
# 75119_3659_00150_45
# 75119_3659_00150_13
# 75119_3659_00150_13
# 75119_3659_00144_5
# 75119_3659_00144_5
# 75119_3659_00144_15
# 75119_3659_00144_15
# 75119_3659_00126_34
# 75119_3659_00126_34
# 75119_3659_00126_12
# 75119_3659_00126_12
# 75119_3659_00124_26
# 75119_3659_00124_26
# 75119_3659_00119_11084
# 75119_3659_00119_11084
# 75119_3659_00119_11072
# 75119_3659_00119_11072
# 75119_3659_00119_11036
# 75119_3659_00119_11036
# 75119_3659_00119_11028
# 75119_3659_00119_11028
# 75119_3659_00100_46
# 75119_3659_00100_46
# 75119_3659_00086_83
# 75119_3659_00086_83
# 75119_3659_00086_73
# 75119_3659_00086_73
# 75119_3659_00082_26
# 75119_3659_00082_26
# 75119_3659_00082_26
# 75119_3659_00072_48
# 75119_3659_00072_48
# 75119_3659_00066_104
# 75119_3659_00066_104
# 75119_3659_00062_35
# 75119_3659_00062_35
# 75119_3659_00042_7
# 75119_3659_00042_7
# 75119_3659_00036_77
# 75119_3659_00036_77
# 75119_3659_00030_25
# 75119_3659_00030_25
# 75119_3659_00030_18
# 75119_3659_00030_18
# 75119_3659_00030_13
# 75119_3659_00030_13
# 75119_3659_00010_209
# 75119_3659_00010_209
# 75119_3628_00009_13
# 75119_3628_00009_13
# 75119_3628_00007_25
# 75119_3628_00007_25
# 75119_3625_00049_16
# 75119_3625_00049_16
# 75119_3625_00038_37
# 75119_3625_00038_37
# 75119_3625_00033_640
# 75119_3625_00033_640
# 75119_3625_00026_102
# 75119_3625_00026_102
# 75119_3625_00022_1386
# 75119_3625_00022_1386
# 75119_3625_00010_85
# 75119_3625_00010_85
# 75119_3625_00010_82
# 75119_3625_00010_82
# 75119_3625_00005_9
# 75119_3625_00005_9
# 75119_3455_00018_432
# 75119_3455_00018_432
# 75119_3455_00018_432
# 75119_3455_00018_411
# 75119_3455_00018_411
# 75119_3455_00018_407
# 75119_3455_00018_407
# 75119_3455_00018_403
# 75119_3455_00018_403
# 75119_3455_00011_7
# 75119_3455_00011_7
# 75119_3455_00011_27
# 75119_3455_00011_27
# 75119_3455_00011_25
# 75119_3455_00011_25
# 75119_3455_00011_25
# 75119_3455_00010_16
# 75119_3455_00010_16
# 75119_3417_00026_8
# 75119_3417_00026_8
# 75119_3417_00025_31
# 75119_3417_00025_31
# 75119_3417_00024_13
# 75119_3417_00024_13
# 75119_3417_00020_16
# 75119_3417_00020_16
# 75119_3417_00019_9
# 75119_3417_00019_9
# 75119_3417_00014_8
# 75119_3417_00014_8
# 75119_3417_00014_22
# 75119_3417_00014_22
# 75119_3417_00014_21
# 75119_3417_00014_21
# 75119_3417_00011_7
# 75119_3417_00011_7
# 75119_3417_00011_7
# 75119_3417_00011_7
# 75119_3308_00020_36
# 75119_3308_00020_36
# 75119_3278_00005_61
# 75119_3278_00005_61
# 75119_3278_00005_60
# 75119_3278_00005_60
# 75119_3221_00024_3
# 75119_3221_00024_3
# 75119_3170_00009_8
# 75119_3170_00009_8
# 75119_3152_00056_31
# 75119_3152_00056_31
# 75119_3152_00056_31
# 75119_3114_00011_1
# 75119_3114_00011_1
# 75119_3114_00004_4
# 75119_3114_00004_4
# 75119_3114_00004_3
# 75119_3114_00004_3
# 75119_3063_00011_31
# 75119_3063_00011_31
# 75119_3063_00001_47
# 75119_3063_00001_47
# 75119_3063_00001_127
# 75119_3063_00001_127
# 75119_2870_00030_24
# 75119_2870_00030_24
# 75119_2870_00024_4
# 75119_2870_00024_4
# 75119_2870_00010_7
# 75119_2870_00010_7
# 75119_2870_00010_6
# 75119_2870_00010_6
# 75119_2870_00010_6
# 75119_2734_00008_409
# 75119_2734_00008_409
# 75119_2709_00007_12
# 75119_2709_00007_12
# 75119_2709_00003_78
# 75119_2709_00003_78
# 75119_2709_00003_56
# 75119_2709_00003_56
# 75119_2683_00009_228
# 75119_2683_00009_228
# 75119_2683_00005_6
# 75119_2683_00005_6
# 75119_2683_00003_20
# 75119_2683_00003_20
# 75119_2601_00003_13
# 75119_2601_00003_13
# 75119_2532_00009_9
# 75119_2532_00009_9
# 75119_2532_00009_12
# 75119_2532_00009_12
# 75119_2494_00070_96
# 75119_2494_00070_96
# 75119_2494_00044_86
# 75119_2494_00044_86
# 75119_2494_00034_6
# 75119_2494_00034_6
# 75119_2494_00021_70
# 75119_2494_00021_70
# 75119_2494_00021_53
# 75119_2494_00021_53
# 75119_2443_00241_37
# 75119_2443_00241_37
# 75119_2443_00232_34
# 75119_2443_00232_34
# 75119_2443_00215_5
# 75119_2443_00215_5
# 75119_2443_00215_16
# 75119_2443_00215_16
# 75119_2443_00207_79
# ...
# 75103_9506_00075_38
# 75103_9506_00062_15
# 75103_9506_00062_15
# 75103_9506_00060_2
# 75103_9506_00060_2
# 75103_9506_00057_24
# 75103_9506_00057_24
# 75103_9506_00045_35
# 75103_9506_00045_35
# 75103_9506_00044_6
# 75103_9506_00044_6
# 75103_9506_00038_14
# 75103_9506_00038_14
# 75103_9504_00087_13
# 75103_9504_00087_13
# 75103_9504_00079_3
# 75103_9504_00079_3
# 75103_9504_00077_19
# 75103_9504_00077_19
# 75103_9504_00044_12
# 75103_9504_00044_12
# 75103_9504_00040_5
# 75103_9504_00040_5
# 75103_9382_00058_9
# 75103_9382_00058_9
# 75103_9382_00056_50
# 75103_9382_00056_50
# 75103_9382_00045_36
# 75103_9382_00045_36
# 75103_9298_00013_43
# 75103_9298_00013_43
# 75103_9191_00189_26
# 75103_9191_00189_26
# 75103_9191_00170_215
# 75103_9191_00170_215
# 75103_9191_00167_38
# 75103_9191_00167_38
# 75103_9191_00161_9
# 75103_9191_00161_9
# 75103_9191_00159_102
# 75103_9191_00159_102
# 75103_9191_00138_48
# 75103_9191_00138_48
# 75103_9191_00102_22
# 75103_9191_00102_22
# 75103_9191_00081_65
# 75103_9191_00081_65
# 75103_9191_00081_59
# 75103_9191_00081_59
# 75103_9190_00037_63
# 75103_9190_00037_63
# 75103_9190_00017_33
# 75103_9190_00017_33
# 75103_9190_00017_31
# 75103_9190_00017_31
# 75103_8716_00065_15
# 75103_8716_00065_15
# 75103_8716_00059_9
# 75103_8716_00059_9
# 75103_8716_00042_11
# 75103_8716_00042_11
# 75103_8716_00026_118
# 75103_8716_00026_118
# 75103_8716_00022_14
# 75103_8716_00022_14
# 75103_8694_00341_52
# 75103_8694_00341_52
# 75103_8694_00318_3
# 75103_8694_00318_3
# 75103_8694_00314_210
# 75103_8694_00314_210
# 75103_8694_00245_9
# 75103_8694_00245_9
# 75103_8694_00245_8
# 75103_8694_00245_8
# 75103_8694_00236_6
# 75103_8694_00236_6
# 75103_8694_00227_31
# 75103_8694_00227_31
# 75103_8694_00210_9
# 75103_8694_00210_9
# 75103_8694_00177_7
# 75103_8694_00177_7
# 75103_8694_00171_12
# 75103_8694_00171_12
# 75103_8694_00163_56
# 75103_8694_00163_56
# 75103_8694_00163_103
# 75103_8694_00163_103
# 75103_8692_00055_9
# 75103_8692_00055_9
# 75103_8692_00037_34
# 75103_8692_00037_34
# 75103_8692_00007_4
# 75103_8692_00007_4
# 75103_8552_00004_68
# 75103_8552_00004_68
# 75103_8538_00007_16
# 75103_8538_00007_16
# 75103_8531_00016_10
# 75103_8531_00016_10
# 75103_8520_00020_212
# 75103_8520_00020_212
# 75103_8520_00010_44
# 75103_8520_00010_44
# 75103_8073_00030_7
# 75103_8073_00030_7
# 75103_8073_00030_59
# 75103_8073_00030_59
# 75103_8073_00018_5
# 75103_8073_00018_5
# 75103_8073_00018_2
# 75103_8073_00018_2
# 75103_8009_00058_12
# 75103_8009_00058_12
# 75103_8009_00026_29
# 75103_8009_00026_29
# 75103_8009_00026_29
# 75103_8009_00020_32
# 75103_8009_00020_32
# 75103_8009_00020_21
# 75103_8009_00020_21
# 75103_7970_00100_15
# 75103_7970_00100_15
# 75103_7970_00088_5
# 75103_7970_00088_5
# 75103_7970_00088_4
# 75103_7970_00088_4
# 75103_7970_00086_16
# 75103_7970_00086_16
# 75103_7729_00005_9
# 75103_7729_00005_9
# 75103_7605_00025_5
# 75103_7605_00025_5
# 75103_7572_00025_18
# 75103_7572_00025_18
# 75103_7572_00024_116
# 75103_7572_00024_116
# 75103_7572_00023_15
# 75103_7572_00023_15
# 75103_7572_00023_15
# 75103_7572_00019_11
# 75103_7572_00019_11
# 75103_7572_00006_4
# 75103_7572_00006_4
# 75103_7395_00011_19
# 75103_7395_00011_19
# 75103_7395_00009_16
# 75103_7395_00009_16
# 75103_7248_00011_64
# 75103_7248_00011_64
# 75103_7248_00011_24
# 75103_7248_00011_24
# 75103_7248_00011_17
# 75103_7248_00011_17
# 75103_7248_00011_15
# 75103_7248_00011_15
# 75103_7248_00007_6
# 75103_7248_00007_6
# 75103_7151_00003_22
# 75103_7151_00003_22
# 75103_7094_00044_21
# 75103_7094_00044_21
# 75103_7061_00016_684
# 75103_7061_00016_684
# 75103_6983_00009_8
# 75103_6983_00009_8
# 75103_6834_00084_8
# 75103_6834_00084_8
# 75103_6834_00079_20
# 75103_6834_00079_20
# 75103_6834_00076_264
# 75103_6834_00076_264
# 75103_6834_00068_31
# 75103_6834_00068_31
# 75103_6834_00067_6
# 75103_6834_00067_6
# 75103_6834_00066_37
# 75103_6834_00066_37
# 75103_6834_00058_10
# 75103_6834_00058_10
# 75103_6834_00056_6
# 75103_6834_00056_6
# 75103_6834_00050_8
# 75103_6834_00050_8
# 75103_6834_00044_36
# 75103_6834_00044_36
# 75103_6834_00036_14
# 75103_6834_00036_14
# 75103_6834_00035_25
# 75103_6834_00035_25
# 75103_6834_00034_113
# 75103_6834_00034_113
# 75103_6834_00030_6
# 75103_6834_00030_6
# 75103_6834_00028_6
# 75103_6834_00028_6
# 75103_6834_00028_26
# 75103_6834_00028_26
# 75103_6834_00026_58
# 75103_6834_00026_58
# 75103_6834_00019_133
# 75103_6834_00019_133
# 75103_6834_00018_16
# 75103_6834_00018_16
# 75103_6834_00013_42
# 75103_6834_00013_42
# 75103_6834_00010_33
# 75103_6834_00010_33
# 75103_6834_00009_44
# 75103_6834_00009_44
# 75103_6834_00007_19
# 75103_6834_00007_19
# 75103_6834_00007_17
# 75103_6834_00007_17
# 75103_6834_00005_16
# 75103_6834_00005_16
# 75103_6517_00037_24
# 75103_6517_00037_24
# 75103_6517_00034_7
# 75103_6517_00034_7
# 75103_6517_00034_7
# 75103_6497_00008_6
# 75103_6497_00008_6
# 75103_6336_00023_36
# 75103_6336_00023_36
# 75103_6336_00021_25
# 75103_6336_00021_25
# 75103_6336_00018_18
# 75103_6336_00018_18
# 75103_6336_00015_21
# 75103_6336_00015_21
# 75103_6286_00050_39
# 75103_6286_00050_39
# 75103_6286_00050_39
# 75103_6286_00048_28
# 75103_6286_00048_28
# 75103_6286_00041_4
# 75103_6286_00041_4
# 75103_6286_00041_14
# 75103_6286_00041_14
# 75103_6286_00032_52
# 75103_6286_00032_52
# 75103_6286_00022_16
# 75103_6286_00022_16
# 75103_5927_00059_6
# 75103_5927_00059_6
# 75103_5927_00059_11
# 75103_5927_00059_11
# 75103_5927_00049_7
# 75103_5927_00049_7
# 75103_5927_00049_7
# 75103_5927_00012_27
# 75103_5927_00012_27
# 75103_4302_00059_115
# 75103_4302_00059_115
# 75103_4302_00052_14
# 75103_4302_00052_14
# 75103_4302_00018_9
# 75103_4302_00018_9
# 75103_4302_00018_9
# 75103_4302_00005_18
# 75103_4302_00005_18
# 75103_4301_00003_5
# 75103_4301_00003_5
# 75103_3875_00014_21
# 75103_3875_00014_21
# 75103_3875_00004_4
# 75103_3875_00004_4
# 75103_3820_00048_4
# 75103_3820_00048_4
# 75103_3820_00046_34
# 75103_3820_00046_34
# 75103_3698_00006_57
# 75103_3698_00006_57
# 75103_3698_00004_5
# 75103_3698_00004_5
# 75103_3643_00012_8
# 75103_3643_00012_8
# 75103_3643_00006_11
# 75103_3643_00006_11
# 75103_3643_00004_65
# 75103_3643_00004_65
# 75103_3196_00015_12
# 75103_3196_00015_12
# 75103_3196_00015_11
# 75103_3196_00015_11
# 75103_2997_00016_29
# 75103_2997_00016_29
# 75103_2997_00002_13
# 75103_2997_00002_13
# 75103_2996_00004_15
# 75103_2996_00004_15
# 75103_2616_00031_67
# 75103_2616_00031_67
# 75103_2616_00029_5
# 75103_2616_00029_5
# 75103_2616_00010_4
# 75103_2616_00010_4
# 75103_2412_00022_11
# 75103_2412_00022_11
# 75103_2330_00014_30
# 75103_2330_00014_30
# 75103_2249_00019_10
# 75103_2249_00019_10
# 75103_2249_00012_68
# 75103_2249_00012_68
# 75103_1880_00077_134
# 75103_1880_00077_134
# 75103_1880_00077_128
# 75103_1880_00077_128
# 75103_1880_00067_4
# 75103_1880_00067_4
# 75103_1880_00049_9
# 75103_1880_00049_9
# 75103_1880_00043_29
# 75103_1880_00043_29
# 75103_1880_00033_109
# 75103_1880_00033_109
# 75103_1880_00023_3
# 75103_1880_00023_3
# 75103_1880_00020_10
# 75103_1880_00020_10
# 75103_1880_00020_10
# 75103_1771_00056_520
# 75103_1771_00056_520
# 75103_1771_00054_14
# 75103_1771_00054_14
# 75103_1771_00054_14
# 75103_1771_00028_26
# 75103_1771_00028_26
# 75103_1771_00026_18
# 75103_1771_00026_18
# 75103_1771_00024_16
# 75103_1771_00024_16
# 75103_1771_00011_18
# 75103_1771_00011_18
# 75103_1413_00016_27
# 75103_1413_00016_27
# 75103_1413_00008_3
# 75103_1413_00008_3
# 75103_1275_00069_10
# 75103_1275_00069_10
# 75103_1275_00025_18
# 75103_1275_00025_18
# 75103_1275_00017_12
# 75103_1275_00017_12
# 75103_1261_00009_27
# 75103_1261_00009_27
# 75103_1021_00003_27
# 75103_1021_00003_27
# 75103_0871_00024_32
# 75103_0871_00024_32
# 75103_0871_00021_31
# 75103_0871_00021_31
# 75103_0871_00020_13
# 75103_0871_00020_13
# 75103_0871_00019_37
# 75103_0871_00019_37
# 75103_0783_00113_58
# 75103_0783_00113_58
# 75103_0783_00113_18
# 75103_0783_00113_18
# 75103_0783_00085_51
# 75103_0783_00085_51
# 75103_0783_00083_6
# 75103_0783_00083_6
# 75103_0761_00018_9
# 75103_0761_00018_9
# 75103_0420_00096_10
# 75103_0420_00096_10
# 75103_0420_00090_88
# 75103_0420_00090_88
# 75103_0420_00079_31
# 75103_0420_00079_31
# 75103_0420_00078_11
# 75103_0420_00078_11
# 75103_0420_00075_204
# 75103_0420_00075_204
# 75103_0420_00059_47
# 75103_0420_00059_47
# 75103_0420_00055_137
# 75103_0420_00055_137
# 75103_0420_00047_7
# 75103_0420_00047_7
# 75102_9900_00002_10
# 75102_9900_00002_10
# 75102_9893_00046_10
# 75102_9893_00046_10
# 75102_9893_00042_20
# 75102_9893_00042_20
# 75102_9893_00028_6
# 75102_9893_00028_6
# 75102_9834_00009_6
# 75102_9834_00009_6
# 75102_9834_00009_5
# 75102_9834_00009_5
# 75102_9834_00002_32
# 75102_9834_00002_32
# 75102_9741_00008_9
# 75102_9741_00008_9
# 75102_9504_00022_19
# 75102_9504_00022_19
# 75102_9408_00009_8
# 75102_9408_00009_8
# 75102_9408_00007_32
# 75102_9408_00007_32
# 75102_9318_00062_58
# 75102_9318_00062_58
# 75102_9318_00062_13
# 75102_9318_00062_13
# 75102_9318_00054_4
# 75102_9318_00054_4
# 75102_9318_00044_2
# 75102_9318_00044_2
# 75102_9318_00036_13
# 75102_9318_00036_13
# 75102_9318_00035_9
# 75102_9318_00035_9
# 75102_9318_00031_3
# 75102_9318_00031_3
# 75102_9318_00012_3
# 75102_9318_00012_3
# 75102_9318_00002_14
# 75102_9318_00002_14
# 75102_8894_00133_9
# 75102_8894_00133_9
# 75102_8752_00057_5
# 75102_8752_00057_5
# 75102_8752_00024_39
# 75102_8752_00024_39
# 75102_8752_00024_36
# 75102_8752_00024_36
# 75102_8752_00024_28
# 75102_8752_00024_28
# 75102_8752_00005_4
# 75102_8752_00005_4
# 75102_8686_00008_197
# 75102_8686_00008_197
# 75102_8686_00008_195
# 75102_8686_00008_195
# 75102_8686_00008_195
# 75102_8609_00018_3
# 75102_8609_00018_3
# 75102_8561_00014_96
# 75102_8561_00014_96
# 75102_8561_00014_5
# 75102_8561_00014_5
# 75102_8561_00014_168
# 75102_8561_00014_168
# 75102_8561_00014_166
# 75102_8561_00014_166
# 75102_8561_00014_125
# 75102_8561_00014_125
# 75102_8538_00023_91
# 75102_8538_00023_91
# 75102_8538_00019_14
# 75102_8538_00019_14
# 75102_8538_00016_9
# 75102_8538_00016_9
# 75102_8538_00016_11
# 75102_8538_00016_11
# 75102_8534_00071_12
# 75102_8534_00071_12
# 75102_8534_00046_18
# 75102_8534_00046_18
# 75102_8525_00271_55
# 75102_8525_00271_55
# 75102_8525_00251_8
# 75102_8525_00251_8
# 75102_8525_00251_6
# 75102_8525_00251_6
# 75102_8525_00251_10
# 75102_8525_00251_10
# 75102_8525_00228_114
# 75102_8525_00228_114
# 75102_8525_00216_5
# 75102_8525_00216_5
# 75102_8525_00187_25
# 75102_8525_00187_25
# 75102_8525_00187_16
# 75102_8525_00187_16
# 75102_8525_00183_31
# 75102_8525_00183_31
# 75102_8525_00163_84
# 75102_8525_00163_84
# 75102_8525_00142_23
# 75102_8525_00142_23
# 75102_8525_00142_11
# 75102_8525_00142_11
# 75102_8525_00141_112
# 75102_8525_00141_112
# 75102_8525_00136_104
# 75102_8525_00136_104
# 75102_8525_00128_8
# 75102_8525_00128_8
# 75102_8525_00126_16
# 75102_8525_00126_16
# 75102_8525_00118_7
# 75102_8525_00118_7
# 75102_8493_00003_14
# 75102_8493_00003_14
# 75102_8212_00110_69
# 75102_8212_00110_69
# 75102_8073_00085_15
# 75102_8073_00085_15
# 75102_7738_00010_13
# 75102_7738_00010_13
# 75102_7738_00010_13
# 75102_7561_00031_12
# 75102_7561_00031_12
# 75102_7561_00030_5
# 75102_7561_00030_5
# 75102_7346_00037_38
# 75102_7346_00037_38
# 75102_7346_00019_17
# 75102_7346_00019_17
# 75102_7346_00010_10
# 75102_7346_00010_10
# 75102_7346_00005_19
# 75102_7346_00005_19
# 75102_7346_00003_32
# 75102_7346_00003_32
# 75102_7028_00022_331
# 75102_7028_00022_331
# 75102_6998_00006_42
# 75102_6998_00006_42
# 75102_6836_00020_18
# 75102_6836_00020_18
# 75102_6836_00018_6
# 75102_6836_00018_6
# 75102_6783_00010_19
# 75102_6783_00010_19
# 75102_6783_00003_18
# 75102_6783_00003_18
# 75102_6635_00007_22
# 75102_6635_00007_22
# 75102_6635_00002_7
# 75102_6635_00002_7
# 75102_6520_00076_12
# 75102_6520_00076_12
# 75102_6520_00071_14
# 75102_6520_00071_14
# 75102_6513_00164_14
# 75102_6513_00164_14
# 75102_6513_00159_134
# 75102_6513_00159_134
# 75102_6513_00152_105
# 75102_6513_00152_105
# 75102_6513_00112_14
# 75102_6513_00112_14
# 75102_6513_00064_5
# 75102_6513_00064_5
# 75102_6513_00062_8
# 75102_6513_00062_8
# 75102_6513_00055_28
# 75102_6513_00055_28
# 75102_6513_00055_21
# 75102_6513_00055_21
# 75102_6513_00055_15
# 75102_6513_00055_15
# 75102_6513_00049_8
# 75102_6513_00049_8
# 75102_6510_00017_64
# 75102_6510_00017_64
# 75102_6124_00019_40
# 75102_6124_00019_40
# 75102_5974_00014_6
# 75102_5974_00014_6
# 75102_5974_00007_3
# 75102_5974_00007_3
# 75102_5913_00009_15
# 75102_5913_00009_15
# 75102_5850_00035_55
# 75102_5850_00035_55
# 75102_5850_00035_37
# 75102_5850_00035_37
# 75102_5820_00005_37
# 75102_5820_00005_37
# 75102_5582_00028_18
# 75102_5582_00028_18
# 75102_5302_00020_64
# 75102_5302_00020_64
# 75102_5302_00020_11
# 75102_5302_00020_11
# 75102_5302_00018_17
# 75102_5302_00018_17
# 75102_4973_00018_39
# 75102_4973_00018_39
# 75102_4973_00001_6
# 75102_4973_00001_6
# 75102_4973_00001_4
# 75102_4973_00001_4
# 75102_4318_00048_34
# 75102_4318_00048_34
# 75102_4318_00048_27
# 75102_4318_00048_27
# 75102_3779_00012_45
# 75102_3779_00012_45
# 75102_3635_00034_6
# 75102_3635_00034_6
# 75102_3635_00032_35
# 75102_3635_00032_35
# 75102_3055_00022_301
# 75102_3055_00022_301
# 75102_3055_00020_157
# 75102_3055_00020_157
# 75102_2451_00017_3
# 75102_2451_00017_3
# 75102_2451_00013_22
# 75102_2451_00013_22
# 75102_2451_00008_111
# 75102_2451_00008_111
# 75102_2110_00100_37
# 75102_2110_00100_37
# 75102_2110_00089_24
# 75102_2110_00089_24
# 75102_2110_00051_30
# 75102_2110_00051_30
# 75102_2110_00035_43
# 75102_2110_00035_43
# 75102_2110_00008_12
# 75102_2110_00008_12
# 75102_2110_00006_16
# 75102_2110_00006_16
# 75102_2110_00006_16
# 75102_2013_00019_33
# 75102_2013_00019_33
# 75102_1432_00043_29
# 75102_1432_00043_29
# 75102_1432_00042_13
# 75102_1432_00042_13
# 75102_1432_00019_21
# 75102_1432_00019_21
# 75102_1317_00002_4
# 75102_1317_00002_4
# 75102_1021_00021_21
# 75102_1021_00021_21
# 75102_0789_00050_10
# 75102_0789_00050_10
# 75102_0789_00028_32
# 75102_0789_00028_32
# 75102_0789_00014_32
# 75102_0789_00014_32
# 75102_0622_00006_12
# 75102_0622_00006_12
# 75102_0440_00044_4
# 75102_0440_00044_4
# 75102_0440_00007_8
# 75102_0440_00007_8
# 75102_0040_00130_19
# 75102_0040_00130_19
# 75102_0040_00117_28
# 75102_0040_00117_28
# 75102_0040_00094_31
# 75102_0040_00094_31
# 75102_0040_00094_25
# 75102_0040_00094_25
# 75101_8894_00043_6
# 75101_8894_00043_6
# 75101_8894_00039_57
# 75101_8894_00039_57
# 75101_8894_00037_31
# 75101_8894_00037_31
# 75101_8894_00007_17
# 75101_8894_00007_17
# 75101_8855_00005_18
# 75101_8855_00005_18
# 75101_8641_00008_154
# 75101_8641_00008_154
# 75101_8635_00304_9
# 75101_8635_00304_9
# 75101_8635_00304_4
# 75101_8635_00304_4
# 75101_8635_00304_4
# 75101_8635_00209_8
# 75101_8635_00209_8
# 75101_8635_00191_81
# 75101_8635_00191_81
# 75101_8635_00179_19
# 75101_8635_00179_19
# 75101_8635_00179_19
# 75101_8635_00173_29
# 75101_8635_00173_29
# 75101_8635_00127_108
# 75101_8635_00127_108
# 75101_8635_00123_219
# 75101_8635_00123_219
# 75101_8635_00089_22
# 75101_8635_00089_22
# 75101_8635_00035_16
# 75101_8635_00035_16
# 75101_8623_00013_7
# 75101_8623_00013_7
# 75101_8623_00013_5
# 75101_8623_00013_5
# 75101_8611_00010_27
# 75101_8611_00010_27
# 75101_8534_00034_16
# 75101_8534_00034_16
# 75101_8534_00030_7
# 75101_8534_00030_7
# 75101_8525_00079_11
# 75101_8525_00079_11
# 75101_8525_00015_5
# 75101_8525_00015_5
# 75101_8397_00017_14
# 75101_8397_00017_14
# 75101_8397_00003_18
# 75101_8397_00003_18
# 75101_8249_00140_27
# 75101_8249_00140_27
# 75101_8212_00056_63
# 75101_8212_00056_63
# 75101_8212_00043_120
# 75101_8212_00043_120
# 75101_7902_00005_49
# 75101_7902_00005_49
# 75101_7348_00007_10
# 75101_7348_00007_10
# 75101_7279_00005_52
# 75101_7279_00005_52
# 75101_6537_00032_7
# 75101_6537_00032_7
# 75101_6520_00032_46
# 75101_6520_00032_46
# 75101_6520_00027_67
# 75101_6520_00027_67
# 75101_6520_00027_66
# 75101_6520_00027_66
# 75101_6513_00026_42
# 75101_6513_00026_42
# 75101_6513_00026_42
# 75101_6513_00017_107
# 75101_6513_00017_107
# 75101_6407_00009_7
# 75101_6407_00009_7
# 75101_6407_00009_18
# 75101_6407_00009_18
# 75101_6407_00005_113
# 75101_6407_00005_113
# 75101_6249_00020_56
# 75101_6249_00020_56
# 75101_6034_00006_19
# 75101_6034_00006_19
# 75101_6033_00036_7
# 75101_6033_00036_7
# 75101_6033_00034_39
# 75101_6033_00034_39
# 75101_6033_00019_14
# 75101_6033_00019_14
# 75101_6033_00017_3
# 75101_6033_00017_3
# 75101_5825_00015_113
# 75101_5825_00015_113
# 75101_5417_00008_24
# 75101_5417_00008_24
# 75101_5368_00010_8
# 75101_5368_00010_8
# 75101_4901_00019_199
# 75101_4901_00019_199
# 75101_4619_00013_57
# 75101_4619_00013_57
# 75101_4461_00019_25
# 75101_4461_00019_25
# 75101_3621_00011_9
# 75101_3621_00011_9
# 75101_3392_00027_24
# 75101_3392_00027_24
# 75101_3392_00003_5
# 75101_3392_00003_5
# 75101_2999_00017_21
# 75101_2999_00017_21
# 75101_2594_00016_12
# 75101_2594_00016_12
# 75101_2502_00009_5
# 75101_2453_00020_83
# 75101_2453_00020_83
# 75101_2400_00001_8
# 75101_2400_00001_8
# 75101_2318_00031_297
# 75101_2318_00031_297
# 75101_2318_00008_6
# 75101_2318_00008_6
# 75101_1178_00015_12
# 75101_1178_00015_12
# 75101_1178_00013_9
# 75101_1178_00013_9
# 75101_1105_00020_48
# 75101_1105_00020_48
# 75101_0632_00006_20
# 75101_0632_00006_20
# 75101_0632_00006_13
# 75101_0632_00006_13
# 75101_0632_00006_13
# 75101_0407_00056_8
# 75101_0407_00056_8
# 75101_0407_00056_21
# 75101_0407_00056_21
# 75101_0407_00049_5
# 75101_0407_00049_5
# 75101_0407_00049_4
# 75101_0407_00049_4
# not last    9745
# last        9326
# Name: range_revente_last, dtype: int64

# %%
z.head()
# Out:
#                       etaban_lot  anneemut    valeurfonc range_revente_last
# idmutation
# 8421910      75120_9898_00055_22      2017 298300.000000           not last
# 8838640      75120_9898_00055_22      2014 280000.000000           not last
# 8117120     75120_9888_00084_104      2019 506997.000000               last
# 8699817     75120_9888_00084_104      2015 320000.000000           not last
# 7981775       75120_9888_00046_2      2020 394900.000000               last

# %%
# Renommer la valeur de "range_revente_last" en 1ère ligne du df pq elle a servi à la mise en place du compteur
# Elle était donc restée en "not last"

# %%
z["range_revente_last"].iloc[0]="last"
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
# Création de la variable "duree_detention"

z["duree_detention"]=z["anneemut"].diff()

# %%
z.head()
# Out:
#                       etaban_lot  anneemut    valeurfonc range_revente_last  \
# idmutation
# 8421910      75120_9898_00055_22      2017 298300.000000               last
# 8838640      75120_9898_00055_22      2014 280000.000000           not last
# 8117120     75120_9888_00084_104      2019 506997.000000               last
# 8699817     75120_9888_00084_104      2015 320000.000000           not last
# 7981775       75120_9888_00046_2      2020 394900.000000               last
#
#             duree_detention
# idmutation
# 8421910                 NaN
# 8838640           -3.000000
# 8117120            5.000000
# 8699817           -4.000000
# 7981775            5.000000

# %%
# Pour les not last => passer la valeur en positif

# %%
z["duree_detention"][z["range_revente_last"]=="not last"]=-z["duree_detention"][z["range_revente_last"]=="not last"]
# Out:
# C:\Users\Anne\AppData\Local\Temp/ipykernel_3380/1681290974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z["duree_detention"][z["range_revente_last"]=="not last"]=-z["duree_detention"][z["range_revente_last"]=="not last"]

# %%
z.head()
# Out:
#                       etaban_lot  anneemut    valeurfonc range_revente_last  \
# idmutation
# 8421910      75120_9898_00055_22      2017 298300.000000               last
# 8838640      75120_9898_00055_22      2014 280000.000000           not last
# 8117120     75120_9888_00084_104      2019 506997.000000               last
# 8699817     75120_9888_00084_104      2015 320000.000000           not last
# 7981775       75120_9888_00046_2      2020 394900.000000               last
#
#             duree_detention
# idmutation
# 8421910                 NaN
# 8838640            3.000000
# 8117120            5.000000
# 8699817            4.000000
# 7981775            5.000000

# %%
# Réduction du dataframe z aux 2 colonnes "range_revente_last" et "duree_detention"
z=z[["range_revente_last", "duree_detention"]]
z
# Out:
#            range_revente_last  duree_detention
# idmutation
# 8421910                  last              NaN
# 8838640              not last         3.000000
# 8117120                  last         5.000000
# 8699817              not last         4.000000
# 7981775                  last         5.000000
# ...                       ...              ...
# 8712767              not last         3.000000
# 8119208                  last         4.000000
# 8439768              not last         2.000000
# 8105917                  last         2.000000
# 8269301              not last         1.000000
#
# [19071 rows x 2 columns]

# %%
# Fusion des dataframe z et df_selec_2 par un merge left sur l'index "idmutation"
df_selec_2=df_selec_2.merge(right=z, on="idmutation", how="left")

# %%
df_selec_2[["etaban_lot","qty_of_mut", "anneemut", "range_revente_last","duree_detention"]].sort_values(by=["etaban_lot", "anneemut"], ascending=False)
# Out:
#                       etaban_lot  qty_of_mut  anneemut range_revente_last  \
# idmutation
# 8125836       75120_9898_00077_6           0      2019                NaN
# 7862739       75120_9898_00077_5           0      2021                NaN
# 7979060       75120_9898_00077_3           0      2020                NaN
# 8827580      75120_9898_00055_28           0      2014                NaN
# 8565959      75120_9898_00055_27           0      2016                NaN
# ...                          ...         ...       ...                ...
# 8442593      75101_0191_00010_55           0      2017                NaN
# 8412777       75101_0191_00006_4           0      2017                NaN
# 8449734      75101_0191_00005_14           0      2017                NaN
# 8715762       75101_0191_00003_4           0      2015                NaN
# 8817315     75101_0191_00003_110           0      2014                NaN
#
#             duree_detention
# idmutation
# 8125836                 NaN
# 7862739                 NaN
# 7979060                 NaN
# 8827580                 NaN
# 8565959                 NaN
# ...                     ...
# 8442593                 NaN
# 8412777                 NaN
# 8449734                 NaN
# 8715762                 NaN
# 8817315                 NaN
#
# [101507 rows x 5 columns]

# %%
# Après fusion, la variable "range_revente_last" = Nan pour les biens qui n'ont pas mutés pendant la période.
# On remplace Nan par la valeur "last" 
df_selec_2["range_revente_last"]=df_selec_2["range_revente_last"].fillna("last")

# %%
# Création de la variable "annee_en_cours"

from datetime import date, time, datetime
df_selec_2["annee_en_cours"]=date.today().year

# %%
# Pour les last => on remplace durée de détention par = annee_en_cours - annee mutation
df_selec_2["duree_detention"][df_selec_2["range_revente_last"]=="last"]=df_selec_2["annee_en_cours"]-df_selec_2["anneemut"]
# Out:
# C:\Users\Anne\AppData\Local\Temp/ipykernel_3380/1983753952.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selec_2["duree_detention"][df_selec_2["range_revente_last"]=="last"]=df_selec_2["annee_en_cours"]-df_selec_2["anneemut"]

# %%
# Vérif générale
df_selec_2[["etaban_lot","qty_of_mut", "anneemut", "range_revente_last","duree_detention"]].sort_values(by=["etaban_lot", "anneemut"], ascending=False)
# Out:
#                       etaban_lot  qty_of_mut  anneemut range_revente_last  \
# idmutation
# 8125836       75120_9898_00077_6           0      2019               last
# 7862739       75120_9898_00077_5           0      2021               last
# 7979060       75120_9898_00077_3           0      2020               last
# 8827580      75120_9898_00055_28           0      2014               last
# 8565959      75120_9898_00055_27           0      2016               last
# ...                          ...         ...       ...                ...
# 8442593      75101_0191_00010_55           0      2017               last
# 8412777       75101_0191_00006_4           0      2017               last
# 8449734      75101_0191_00005_14           0      2017               last
# 8715762       75101_0191_00003_4           0      2015               last
# 8817315     75101_0191_00003_110           0      2014               last
#
#             duree_detention
# idmutation
# 8125836            3.000000
# 7862739            1.000000
# 7979060            2.000000
# 8827580            8.000000
# 8565959            6.000000
# ...                     ...
# 8442593            5.000000
# 8412777            5.000000
# 8449734            5.000000
# 8715762            7.000000
# 8817315            8.000000
#
# [101507 rows x 5 columns]

# %%
# Vérif sur les qty_of_mut=0
df_selec_2[df_selec_2["qty_of_mut"]==0][["etaban_lot","qty_of_mut", "anneemut", "range_revente_last","duree_detention"]].sort_values(by=["etaban_lot", "anneemut"], ascending=False)
# Out:
#                       etaban_lot  qty_of_mut  anneemut range_revente_last  \
# idmutation
# 8125836       75120_9898_00077_6           0      2019               last
# 7862739       75120_9898_00077_5           0      2021               last
# 7979060       75120_9898_00077_3           0      2020               last
# 8827580      75120_9898_00055_28           0      2014               last
# 8565959      75120_9898_00055_27           0      2016               last
# ...                          ...         ...       ...                ...
# 8442593      75101_0191_00010_55           0      2017               last
# 8412777       75101_0191_00006_4           0      2017               last
# 8449734      75101_0191_00005_14           0      2017               last
# 8715762       75101_0191_00003_4           0      2015               last
# 8817315     75101_0191_00003_110           0      2014               last
#
#             duree_detention
# idmutation
# 8125836            3.000000
# 7862739            1.000000
# 7979060            2.000000
# 8827580            8.000000
# 8565959            6.000000
# ...                     ...
# 8442593            5.000000
# 8412777            5.000000
# 8449734            5.000000
# 8715762            7.000000
# 8817315            8.000000
#
# [82436 rows x 5 columns]

# %%
# Vérif sur les qty_of_mut=1
df_selec_2[df_selec_2["qty_of_mut"]==1][["etaban_lot","qty_of_mut", "anneemut", "range_revente_last","duree_detention"]].sort_values(by=["etaban_lot", "anneemut"], ascending=False)
# Out:
#                       etaban_lot  qty_of_mut  anneemut range_revente_last  \
# idmutation
# 8421910      75120_9898_00055_22           1      2017               last
# 8838640      75120_9898_00055_22           1      2014           not last
# 8117120     75120_9888_00084_104           1      2019               last
# 8699817     75120_9888_00084_104           1      2015           not last
# 7981775       75120_9888_00046_2           1      2020               last
# ...                          ...         ...       ...                ...
# 8712767      75101_0407_00056_21           1      2015           not last
# 8119208       75101_0407_00049_5           1      2019               last
# 8439768       75101_0407_00049_5           1      2017           not last
# 8105917       75101_0407_00049_4           1      2019               last
# 8269301       75101_0407_00049_4           1      2018           not last
#
#             duree_detention
# idmutation
# 8421910            5.000000
# 8838640            3.000000
# 8117120            3.000000
# 8699817            4.000000
# 7981775            2.000000
# ...                     ...
# 8712767            3.000000
# 8119208            3.000000
# 8439768            2.000000
# 8105917            3.000000
# 8269301            1.000000
#
# [17816 rows x 5 columns]

# %%
# Vérif sur les qty_of_mut=2
df_selec_2[df_selec_2["qty_of_mut"]==2][["etaban_lot","qty_of_mut", "anneemut", "range_revente_last","duree_detention"]].sort_values(by=["etaban_lot", "anneemut"], ascending=False)
# Out:
#                      etaban_lot  qty_of_mut  anneemut range_revente_last  \
# idmutation
# 7994587     75120_9132_00015_17           2      2020               last
# 8285264     75120_9132_00015_17           2      2018           not last
# 8698021     75120_9132_00015_17           2      2015           not last
# 7838868     75120_9085_00016_72           2      2021               last
# 8722097     75120_9085_00016_72           2      2015           not last
# ...                         ...         ...       ...                ...
# 8266468     75101_6513_00026_42           2      2018           not last
# 8812325     75101_6513_00026_42           2      2014           not last
# 7857085     75101_0632_00006_13           2      2021               last
# 7972144     75101_0632_00006_13           2      2020           not last
# 8693949     75101_0632_00006_13           2      2015           not last
#
#             duree_detention
# idmutation
# 7994587            2.000000
# 8285264            2.000000
# 8698021            3.000000
# 7838868            1.000000
# 8722097            6.000000
# ...                     ...
# 8266468            3.000000
# 8812325            4.000000
# 7857085            1.000000
# 7972144            1.000000
# 8693949            5.000000
#
# [1211 rows x 5 columns]

# %%
# Vérif sur les qty_of_mut=3
df_selec_2[df_selec_2["qty_of_mut"]==3][["etaban_lot","qty_of_mut", "anneemut", "moismut", "range_revente_last","duree_detention"]].sort_values(by=["etaban_lot", "anneemut"], ascending=False)
# Out:
#                        etaban_lot  qty_of_mut  anneemut  moismut  \
# idmutation
# 8122014        75119_3417_00011_7           3      2019        3
# 8145023        75119_3417_00011_7           3      2019        8
# 8444185        75119_3417_00011_7           3      2017        7
# 8837536        75119_3417_00011_7           3      2014        6
# 7834073        75119_0833_00099_3           3      2021       11
# 7849661        75119_0833_00099_3           3      2021        7
# 8132612        75119_0833_00099_3           3      2019        1
# 8687655        75119_0833_00099_3           3      2015        7
# 7830344        75118_6467_00091_9           3      2021        5
# 7856004        75118_6467_00091_9           3      2021       10
# 7982305        75118_6467_00091_9           3      2020        2
# 8439263        75118_6467_00091_9           3      2017        2
# 7833765       75118_5010_00078_10           3      2021        4
# 8444884       75118_5010_00078_10           3      2017        4
# 8565043       75118_5010_00078_10           3      2016        4
# 8816522       75118_5010_00078_10           3      2014        8
# 7830682        75118_2974_00023_4           3      2021        9
# 8555709        75118_2974_00023_4           3      2016       11
# 8582225        75118_2974_00023_4           3      2016       12
# 8700271        75118_2974_00023_4           3      2015       12
# 7840657        75117_4440_00008_6           3      2021        3
# 8116696        75117_4440_00008_6           3      2019       11
# 8264434        75117_4440_00008_6           3      2018        7
# 8822660        75117_4440_00008_6           3      2014        2
# 8135942      75115_5456_00332_286           3      2019        2
# 8428363      75115_5456_00332_286           3      2017        7
# 8565922      75115_5456_00332_286           3      2016        2
# 8711656      75115_5456_00332_286           3      2015       10
# 7831807       75114_5465_00022_19           3      2021        1
# 7831932       75114_5465_00022_19           3      2021        4
# 8441874       75114_5465_00022_19           3      2017        5
# 8578830       75114_5465_00022_19           3      2016        9
# 8426991       75114_2665_00006_16           3      2017        9
# 8572266       75114_2665_00006_16           3      2016        7
# 8815968       75114_2665_00006_16           3      2014       12
# 8835306       75114_2665_00006_16           3      2014        8
# 7983865       75113_0563_00020_11           3      2020        9
# 8143650       75113_0563_00020_11           3      2019        9
# 8561774       75113_0563_00020_11           3      2016        4
# 8711853       75113_0563_00020_11           3      2015       10
# 7972157     75111_3700_00020_1004           3      2020        6
# 7989750     75111_3700_00020_1004           3      2020       12
# 8117972     75111_3700_00020_1004           3      2019        5
# 8585796     75111_3700_00020_1004           3      2016        9
#
#            range_revente_last  duree_detention
# idmutation
# 8122014                  last         3.000000
# 8145023              not last        -0.000000
# 8444185              not last         2.000000
# 8837536              not last         3.000000
# 7834073                  last         1.000000
# 7849661              not last        -0.000000
# 8132612              not last         2.000000
# 8687655              not last         4.000000
# 7830344                  last         1.000000
# 7856004              not last        -0.000000
# 7982305              not last         1.000000
# 8439263              not last         3.000000
# 7833765                  last         1.000000
# 8444884              not last         4.000000
# 8565043              not last         1.000000
# 8816522              not last         2.000000
# 7830682                  last         1.000000
# 8555709              not last         5.000000
# 8582225              not last        -0.000000
# 8700271              not last         1.000000
# 7840657                  last         1.000000
# 8116696              not last         2.000000
# 8264434              not last         1.000000
# 8822660              not last         4.000000
# 8135942                  last         3.000000
# 8428363              not last         2.000000
# 8565922              not last         1.000000
# 8711656              not last         1.000000
# 7831807                  last         1.000000
# 7831932              not last        -0.000000
# 8441874              not last         4.000000
# 8578830              not last         1.000000
# 8426991                  last         5.000000
# 8572266              not last         1.000000
# 8815968              not last         2.000000
# 8835306              not last        -0.000000
# 7983865                  last         2.000000
# 8143650              not last         1.000000
# 8561774              not last         3.000000
# 8711853              not last         1.000000
# 7972157                  last         2.000000
# 7989750              not last        -0.000000
# 8117972              not last         1.000000
# 8585796              not last         3.000000

# %%
# On constate que certains lots ont été revendus 2 fois la même année. Ca pose question

# %%
df_selec_2["duree_detention"].describe().to_frame()
# Out:
#        duree_detention
# count    101507.000000
# mean          4.209522
# std           2.176424
# min          -0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           6.000000
# max           8.000000

# %%
# Pour les vis suivantes, on isole les lignes "not last" des biens qui ont été revendus au moins 1 fois pendant la période

selec_3=df_selec_2[(df_selec_2["qty_of_mut"]>0)&(df_selec_2["range_revente_last"]=="not last")]
selec.shape
# Out:
# (13365, 38)

# %%
selec_3["duree_detention"].value_counts().sort_index().to_frame()
# Out:
#            duree_detention
# -0.000000              334
# 1.000000              1141
# 2.000000              1604
# 3.000000              1998
# 4.000000              1945
# 5.000000              1426
# 6.000000               914
# 7.000000               382

# %%
plt.figure(figsize=(10,5))

sns.countplot(x='duree_detention', data=selec_3)
plt.title("Durée de détention des biens qui ont été revendus entre 2014 et 2021", fontsize=15)
plt.xlabel("Durée de détention (en année)");

# %%
w=selec_3.groupby("l_codinsee").agg({"duree_detention":"mean"})

# %%
list_arrond=w.index.tolist()
x_ticks=np.arange(len(w))

plt.figure(figsize=(7,5))
plt.bar(range(len(w)), w["duree_detention"], linewidth=5, color="#dfa801")
plt.xticks(x_ticks, list_arrond, rotation=60)
plt.xlabel("Arrondissements")
plt.ylabel("Durée moyenne de détention du bien (en année)")
plt.title("Durée moyenne de détention des biens qui ont été revendus \n pendant la période 2014 -2021 , par arrondissement", fontsize=15);

# %%
z=selec_3.groupby("Type_appart").agg({"duree_detention":"mean"})

# %%
list_z=z.index.tolist()
x_ticks=np.arange(len(z))

plt.figure(figsize=(7,5))
plt.bar(range(len(z)), z["duree_detention"], linewidth=5, color="#aaf550")
plt.xticks(x_ticks, list_z, rotation=60)
plt.xlabel("Type d'appartement")
plt.ylabel("Durée moyenne de détention du bien (en année)")
plt.title("Durée moyenne de détention des biens qui ont été revendus \n pendant la période 2014 -2021 , par type d'appartement", fontsize=15);

# %%
plt.figure(figsize=(7,5))
sns.catplot(x = 'adedpe202006_mean_class_conso_ener', y = 'duree_detention', kind="bar", data = selec_3, order=["B","C", "D", "E", "F", "G", "N"])
plt.xlabel("Classe de consommation énergétique")
plt.ylabel("Durée moyenne de détention du bien (en année)")
plt.title("Durée moyenne de détention des biens qui ont été revendus \n pendant la période 2014 -2021 , par classe de consomation", fontsize=15);

# %%
plt.figure(figsize=(7,5))
sns.catplot(x = 'Commerces_bruyants', y = 'duree_detention', kind="bar", data = selec_3)
plt.xlabel("Nbre de commerces bruyants dans le bâtiment")
plt.ylabel("Durée moyenne de détention du bien (en année)")
plt.title("Durée moyenne de détention des biens qui ont été revendus \n pendant la période 2014 -2021 , selon le nbre de commerces bruyants dans le bâtiment ", fontsize=15);

# %%
df_selec_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101507 entries, 7819809 to 8843172
# Data columns (total 36 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   etaban_lot                             101507 non-null  object
#  1   qty_of_mut                             101507 non-null  int64
#  2   Revente                                101507 non-null  int64
#  3   datemut                                101507 non-null  object
#  4   anneemut                               101507 non-null  int64
#  5   moismut                                101507 non-null  int64
#  6   Immeuble_neuf                          101507 non-null  int64
#  7   valeurfonc                             101507 non-null  float64
#  8   nblot                                  101507 non-null  object
#  9   l_codinsee                             101507 non-null  int64
#  10  nblocdep                               101507 non-null  object
#  11  Type_appart                            101507 non-null  object
#  12  scarrez                                101507 non-null  float64
#  13  anarnc202012_nb_lot_tot                101507 non-null  float64
#  14  adedpe202006_mean_class_conso_ener     101507 non-null  object
#  15  adedpe202006_mean_class_estim_ges      101507 non-null  object
#  16  adedpe202006_logtype_traversant        101507 non-null  object
#  17  cerffo2020_annee_construction          101507 non-null  object
#  18  cerffo2020_nb_log                      101507 non-null  int64
#  19  mcumer202007_is_mer                    101507 non-null  float64
#  20  adedpe202006_logtype_ch_type_inst      101507 non-null  object
#  21  adedpe202006_logtype_ecs_type_inst     101507 non-null  object
#  22  adedpe202006_logtype_mur_mat_ext       101507 non-null  object
#  23  adedpe202006_logtype_mur_pos_isol_ext  101507 non-null  object
#  24  Commerces_bruyants                     101507 non-null  int64
#  25  cat_valeur                             101507 non-null  category
#  26  range_revente_first                    19071 non-null   object
#  27  Evol_val                               101507 non-null  float64
#  28  Estimation_prix_m2                     101507 non-null  int64
#  29  Valeur_estimée                         101507 non-null  float64
#  30  Taille_copro                           101507 non-null  object
#  31  nbre_etages                            101507 non-null  object
#  32  cat_scarrez                            101507 non-null  category
#  33  range_revente_last                     101507 non-null  object
#  34  duree_detention                        101507 non-null  float64
#  35  annee_en_cours                         101507 non-null  int64
# dtypes: category(2), float64(7), int64(10), object(17)
# memory usage: 27.3+ MB

# %%
# Suppression des variables qui vont gêner la modélisation ou pas utiles pq elles ont servi à construire d'autres variables

df_selec_2=df_selec_2.drop(["valeurfonc", 
               "cerffo2020_nb_log", 
               "qty_of_mut",
              "datemut",
              "moismut",
              "etaban_lot",
              "cat_valeur",
              "range_revente_first",
              "range_revente_last",
              "cat_scarrez",
               "annee_en_cours",
               "Estimation_prix_m2",
               "Valeur_estimée"], axis=1)

# %%
df_selec_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101507 entries, 7819809 to 8843172
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Revente                                101507 non-null  int64
#  1   anneemut                               101507 non-null  int64
#  2   Immeuble_neuf                          101507 non-null  int64
#  3   nblot                                  101507 non-null  object
#  4   l_codinsee                             101507 non-null  int64
#  5   nblocdep                               101507 non-null  object
#  6   Type_appart                            101507 non-null  object
#  7   scarrez                                101507 non-null  float64
#  8   anarnc202012_nb_lot_tot                101507 non-null  float64
#  9   adedpe202006_mean_class_conso_ener     101507 non-null  object
#  10  adedpe202006_mean_class_estim_ges      101507 non-null  object
#  11  adedpe202006_logtype_traversant        101507 non-null  object
#  12  cerffo2020_annee_construction          101507 non-null  object
#  13  mcumer202007_is_mer                    101507 non-null  float64
#  14  adedpe202006_logtype_ch_type_inst      101507 non-null  object
#  15  adedpe202006_logtype_ecs_type_inst     101507 non-null  object
#  16  adedpe202006_logtype_mur_mat_ext       101507 non-null  object
#  17  adedpe202006_logtype_mur_pos_isol_ext  101507 non-null  object
#  18  Commerces_bruyants                     101507 non-null  int64
#  19  Evol_val                               101507 non-null  float64
#  20  Taille_copro                           101507 non-null  object
#  21  nbre_etages                            101507 non-null  object
#  22  duree_detention                        101507 non-null  float64
# dtypes: float64(5), int64(5), object(13)
# memory usage: 18.6+ MB

# %%
df2=df_selec_2

# %%
df2.head()
# Out:
#             Revente  anneemut  Immeuble_neuf nblot  l_codinsee nblocdep  \
# idmutation
# 7819809           0      2021              0     1       75101        1
# 7819821           0      2021              0     1       75117        0
# 7819822           0      2021              0     3       75115        1
# 7819824           1      2021              0     1       75118        0
# 8563148           1      2016              0     1       75118        0
#
#            Type_appart   scarrez  anarnc202012_nb_lot_tot  \
# idmutation
# 7819809             2P 26.060000               394.000000
# 7819821             2P 35.530000                33.000000
# 7819822             3P 35.400000                50.000000
# 7819824             2P 46.020000                52.000000
# 8563148             2P 45.760000                52.000000
#
#            adedpe202006_mean_class_conso_ener  ... mcumer202007_is_mer  \
# idmutation                                     ...
# 7819809                                     E  ...            1.000000
# 7819821                                     F  ...            1.000000
# 7819822                                     F  ...            1.000000
# 7819824                                     E  ...            1.000000
# 8563148                                     E  ...            1.000000
#
#            adedpe202006_logtype_ch_type_inst  \
# idmutation
# 7819809                           individuel
# 7819821                           individuel
# 7819822                           individuel
# 7819824                           individuel
# 8563148                           individuel
#
#            adedpe202006_logtype_ecs_type_inst  \
# idmutation
# 7819809                            individuel
# 7819821                            individuel
# 7819822                            individuel
# 7819824                            individuel
# 8563148                            individuel
#
#             adedpe202006_logtype_mur_mat_ext  \
# idmutation
# 7819809                        Mur en brique
# 7819821                        Mur en pierre
# 7819822                        Mur en pierre
# 7819824                        Mur en pierre
# 8563148                        Mur en pierre
#
#            adedpe202006_logtype_mur_pos_isol_ext Commerces_bruyants  Evol_val  \
# idmutation
# 7819809                                      ITI                  1 -0.044936
# 7819821                                      ITI                  0 -0.176744
# 7819822                                      ITI                  0 -0.174273
# 7819824                                      ITI                  1  0.492303
# 8563148                                      ITI                  1  0.000000
#
#            Taille_copro  nbre_etages  duree_detention
# idmutation
# 7819809     Très grande     De 4 à 7         1.000000
# 7819821          Grande     De 4 à 7         1.000000
# 7819822          Grande     De 4 à 7         1.000000
# 7819824         Moyenne     De 4 à 7         1.000000
# 8563148         Moyenne     De 4 à 7         5.000000
#
# [5 rows x 23 columns]

# %%
df2.to_csv(r"C:\Users\Anne\Projet Bâtiment\210622\df2.csv", index=False)
