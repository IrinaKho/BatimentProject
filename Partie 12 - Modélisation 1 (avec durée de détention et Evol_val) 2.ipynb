# %%
#MODELISATION AVEC VARIABLE CIBLE = "Revente" (avec les variables "durée de détention" et "evol_val")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df2=pd.read_csv("df2.csv")

# %%
df2.head()
# Out:
#    Revente  anneemut  Immeuble_neuf nblot  l_codinsee nblocdep Type_appart  \
# 0        0      2021              0     1       75101        1          2P
# 1        0      2021              0     1       75117        0          2P
# 2        0      2021              0     3       75115        1          3P
# 3        1      2021              0     1       75118        0          2P
# 4        1      2016              0     1       75118        0          2P
#
#    scarrez  anarnc202012_nb_lot_tot adedpe202006_mean_class_conso_ener  ...  \
# 0    26.06                    394.0                                  E  ...
# 1    35.53                     33.0                                  F  ...
# 2    35.40                     50.0                                  F  ...
# 3    46.02                     52.0                                  E  ...
# 4    45.76                     52.0                                  E  ...
#
#   mcumer202007_is_mer adedpe202006_logtype_ch_type_inst  \
# 0                 1.0                        individuel
# 1                 1.0                        individuel
# 2                 1.0                        individuel
# 3                 1.0                        individuel
# 4                 1.0                        individuel
#
#   adedpe202006_logtype_ecs_type_inst  adedpe202006_logtype_mur_mat_ext  \
# 0                         individuel                     Mur en brique
# 1                         individuel                     Mur en pierre
# 2                         individuel                     Mur en pierre
# 3                         individuel                     Mur en pierre
# 4                         individuel                     Mur en pierre
#
#   adedpe202006_logtype_mur_pos_isol_ext Commerces_bruyants  Evol_val  \
# 0                                   ITI                  1 -0.044936
# 1                                   ITI                  0 -0.176744
# 2                                   ITI                  0 -0.174273
# 3                                   ITI                  1  0.492303
# 4                                   ITI                  1  0.000000
#
#   Taille_copro  nbre_etages  duree_detention
# 0  Très grande     De 4 à 7              1.0
# 1       Grande     De 4 à 7              1.0
# 2       Grande     De 4 à 7              1.0
# 3      Moyenne     De 4 à 7              1.0
# 4      Moyenne     De 4 à 7              5.0
#
# [5 rows x 23 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101507 entries, 0 to 101506
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Revente                                101507 non-null  int64
#  1   anneemut                               101507 non-null  int64
#  2   Immeuble_neuf                          101507 non-null  int64
#  3   nblot                                  101507 non-null  object
#  4   l_codinsee                             101507 non-null  int64
#  5   nblocdep                               101507 non-null  object
#  6   Type_appart                            101507 non-null  object
#  7   scarrez                                101507 non-null  float64
#  8   anarnc202012_nb_lot_tot                101507 non-null  float64
#  9   adedpe202006_mean_class_conso_ener     101507 non-null  object
#  10  adedpe202006_mean_class_estim_ges      101507 non-null  object
#  11  adedpe202006_logtype_traversant        101507 non-null  object
#  12  cerffo2020_annee_construction          101507 non-null  object
#  13  mcumer202007_is_mer                    101507 non-null  float64
#  14  adedpe202006_logtype_ch_type_inst      101507 non-null  object
#  15  adedpe202006_logtype_ecs_type_inst     101507 non-null  object
#  16  adedpe202006_logtype_mur_mat_ext       101507 non-null  object
#  17  adedpe202006_logtype_mur_pos_isol_ext  101507 non-null  object
#  18  Commerces_bruyants                     101507 non-null  int64
#  19  Evol_val                               101507 non-null  float64
#  20  Taille_copro                           101507 non-null  object
#  21  nbre_etages                            101507 non-null  object
#  22  duree_detention                        101507 non-null  float64
# dtypes: float64(5), int64(5), object(13)
# memory usage: 17.8+ MB

# %%
df2.isna().sum()
# Out:
# Revente                                  0
# anneemut                                 0
# Immeuble_neuf                            0
# nblot                                    0
# l_codinsee                               0
# nblocdep                                 0
# Type_appart                              0
# scarrez                                  0
# anarnc202012_nb_lot_tot                  0
# adedpe202006_mean_class_conso_ener       0
# adedpe202006_mean_class_estim_ges        0
# adedpe202006_logtype_traversant          0
# cerffo2020_annee_construction            0
# mcumer202007_is_mer                      0
# adedpe202006_logtype_ch_type_inst        0
# adedpe202006_logtype_ecs_type_inst       0
# adedpe202006_logtype_mur_mat_ext         0
# adedpe202006_logtype_mur_pos_isol_ext    0
# Commerces_bruyants                       0
# Evol_val                                 0
# Taille_copro                             0
# nbre_etages                              0
# duree_detention                          0
# dtype: int64

# %%
# Suppression de la variable annéemut qui va gêner la dichotomisation
df2=df2.drop("anneemut", axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
#Features / Target

X=df2.drop("Revente", axis=1)
y=df2["Revente"]

X.shape, y.shape
# Out:
# ((101507, 21), (101507,))

# %%
numeric_columns=X.select_dtypes(include=np.number).columns.tolist()
numeric_columns
# Out:
# ['Immeuble_neuf',
#  'l_codinsee',
#  'scarrez',
#  'anarnc202012_nb_lot_tot',
#  'mcumer202007_is_mer',
#  'Commerces_bruyants',
#  'Evol_val',
#  'duree_detention']

# %%
object_columns=X.select_dtypes(include='object').columns.tolist()
object_columns
# Out:
# ['nblot',
#  'nblocdep',
#  'Type_appart',
#  'adedpe202006_mean_class_conso_ener',
#  'adedpe202006_mean_class_estim_ges',
#  'adedpe202006_logtype_traversant',
#  'cerffo2020_annee_construction',
#  'adedpe202006_logtype_ch_type_inst',
#  'adedpe202006_logtype_ecs_type_inst',
#  'adedpe202006_logtype_mur_mat_ext',
#  'adedpe202006_logtype_mur_pos_isol_ext',
#  'Taille_copro',
#  'nbre_etages']

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.25, random_state=10)
X_train.shape, X_test.shape
# Out:
# ((76130, 21), (25377, 21))

# %%
#ENCODAGE DES DONNEES CATEGORIELLES

# %%
X_train=pd.get_dummies(X_train)

# %%
X_test=pd.get_dummies(X_test)

# %%
X_train.shape
# Out:
# (76130, 65)

# %%
X_test.shape
# Out:
# (25377, 65)

# %%
# NORMALISATION

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train[numeric_columns] = scaler.fit_transform(X_train[numeric_columns])
X_test[numeric_columns] = scaler.transform(X_test[numeric_columns])

# %%
# Utilisation de la carte Scikit Learn pour choix modèle de classification
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# Premier modèle : https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html

from sklearn.svm import LinearSVC

model1=LinearSVC()
model1.fit(X_train, y_train)
model1.score(X_test, y_test)
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.8146352996808134

# %%
y_pred_1=model1.predict(X_test)
pd.crosstab(y_test, y_pred_1)
# Out:
# col_0        0   1
# Revente
# 0        20670  11
# 1         4693   3

# %%
print(classification_report(y_test, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90     20681
#            1       0.21      0.00      0.00      4696
#
#     accuracy                           0.81     25377
#    macro avg       0.51      0.50      0.45     25377
# weighted avg       0.70      0.81      0.73     25377

# %%
# Deuxième modèle : https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

from sklearn.neighbors import KNeighborsClassifier

model2=KNeighborsClassifier()
model2.fit(X_train, y_train)
model2.score(X_test, y_test)
# Out:
# 0.7990700240375143

# %%
y_pred_2=model2.predict(X_test)
pd.crosstab(y_test, y_pred_2)
# Out:
# col_0        0     1
# Revente
# 0        19230  1451
# 1         3648  1048

# %%
print(classification_report(y_test, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88     20681
#            1       0.42      0.22      0.29      4696
#
#     accuracy                           0.80     25377
#    macro avg       0.63      0.58      0.59     25377
# weighted avg       0.76      0.80      0.77     25377

# %%
# Troisième modèle : https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
from sklearn.ensemble import RandomForestClassifier

model3=RandomForestClassifier()
model3.fit(X_train, y_train)
model3.score(X_test, y_test)
# Out:
# 0.9328131772865192

# %%
y_pred_3=model3.predict(X_test)
pd.crosstab(y_test, y_pred_3)
# Out:
# col_0        0     1
# Revente
# 0        20433   248
# 1         1457  3239

# %%
print(classification_report(y_test, y_pred_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     20681
#            1       0.93      0.69      0.79      4696
#
#     accuracy                           0.93     25377
#    macro avg       0.93      0.84      0.88     25377
# weighted avg       0.93      0.93      0.93     25377

# %%
# Affichage des meilleurs paramètres du RandomForestClassifier
feats = {}
for feature, importance in zip(X_train.columns, model3.feature_importances_):
    feats[feature] = importance 
    
importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Importance'})
importances.sort_values(by='Importance', ascending=False).head(5)
# Out:
#                          Importance
# Evol_val                   0.441506
# duree_detention            0.129764
# scarrez                    0.077844
# anarnc202012_nb_lot_tot    0.058059
# l_codinsee                 0.040514

# %%
# Quatrième modèle : https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html

from sklearn.linear_model import SGDClassifier

model4=SGDClassifier()
model4.fit(X_train, y_train)
model4.score(X_test, y_test)
# Out:
# 0.8149505457697915

# %%
y_pred_4=model4.predict(X_test)
pd.crosstab(y_test, y_pred_4)
# Out:
# col_0        0
# Revente
# 0        20681
# 1         4696

# %%
print(classification_report(y_test, y_pred_4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90     20681
#            1       0.00      0.00      0.00      4696
#
#     accuracy                           0.81     25377
#    macro avg       0.41      0.50      0.45     25377
# weighted avg       0.66      0.81      0.73     25377
# C:\Users\Anne\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Anne\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Anne\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Cinquième modèle : https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

from sklearn.linear_model import LogisticRegression

model5=LogisticRegression()
model5.fit(X_train, y_train)
model5.score(X_test, y_test)
# Out:
# C:\Users\Anne\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8164479646924381

# %%
y_pred_5=model5.predict(X_test)
pd.crosstab(y_test, y_pred_5)
# Out:
# col_0        0   1
# Revente
# 0        20641  40
# 1         4618  78

# %%
print(classification_report(y_test, y_pred_5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90     20681
#            1       0.66      0.02      0.03      4696
#
#     accuracy                           0.82     25377
#    macro avg       0.74      0.51      0.47     25377
# weighted avg       0.79      0.82      0.74     25377

# %%
# Sixième modèle : https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# Trop long... On le suspend

#from sklearn.svm import SVC

#model6=SVC(kernel="linear")
#model6.fit(X_train, y_train)
#model6.score(X_test, y_test)

# %%
#y_pred_6=model6.predict(X_test)
#pd.crosstab(y_test, y_pred_6)

# %%
#print(classification_report(y_test, y_pred_6))

# %%
# Septième modèle : https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

from sklearn.tree import DecisionTreeClassifier

model7=DecisionTreeClassifier()
model7.fit(X_train, y_train)
model7.score(X_test, y_test)
# Out:
# 0.9001458013161524

# %%
y_pred_7=model7.predict(X_test)
pd.crosstab(y_test, y_pred_7)
# Out:
# col_0        0     1
# Revente
# 0        19330  1351
# 1         1183  3513

# %%
print(classification_report(y_test, y_pred_7))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94     20681
#            1       0.72      0.75      0.73      4696
#
#     accuracy                           0.90     25377
#    macro avg       0.83      0.84      0.84     25377
# weighted avg       0.90      0.90      0.90     25377

# %%
# Affichage des meilleurs paramètres DecisionTreeClassifier
feats = {}
for feature, importance in zip(X_train.columns, model7.feature_importances_):
    feats[feature] = importance 
    
importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Importance'})
importances.sort_values(by='Importance', ascending=False).head(5)
# Out:
#                          Importance
# Evol_val                   0.609459
# duree_detention            0.112282
# scarrez                    0.062855
# anarnc202012_nb_lot_tot    0.044524
# l_codinsee                 0.025818

# %%
# Le meilleur score est obtenu pour le modèle de RandomForestClassifier (commentaires des scores sur doc excel Compar_scores). 
# Nous allons donc essayer d'optimiser ce modèle :

# %%
# Gridsearch

# https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
# https://scikit-learn.org/stable/modules/grid_search.html
# https://www.youtube.com/watch?v=c4mS7KaOIGY

from sklearn.model_selection import GridSearchCV


# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [2,4]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]

params_model3={"n_estimators":n_estimators, 
               "max_features" :max_features,
              "max_depth": max_depth,
              "min_samples_split": min_samples_split,
               "min_samples_leaf":min_samples_leaf,
               "bootstrap":bootstrap}

# %%
CV_model3 = GridSearchCV(estimator=model3, param_grid=params_model3, cv= 5, verbose=3)

# %%
CV_model3.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.811 total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.8s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=41;, score=0.811 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=48;, score=0.811 total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=56;, score=0.811 total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.9s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=64;, score=0.811 total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=72;, score=0.811 total time=   0.9s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=80;, score=0.811 total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.811 total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.811 total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.811 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.811 total time=   0.4s
# ...
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.922 total time=   1.2s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.919 total time=   1.2s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.925 total time=   1.2s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.923 total time=   1.2s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.922 total time=   1.2s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.924 total time=   2.0s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.921 total time=   2.0s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.927 total time=   2.1s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.923 total time=   2.0s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=17;, score=0.922 total time=   2.0s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.924 total time=   3.0s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.926 total time=   3.1s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.925 total time=   3.0s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.929 total time=   3.0s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=25;, score=0.926 total time=   3.0s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.928 total time=   4.0s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.926 total time=   3.9s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.928 total time=   4.0s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.926 total time=   4.0s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=33;, score=0.929 total time=   4.1s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.928 total time=   5.2s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.925 total time=   5.1s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.928 total time=   5.3s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.926 total time=   5.2s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=41;, score=0.927 total time=   5.1s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.928 total time=   5.9s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.925 total time=   5.9s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.928 total time=   5.9s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.926 total time=   5.8s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=48;, score=0.929 total time=   5.9s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.927 total time=   6.9s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.925 total time=   7.1s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.926 total time=   6.8s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.928 total time=   6.8s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=56;, score=0.929 total time=   6.9s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.928 total time=   7.9s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.927 total time=   7.8s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.928 total time=   7.8s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.927 total time=   7.8s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=64;, score=0.928 total time=   7.8s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.927 total time=   8.8s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.925 total time=   8.8s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.927 total time=   8.8s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.928 total time=   8.7s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=72;, score=0.928 total time=   8.9s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.927 total time=  10.0s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.925 total time=   9.8s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.928 total time=   9.9s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.928 total time=   9.7s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=80;, score=0.929 total time=   9.8s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.921 total time=   1.2s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.919 total time=   1.2s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.920 total time=   1.2s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.923 total time=   1.2s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=0.924 total time=   1.2s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.925 total time=   2.0s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.922 total time=   2.1s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.923 total time=   2.1s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.925 total time=   2.0s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=17;, score=0.920 total time=   2.1s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.925 total time=   3.1s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.924 total time=   3.0s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.928 total time=   3.0s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.928 total time=   3.0s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=25;, score=0.928 total time=   3.0s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.927 total time=   4.1s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.925 total time=   4.0s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.925 total time=   4.1s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.927 total time=   4.1s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=33;, score=0.926 total time=   4.1s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.928 total time=   5.0s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.926 total time=   4.9s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.927 total time=   4.9s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.925 total time=   4.9s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=41;, score=0.929 total time=   4.9s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.927 total time=   5.8s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.925 total time=   5.7s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.928 total time=   5.8s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.927 total time=   5.8s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=48;, score=0.929 total time=   5.8s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.927 total time=   6.8s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.927 total time=   6.8s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.927 total time=   6.7s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.928 total time=   6.7s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=56;, score=0.928 total time=   6.8s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.928 total time=   7.7s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.926 total time=   7.7s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.928 total time=   7.7s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.928 total time=   7.8s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=64;, score=0.927 total time=   7.8s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.927 total time=   8.8s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.924 total time=   8.7s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.928 total time=   8.9s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.927 total time=   8.6s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=72;, score=0.930 total time=   8.7s
# [CV 1/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.927 total time=   9.8s
# [CV 2/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.925 total time=   9.7s
# [CV 3/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.929 total time=   9.6s
# [CV 4/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.926 total time=   9.8s
# [CV 5/5] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=80;, score=0.930 total time=   9.6s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 4, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72,
#                                           80]},
#              verbose=3)

# %%
CV_model3.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 80}

# %%
print("score : {}".format(CV_model3.score(X_test, y_test)))
# Out:
# score : 0.9325767427197856

# %%
# Prédiction du modèle
y_pred_CV_model3 = CV_model3.predict(X_test)

# %%
# Matrice de correlation
pd.crosstab(y_test, y_pred_CV_model3, rownames=['Classe'], colnames=['Classe prédite par dt'])
# Out:
# Classe prédite par dt      0     1
# Classe
# 0                      20421   260
# 1                       1451  3245

# %%
# Rapport de classification
print(classification_report(y_test, y_pred_CV_model3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     20681
#            1       0.93      0.69      0.79      4696
#
#     accuracy                           0.93     25377
#    macro avg       0.93      0.84      0.88     25377
# weighted avg       0.93      0.93      0.93     25377

# %%
# On va essayer d'améliorer le recall du RandomForestClassifier avec l'over et l'undersampling

# %%
# OVERSAMPLING & UNDERSAMPLING 

# La classification sur données déséquilibrées est un problème de classification où l'échantillon d'apprentissage 
# contient une forte disparité entre les classes à prédire.
# Ce problème revient fréquemment dans les problèmes de classifications binaires.

# %%
# OVERSAMPLING = Les méthodes d'Oversampling fonctionnent en augmentant le nombre d'observations 
# de la / des classes minoritaires afin d'arriver à un ratio classe minoritaire / classe majoritaire satisfaisant.

# %%
# 1ère méthode d'Oversampling = OVERSAMPLING ALEATOIRE

from imblearn.over_sampling import RandomOverSampler
from imblearn.metrics import classification_report_imbalanced

# %%
ros = RandomOverSampler()
X_ro, y_ro = ros.fit_resample(X_train, y_train)
print(y_ro.value_counts())
# Out:
# 0    61755
# 1    61755
# Name: Revente, dtype: int64

# %%
model3.fit(X_ro, y_ro)
y_pred = model3.predict(X_test)
cm = pd.crosstab(y_test, y_pred, rownames=['Classe réelle'], colnames=['Classe prédite'])
cm
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               20201   480
# 1                1186  3510

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     20681
#            1       0.88      0.75      0.81      4696
#
#     accuracy                           0.93     25377
#    macro avg       0.91      0.86      0.88     25377
# weighted avg       0.93      0.93      0.93     25377

# %%
# 2ème méthode d'Oversampling = SMOTE

from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE()
X_sm, y_sm = sm.fit_resample(X_train, y_train)
print(y_sm.value_counts())
# Out:
# 0    61755
# 1    61755
# Name: Revente, dtype: int64

# %%
model3.fit(X_sm, y_sm)
y_pred = model3.predict(X_test)
cm = pd.crosstab(y_test, y_pred, rownames=['Classe réelle'], colnames=['Classe prédite'])
cm
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               19445  1236
# 1                 962  3734

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     20681
#            1       0.75      0.80      0.77      4696
#
#     accuracy                           0.91     25377
#    macro avg       0.85      0.87      0.86     25377
# weighted avg       0.92      0.91      0.91     25377

# %%
# 3ème méthode d'Oversampling : ADASYN
# https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.ADASYN.html


from imblearn.over_sampling import ADASYN

# %%
adsyn = ADASYN()
X_adsyn, y_adsyn = adsyn.fit_resample(X_train, y_train)
print(y_adsyn.value_counts())
# Out:
# 1    62784
# 0    61755
# Name: Revente, dtype: int64

# %%
model3.fit(X_adsyn, y_adsyn)
y_pred = model3.predict(X_test)
cm = pd.crosstab(y_test, y_pred, rownames=['Classe réelle'], colnames=['Classe prédite'])
cm
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               19480  1201
# 1                 979  3717

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     20681
#            1       0.76      0.79      0.77      4696
#
#     accuracy                           0.91     25377
#    macro avg       0.85      0.87      0.86     25377
# weighted avg       0.92      0.91      0.91     25377

# %%
# 4 ème méthode d'Oversampling : BORDERLINE smote
# https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.BorderlineSMOTE.html


from imblearn.over_sampling import BorderlineSMOTE

# %%
bdls = BorderlineSMOTE()
X_bdls, y_bdls = bdls.fit_resample(X_train, y_train)
print(y_bdls.value_counts())
# Out:
# 0    61755
# 1    61755
# Name: Revente, dtype: int64

# %%
model3.fit(X_bdls, y_bdls)
y_pred = model3.predict(X_test)
cm = pd.crosstab(y_test, y_pred, rownames=['Classe réelle'], colnames=['Classe prédite'])
cm
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               19453  1228
# 1                 942  3754

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     20681
#            1       0.75      0.80      0.78      4696
#
#     accuracy                           0.91     25377
#    macro avg       0.85      0.87      0.86     25377
# weighted avg       0.92      0.91      0.92     25377

# %%
# UNDERSAMPLING = Les méthodes d'Undersampling fonctionnent en diminuant le nombre d'observations 
# de la / des classes majoritaires afin d'arriver à un ratio classe minoritaire / classe majoritaire satisfaisant.

# %%
# UNDERSAMPLING ALEATOIRE
from imblearn.under_sampling import RandomUnderSampler

# %%
RUS=RandomUnderSampler()
X_ru, y_ru=RUS.fit_resample(X_train, y_train)
print(y_ru.value_counts())
# Out:
# 0    14375
# 1    14375
# Name: Revente, dtype: int64

# %%
model3.fit(X_ru, y_ru)
y_pred = model3.predict(X_test)
cm = pd.crosstab(y_test, y_pred, rownames=['Classe réelle'], colnames=['Classe prédite'])
cm
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               18237  2444
# 1                 544  4152

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92     20681
#            1       0.63      0.88      0.74      4696
#
#     accuracy                           0.88     25377
#    macro avg       0.80      0.88      0.83     25377
# weighted avg       0.91      0.88      0.89     25377

# %%
# PARAMETRE CLASS_WEIGHT : nous allons donner plus de poids à la classe 1 (70% au lieu de 50%)

model3=RandomForestClassifier(class_weight={0: 0.30, 1: 0.70})
model3.fit(X_train, y_train)
model3.score(X_test, y_test)
# Out:
# 0.9294242818300036

# %%
y_pred_3=model3.predict(X_test)
pd.crosstab(y_test, y_pred_3)
# Out:
# col_0        0     1
# Revente
# 0        20455   226
# 1         1565  3131

# %%
print(classification_report(y_test, y_pred_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     20681
#            1       0.93      0.67      0.78      4696
#
#     accuracy                           0.93     25377
#    macro avg       0.93      0.83      0.87     25377
# weighted avg       0.93      0.93      0.92     25377

# %%
# MODIFICATION DU SEUIL DE PROBA à 0.3

# %%
model3=RandomForestClassifier()
model3.fit(X_train, y_train)

threshold = 0.3

probs = model3.predict_proba(X_test)
pred_class = (probs[:,1]>=threshold).astype('int')

pd.crosstab(y_test, pred_class)
# Out:
# col_0        0     1
# Revente
# 0        19296  1385
# 1          715  3981

# %%
print(classification_report(y_test, pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95     20681
#            1       0.74      0.85      0.79      4696
#
#     accuracy                           0.92     25377
#    macro avg       0.85      0.89      0.87     25377
# weighted avg       0.92      0.92      0.92     25377

# %%
# MODIFICATION DU SEUIL DE PROBA à 0.4

# %%
model3=RandomForestClassifier()
model3.fit(X_train, y_train)

threshold = 0.4

probs = model3.predict_proba(X_test)
pred_class = (probs[:,1]>=threshold).astype('int')

pd.crosstab(y_test, pred_class)
# Out:
# col_0        0     1
# Revente
# 0        20083   598
# 1         1084  3612

# %%
print(classification_report(y_test, pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     20681
#            1       0.86      0.77      0.81      4696
#
#     accuracy                           0.93     25377
#    macro avg       0.90      0.87      0.89     25377
# weighted avg       0.93      0.93      0.93     25377

# %%
#https://datascientest.com/comment-gerer-les-problemes-de-classification-desequilibree-partie-ii
